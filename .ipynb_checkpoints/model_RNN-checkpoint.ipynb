# %%
import os
import pickle
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

PATH_DATA = "./data/mortality/data/"
PATH_VALIDATION = "./data/mortality/validation/"
PATH_OUTPUT = "./output/"

# %% [markdown]
# # Mortality Prediction Based on RNN with GRU units

# %% [markdown]
# ## 1. Data Overview
#
# - Data source: MIMIC-III https://mimic.physionet.org/

# %%
df_mortality = pd.read_csv(os.path.join(PATH_DATA, "MORTALITY.csv"))
df_admissions = pd.read_csv(os.path.join(PATH_DATA, "ADMISSIONS.csv"))
df_diagnoses = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"))

# %%
df_mortality.head()
# Out:
#    SUBJECT_ID  MORTALITY
# 0         252          1
# 1         721          1
# 2         776          1
# 3         801          0
# 4         822          1

# %%
df_admissions.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 1      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 2      33          34   115799  2186-07-18 16:46:00  2186-07-20 16:00:00
# 3      34          34   144319  2191-02-23 05:23:00  2191-02-25 20:20:00
# 4      36          36   182104  2131-04-30 07:15:00  2131-05-08 14:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION DISCHARGE_LOCATION  \
# 0       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE
# 1       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
# 3       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
# 4       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
#
#   INSURANCE LANGUAGE       RELIGION MARITAL_STATUS ETHNICITY  \
# 0  Medicare      NaN       CATHOLIC        MARRIED     WHITE
# 1  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 2  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 3  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 4  Medicare     ENGL  NOT SPECIFIED        MARRIED     WHITE
#
#              EDREGTIME            EDOUTTIME  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3  2191-02-23 04:23:00  2191-02-23 07:25:00
# 4                  NaN                  NaN
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 1                                         BRAIN MASS                     0
# 2                                    CHEST PAIN\CATH                     0
# 3                                        BRADYCARDIA                     0
# 4  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
df_diagnoses.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1523         117   140784      1.0      5715
# 1    1524         117   140784      2.0      7895
# 2    1525         117   140784      3.0     07054
# 3    1526         117   140784      4.0      2875
# 4    1527         117   140784      5.0      4280

# %% [markdown]
# ## 2. Data preprocessing
#
# ### 2.1 Build original dataset
#
# - `extract_code`
#  - follow ICD-9-CM format (https://www.cms.gov/Medicare/Quality-Initiatives-Patient-Assessment-Instruments/HospitalQualityInits/Downloads/HospitalAppendix_F.pdf) to extract main digits of ICD-9 code
#
#
# - `build_dict`
#  - create corresponding id map for ICD-9 code, {main digits of ICD9: unique feature ID}
#
#
# - `build_dataset`
#  - group the diagnosis codes for the same visit
#  - group the visits for same patient
#  - make visit lists for paitents with chronological order
#  - return: List(patient IDs), List(labels), Visit sequence data as a List of List of List.

# %%
def extract_code(icd9_object):

    icd9_str = str(icd9_object)
    if icd9_str[0] == 'E': icd9_str = icd9_str[0:4]
    else: icd9_str = icd9_str[0:3]
    
    return icd9_str

# %%
def build_dict(df_icd9, extract_func):

    unique_code = df_icd9['ICD9_CODE'].apply(extract_func).unique()
    unique_code = pd.Series(unique_code).sort_values()
    code_dict = dict(zip(unique_code, range(len(unique_code))))
    
    return code_dict

# %%
def build_dataset(path, code_dict, extract_func):

    df_mortality = pd.read_csv(os.path.join(path, "MORTALITY.csv"))
    df_admissions = pd.read_csv(os.path.join(path, "ADMISSIONS.csv"))
    df_diagnoses = pd.read_csv(os.path.join(path, "DIAGNOSES_ICD.csv"))
    
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].apply(extract_func)
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].map(code_dict)
    df_joined = df_admissions.merge(df_diagnoses, on=['HADM_ID', 'SUBJECT_ID'])
    df_patient_admittee_ICD9 = df_joined[['SUBJECT_ID', 'ADMITTIME','ICD9_CODE']]
    
    patient_ids = []
    labels = []
    seq_data = []
    
    for name1, d in df_patient_admittee_ICD9.groupby('SUBJECT_ID'):
        patient_ids.append(name1)
        labels.extend(list(df_mortality["MORTALITY"][(df_mortality["SUBJECT_ID"] == name1)]))
        subl = []
        d['ADMITTIME'] = pd.to_datetime(d['ADMITTIME'])
        for name2, subd in d.groupby('ADMITTIME'):
            subl.append(list(subd['ICD9_CODE']))
        seq_data.append(subl)
    
    return patient_ids, labels, seq_data

# %%
print("Building feature id map")
df_icd9 = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"), usecols=["ICD9_CODE"])
code_dict = build_dict(df_icd9, extract_code)

print("Constructing train and test set")
ids, labels, seqs = build_dataset(PATH_DATA, code_dict, extract_code)
train_ids, test_ids, train_seqs, test_seqs, train_labels, test_labels = train_test_split(ids, seqs, labels, test_size=0.2)

print("Constructing validation set")
valid_ids, valid_labels, valid_seqs = build_dataset(PATH_VALIDATION, code_dict, extract_code)
print("Completed!")
# Out:
# Building feature id map
# Constructing train and test set
# Constructing validation set
# Completed!

# %%
ids[0:5] # patient IDs
# Out:
# [17, 23, 34, 36, 61]

# %%
labels[0:5] # mortality
# Out:
# [1, 1, 1, 1, 0]

# %%
seqs[0:5] # unique feature id
# Out:
# [[[545, 336, 854, 171], [303, 375, 582, 336, 210, 525, 522, 171]],
#  [[296, 293, 304, 872, 171, 287, 451, 279],
#   [132, 242, 577, 304, 287, 171, 171, 872, 872, 857]],
#  [[292, 308, 305, 307, 746, 306, 296, 782],
#   [307, 308, 306, 296, 881, 308, 148, 258]],
#  [[296, 293, 367, 287, 204, 393, 451, 852, 447],
#   [747, 747, 297, 331, 745, 367, 296, 872, 287, 451, 393, 852],
#   [408, 297, 382, 358, 746, 382, 296, 367, 287, 451, 199, 852]],
#  [[113, 187, 186, 429, 184, 164, 748, 430, 498],
#   [113,
#    183,
#    745,
#    420,
#    418,
#    175,
#    16,
#    744,
#    175,
#    595,
#    43,
#    175,
#    336,
#    307,
#    157,
#    245,
#    34]]]

# %% [markdown]
# ### 2.2 Custom Pytorch Dataset
#
# For each patient, I decided to use a matrix, rows represent different visits, jth column show the integer feature ID j. If matrix[i][j] == 1, it means that on ith visit, we get feature ID j.

# %%
# for each row, get the number of feature id.
def get_num_features(seqs):

    def get_flatten_list(ori_list, flatten_list = None):
        if flatten_list is None: flatten_list = []
        for i in ori_list:
            if isinstance(i, list): get_flatten_list(i, flatten_list)
            else: flatten_list.append(i)
        return flatten_list

    def get_max(list1):
        tmp = -1
        for i in list1:
            if i > tmp: tmp = i
        return tmp
    
    l = get_flatten_list(seqs)
    return get_max(l) + 1

# %%
# inherit from Dataset, represent matrixs.
class MyDataset(Dataset):
    def __init__(self, seqs, labels, num_features):

        self.labels = labels
        self.seqs = []
        def isNaN(num):
            return num != num
        for seq in seqs:
            new_seq = []
            for visit in seq:
                new_visit = [0] * int(num_features)
                for i in visit:
                    if not isNaN(i): new_visit[int(i)] = 1
                new_visit = np.asarray(new_visit)
                new_seq.append(new_visit)
            new_seq = np.asarray(new_seq)
            self.seqs.append(new_seq)
            
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # returns will be wrapped as List of Tensor(s) by DataLoader
        return self.seqs[index], self.labels[index]

# %% [markdown]
# ### 2.3 Generate mini-batches represented by 3D tensors
#
# Generate mini-batches by defining `collate_fn` which is an argument of DataLoader constructor.
#
# - mini-batches: batch_size * max_length * num_features. A min-batch consists of different patient's matrice
#
# - If matrice in same batch have different number of rows, I will padding them with zero rows.

# %%
def collate_fn(batch):

    def getKey(item):
        return item[1]
    
    new_tuples = []
    seqs = []
    labels = []
    lengths = []
    max_length = -1
    num_features = len(batch[0][0][0])
    
    for b in batch:
        b_seqs = b[0]
        tmp_list = [b_seqs, len(b_seqs), b[1]]
        new_tuples.append(tuple(tmp_list))
        if len(b_seqs) > max_length:
            max_length = len(b_seqs)
    batch = sorted(new_tuples, key = getKey, reverse=True)
    
    for b in batch:
        b_seqs = b[0]
        labels.append(b[2])
        lengths.append(b[1])
        b_seqs = list(b_seqs)
        while len(b_seqs) < max_length:
            b_seqs.append([0] * num_features)
        seqs.append(torch.Tensor(b_seqs))
    seqs_tensor = torch.stack(seqs, 0)
    lengths_tensor = torch.LongTensor(lengths)
    labels_tensor = torch.LongTensor(labels)

    return (seqs_tensor, lengths_tensor), labels_tensor

# %% [markdown]
# ## 3. Build RNN model
#
#
# - Only need to define the forward function, the backward function will be generate automatically

# %%
class MyNet(nn.Module):
    def __init__(self, dim_input):
        super(MyNet, self).__init__()
        self.fc1 = nn.Linear(dim_input, 32)
        self.rnn = nn.GRU(input_size=32, hidden_size=16, num_layers=2, batch_first=True, dropout=0.5, bidirectional=False)
        self.fc2 = nn.Linear(16, 2)
        self.tanh = nn.Tanh()

    def forward(self, input_tuple):
        seqs, lengths = input_tuple
        seqs = self.fc1(seqs)
        seqs = F.tanh(seqs)
        seqs = pack_padded_sequence(seqs, lengths, batch_first=True)
        seqs, _ = self.rnn(seqs)
        seqs, _ = pad_packed_sequence(seqs, batch_first=True)
        new_seqs = []
        for i in range(0, len(seqs)):
            new_seqs.append(seqs[i][lengths[i] - 1])
        new_seqs = torch.stack(new_seqs, 0)
        seqs = self.fc2(new_seqs)
        return seqs

# %% [markdown]
# ## 4. Training and validation process

# %%
import os
import time

class MyAverageGenerator():
    def __init__(self):
        self.val = 0
        self.average = 0
        self.sum = 0
        self.count = 0

    def update(self, val, size = 1):
        self.val = val
        self.sum += val * size
        self.count += size
        self.average = self.sum / self.count
 
'''
Reference: https://github.com/cse6250/SepsisPrediction/blob/1b732548e263a29e859540bbcda6ede2c40445db/src/sepsis_prediction_lstm/utils.py
'''

def get_batch_accuracy(output, target):
    
    with torch.no_grad():

        batch_size = target.size(0)
        _, pred = output.max(1)
        correct = pred.eq(target).sum()

        return correct * 100.0 / batch_size

def train(model, device, data_loader, criterion, optimizer, epoch, print_freq=10):
    batch_time = MyAverageGenerator()
    data_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    acc = MyAverageGenerator()

    model.train()

    end = time.time()
    for i, (input, target) in enumerate(data_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        if isinstance(input, tuple):
            input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
        else:
            input = input.to(device)
        target = target.to(device)

        optimizer.zero_grad()
        output = model(input)
        loss = criterion(output, target)
        assert not np.isnan(loss.item()), 'Model diverged with loss = NaN'

        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        losses.update(loss.item(), target.size(0))
        acc.update(get_batch_accuracy(output, target).item(), target.size(0))

        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Time ({batch_time.average:.3f})\t'
                  'Data ({data_time.average:.3f})\t'
                  'Loss ({loss.average:.4f})\t'
                  'Accuracy ({acc.average:.3f})'.format(epoch, i, len(data_loader), batch_time=batch_time, data_time=data_time, loss=losses, acc=acc))

    return losses.average, acc.average


def evaluate(model, device, data_loader, criterion, print_freq=10):
    batch_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    acc = MyAverageGenerator()

    results = []

    model.eval()

    with torch.no_grad():
        end = time.time()
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)
            target = target.to(device)

            output = model(input)
            loss = criterion(output, target)

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            losses.update(loss.item(), target.size(0))
            acc.update(get_batch_accuracy(output, target).item(), target.size(0))

            y_true = target.detach().to('cpu').numpy().tolist()
            y_pred = output.detach().to('cpu').max(1)[1].numpy().tolist()
            results.extend(list(zip(y_true, y_pred)))

            if i % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                      'Time ({batch_time.average:.3f})\t'
                      'Loss ({loss.average:.4f})\t'
                      'Accuracy ({acc.average:.3f})'.format(i, len(data_loader), batch_time=batch_time, loss=losses, acc=acc))

    return losses.average, acc.average, results

# %%
torch.manual_seed(0)
NUM_EPOCHS = 20
BATCH_SIZE = 32
USE_CUDA = False
NUM_WORKERS = 0

# %%
num_features = get_num_features(train_seqs)

train_dataset = MyDataset(train_seqs, train_labels, num_features)
valid_dataset = MyDataset(valid_seqs, valid_labels, num_features)
test_dataset = MyDataset(test_seqs, test_labels, num_features)

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=NUM_WORKERS)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)
# batch_size for the test set should be 1 to avoid sorting each mini-batch which breaks the connection with patient IDs
test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)

# %%
model = MyNet(num_features)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

device = torch.device("cuda" if torch.cuda.is_available() and USE_CUDA else "cpu")
model.to(device)
criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
best_val_acc = 0.0
train_losses, train_accuracies = [], []
valid_losses, valid_accuracies = [], []
for epoch in range(NUM_EPOCHS):
    train_loss, train_accuracy = train(model, device, train_loader, criterion, optimizer, epoch)
    valid_loss, valid_accuracy, valid_results = evaluate(model, device, valid_loader, criterion)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    train_accuracies.append(train_accuracy)
    valid_accuracies.append(valid_accuracy)

    is_best = valid_accuracy > best_val_acc  # keep the best model
    if is_best:
        best_val_acc = valid_accuracy
        torch.save(model, os.path.join(PATH_OUTPUT, "MyNet.pth"))
# Out:
# Epoch: [0][0/132]	Time (0.091)	Data (0.055)	Loss (0.7093)	Accuracy (40.625)
# Epoch: [0][10/132]	Time (0.032)	Data (0.020)	Loss (0.7070)	Accuracy (38.068)
# Epoch: [0][20/132]	Time (0.027)	Data (0.016)	Loss (0.7065)	Accuracy (38.690)
# Epoch: [0][30/132]	Time (0.025)	Data (0.015)	Loss (0.7057)	Accuracy (38.206)
# Epoch: [0][40/132]	Time (0.024)	Data (0.014)	Loss (0.7049)	Accuracy (38.720)
# Epoch: [0][50/132]	Time (0.023)	Data (0.014)	Loss (0.7036)	Accuracy (39.583)
# Epoch: [0][60/132]	Time (0.024)	Data (0.014)	Loss (0.7025)	Accuracy (40.318)
# Epoch: [0][70/132]	Time (0.023)	Data (0.014)	Loss (0.7013)	Accuracy (41.769)
# Epoch: [0][80/132]	Time (0.023)	Data (0.014)	Loss (0.7003)	Accuracy (43.017)
# Epoch: [0][90/132]	Time (0.023)	Data (0.014)	Loss (0.6992)	Accuracy (44.265)
# Epoch: [0][100/132]	Time (0.023)	Data (0.014)	Loss (0.6981)	Accuracy (45.421)
# Epoch: [0][110/132]	Time (0.023)	Data (0.014)	Loss (0.6969)	Accuracy (46.340)
# Epoch: [0][120/132]	Time (0.023)	Data (0.014)	Loss (0.6958)	Accuracy (47.340)
# Epoch: [0][130/132]	Time (0.023)	Data (0.014)	Loss (0.6948)	Accuracy (48.378)
# Test: [0/24]	Time (0.017)	Loss (0.6966)	Accuracy (56.250)
# Test: [10/24]	Time (0.016)	Loss (0.6862)	Accuracy (61.364)
# Test: [20/24]	Time (0.015)	Loss (0.6830)	Accuracy (62.054)
# Epoch: [1][0/132]	Time (0.038)	Data (0.017)	Loss (0.6969)	Accuracy (68.750)
# Epoch: [1][10/132]	Time (0.025)	Data (0.015)	Loss (0.6874)	Accuracy (57.955)
# Epoch: [1][20/132]	Time (0.024)	Data (0.014)	Loss (0.6817)	Accuracy (61.012)
# Epoch: [1][30/132]	Time (0.023)	Data (0.014)	Loss (0.6795)	Accuracy (61.492)
# Epoch: [1][40/132]	Time (0.023)	Data (0.014)	Loss (0.6776)	Accuracy (62.652)
# Epoch: [1][50/132]	Time (0.024)	Data (0.015)	Loss (0.6771)	Accuracy (62.623)
# Epoch: [1][60/132]	Time (0.024)	Data (0.014)	Loss (0.6754)	Accuracy (62.807)
# Epoch: [1][70/132]	Time (0.024)	Data (0.014)	Loss (0.6766)	Accuracy (62.280)
# Epoch: [1][80/132]	Time (0.023)	Data (0.014)	Loss (0.6770)	Accuracy (61.921)
# Epoch: [1][90/132]	Time (0.023)	Data (0.014)	Loss (0.6767)	Accuracy (61.779)
# Epoch: [1][100/132]	Time (0.024)	Data (0.014)	Loss (0.6759)	Accuracy (62.129)
# Epoch: [1][110/132]	Time (0.024)	Data (0.014)	Loss (0.6747)	Accuracy (62.416)
# Epoch: [1][120/132]	Time (0.024)	Data (0.014)	Loss (0.6744)	Accuracy (62.319)
# Epoch: [1][130/132]	Time (0.024)	Data (0.014)	Loss (0.6729)	Accuracy (62.762)
# Test: [0/24]	Time (0.017)	Loss (0.6917)	Accuracy (56.250)
# Test: [10/24]	Time (0.017)	Loss (0.6721)	Accuracy (61.364)
# Test: [20/24]	Time (0.018)	Loss (0.6657)	Accuracy (62.054)
# Epoch: [2][0/132]	Time (0.027)	Data (0.016)	Loss (0.6361)	Accuracy (65.625)
# Epoch: [2][10/132]	Time (0.021)	Data (0.012)	Loss (0.6659)	Accuracy (60.511)
# Epoch: [2][20/132]	Time (0.019)	Data (0.012)	Loss (0.6647)	Accuracy (61.756)
# Epoch: [2][30/132]	Time (0.021)	Data (0.012)	Loss (0.6640)	Accuracy (62.198)
# Epoch: [2][40/132]	Time (0.022)	Data (0.013)	Loss (0.6598)	Accuracy (63.110)
# Epoch: [2][50/132]	Time (0.021)	Data (0.013)	Loss (0.6578)	Accuracy (63.664)
# Epoch: [2][60/132]	Time (0.022)	Data (0.013)	Loss (0.6571)	Accuracy (63.934)
# Epoch: [2][70/132]	Time (0.022)	Data (0.013)	Loss (0.6602)	Accuracy (62.984)
# Epoch: [2][80/132]	Time (0.022)	Data (0.013)	Loss (0.6586)	Accuracy (63.079)
# Epoch: [2][90/132]	Time (0.023)	Data (0.014)	Loss (0.6581)	Accuracy (62.981)
# Epoch: [2][100/132]	Time (0.022)	Data (0.013)	Loss (0.6582)	Accuracy (62.655)
# Epoch: [2][110/132]	Time (0.022)	Data (0.013)	Loss (0.6562)	Accuracy (62.922)
# Epoch: [2][120/132]	Time (0.022)	Data (0.013)	Loss (0.6550)	Accuracy (63.068)
# Epoch: [2][130/132]	Time (0.022)	Data (0.013)	Loss (0.6548)	Accuracy (63.025)
# Test: [0/24]	Time (0.014)	Loss (0.6723)	Accuracy (56.250)
# Test: [10/24]	Time (0.013)	Loss (0.6537)	Accuracy (61.648)
# Test: [20/24]	Time (0.013)	Loss (0.6433)	Accuracy (62.500)
# Epoch: [3][0/132]	Time (0.013)	Data (0.008)	Loss (0.6287)	Accuracy (68.750)
# Epoch: [3][10/132]	Time (0.026)	Data (0.015)	Loss (0.6417)	Accuracy (63.636)
# Epoch: [3][20/132]	Time (0.029)	Data (0.017)	Loss (0.6318)	Accuracy (65.923)
# Epoch: [3][30/132]	Time (0.027)	Data (0.016)	Loss (0.6301)	Accuracy (65.927)
# Epoch: [3][40/132]	Time (0.025)	Data (0.015)	Loss (0.6299)	Accuracy (65.320)
# Epoch: [3][50/132]	Time (0.024)	Data (0.014)	Loss (0.6308)	Accuracy (65.135)
# Epoch: [3][60/132]	Time (0.024)	Data (0.014)	Loss (0.6321)	Accuracy (64.703)
# Epoch: [3][70/132]	Time (0.024)	Data (0.014)	Loss (0.6297)	Accuracy (65.273)
# Epoch: [3][80/132]	Time (0.024)	Data (0.014)	Loss (0.6299)	Accuracy (64.892)
# Epoch: [3][90/132]	Time (0.023)	Data (0.014)	Loss (0.6282)	Accuracy (65.213)
# Epoch: [3][100/132]	Time (0.023)	Data (0.014)	Loss (0.6265)	Accuracy (65.594)
# Epoch: [3][110/132]	Time (0.023)	Data (0.014)	Loss (0.6242)	Accuracy (65.963)
# Epoch: [3][120/132]	Time (0.023)	Data (0.014)	Loss (0.6233)	Accuracy (66.038)
# Epoch: [3][130/132]	Time (0.023)	Data (0.013)	Loss (0.6236)	Accuracy (65.840)
# Test: [0/24]	Time (0.015)	Loss (0.6307)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.6223)	Accuracy (66.193)
# Test: [20/24]	Time (0.014)	Loss (0.6047)	Accuracy (68.304)
# Epoch: [4][0/132]	Time (0.018)	Data (0.010)	Loss (0.5660)	Accuracy (78.125)
# Epoch: [4][10/132]	Time (0.019)	Data (0.011)	Loss (0.5960)	Accuracy (68.182)
# Epoch: [4][20/132]	Time (0.019)	Data (0.011)	Loss (0.5985)	Accuracy (69.792)
# Epoch: [4][30/132]	Time (0.020)	Data (0.012)	Loss (0.5982)	Accuracy (69.052)
# Epoch: [4][40/132]	Time (0.020)	Data (0.012)	Loss (0.5959)	Accuracy (70.122)
# Epoch: [4][50/132]	Time (0.021)	Data (0.013)	Loss (0.5933)	Accuracy (70.833)
# Epoch: [4][60/132]	Time (0.021)	Data (0.013)	Loss (0.5948)	Accuracy (69.826)
# Epoch: [4][70/132]	Time (0.021)	Data (0.013)	Loss (0.5921)	Accuracy (70.202)
# Epoch: [4][80/132]	Time (0.021)	Data (0.013)	Loss (0.5887)	Accuracy (70.255)
# Epoch: [4][90/132]	Time (0.021)	Data (0.013)	Loss (0.5888)	Accuracy (70.089)
# Epoch: [4][100/132]	Time (0.022)	Data (0.013)	Loss (0.5873)	Accuracy (70.421)
# Epoch: [4][110/132]	Time (0.021)	Data (0.013)	Loss (0.5847)	Accuracy (70.805)
# Epoch: [4][120/132]	Time (0.021)	Data (0.013)	Loss (0.5846)	Accuracy (70.790)
# Epoch: [4][130/132]	Time (0.021)	Data (0.013)	Loss (0.5822)	Accuracy (70.945)
# Test: [0/24]	Time (0.014)	Loss (0.5915)	Accuracy (68.750)
# Test: [10/24]	Time (0.013)	Loss (0.5936)	Accuracy (67.898)
# Test: [20/24]	Time (0.013)	Loss (0.5668)	Accuracy (70.536)
# Epoch: [5][0/132]	Time (0.015)	Data (0.009)	Loss (0.5880)	Accuracy (68.750)
# Epoch: [5][10/132]	Time (0.025)	Data (0.015)	Loss (0.5521)	Accuracy (72.727)
# Epoch: [5][20/132]	Time (0.023)	Data (0.013)	Loss (0.5618)	Accuracy (70.982)
# Epoch: [5][30/132]	Time (0.022)	Data (0.013)	Loss (0.5557)	Accuracy (71.270)
# Epoch: [5][40/132]	Time (0.021)	Data (0.013)	Loss (0.5575)	Accuracy (71.875)
# Epoch: [5][50/132]	Time (0.021)	Data (0.013)	Loss (0.5594)	Accuracy (72.059)
# Epoch: [5][60/132]	Time (0.021)	Data (0.012)	Loss (0.5568)	Accuracy (71.926)
# Epoch: [5][70/132]	Time (0.021)	Data (0.012)	Loss (0.5542)	Accuracy (72.667)
# Epoch: [5][80/132]	Time (0.021)	Data (0.013)	Loss (0.5542)	Accuracy (72.917)
# Epoch: [5][90/132]	Time (0.021)	Data (0.013)	Loss (0.5512)	Accuracy (73.146)
# Epoch: [5][100/132]	Time (0.021)	Data (0.013)	Loss (0.5484)	Accuracy (73.391)
# Epoch: [5][110/132]	Time (0.021)	Data (0.013)	Loss (0.5491)	Accuracy (73.395)
# Epoch: [5][120/132]	Time (0.021)	Data (0.013)	Loss (0.5476)	Accuracy (73.683)
# Epoch: [5][130/132]	Time (0.021)	Data (0.013)	Loss (0.5478)	Accuracy (73.473)
# Test: [0/24]	Time (0.015)	Loss (0.5691)	Accuracy (65.625)
# Test: [10/24]	Time (0.015)	Loss (0.5788)	Accuracy (66.477)
# Test: [20/24]	Time (0.014)	Loss (0.5443)	Accuracy (70.238)
# Epoch: [6][0/132]	Time (0.015)	Data (0.009)	Loss (0.6480)	Accuracy (68.750)
# Epoch: [6][10/132]	Time (0.021)	Data (0.013)	Loss (0.5445)	Accuracy (74.432)
# Epoch: [6][20/132]	Time (0.020)	Data (0.013)	Loss (0.5416)	Accuracy (72.917)
# Epoch: [6][30/132]	Time (0.022)	Data (0.013)	Loss (0.5294)	Accuracy (74.093)
# Epoch: [6][40/132]	Time (0.021)	Data (0.013)	Loss (0.5223)	Accuracy (74.848)
# Epoch: [6][50/132]	Time (0.022)	Data (0.013)	Loss (0.5236)	Accuracy (74.877)
# Epoch: [6][60/132]	Time (0.021)	Data (0.013)	Loss (0.5317)	Accuracy (73.822)
# Epoch: [6][70/132]	Time (0.021)	Data (0.013)	Loss (0.5324)	Accuracy (73.768)
# Epoch: [6][80/132]	Time (0.021)	Data (0.013)	Loss (0.5260)	Accuracy (74.267)
# Epoch: [6][90/132]	Time (0.022)	Data (0.013)	Loss (0.5230)	Accuracy (74.691)
# Epoch: [6][100/132]	Time (0.022)	Data (0.013)	Loss (0.5251)	Accuracy (74.381)
# Epoch: [6][110/132]	Time (0.022)	Data (0.013)	Loss (0.5243)	Accuracy (74.409)
# Epoch: [6][120/132]	Time (0.022)	Data (0.013)	Loss (0.5253)	Accuracy (74.458)
# Epoch: [6][130/132]	Time (0.022)	Data (0.013)	Loss (0.5241)	Accuracy (74.571)
# Test: [0/24]	Time (0.015)	Loss (0.5555)	Accuracy (68.750)
# Test: [10/24]	Time (0.015)	Loss (0.5716)	Accuracy (67.898)
# Test: [20/24]	Time (0.014)	Loss (0.5321)	Accuracy (70.982)
# Epoch: [7][0/132]	Time (0.018)	Data (0.010)	Loss (0.5381)	Accuracy (78.125)
# Epoch: [7][10/132]	Time (0.020)	Data (0.012)	Loss (0.5028)	Accuracy (75.568)
# Epoch: [7][20/132]	Time (0.023)	Data (0.013)	Loss (0.5163)	Accuracy (74.107)
# Epoch: [7][30/132]	Time (0.022)	Data (0.013)	Loss (0.5106)	Accuracy (75.000)
# Epoch: [7][40/132]	Time (0.022)	Data (0.013)	Loss (0.5007)	Accuracy (76.372)
# Epoch: [7][50/132]	Time (0.022)	Data (0.013)	Loss (0.5040)	Accuracy (76.287)
# Epoch: [7][60/132]	Time (0.021)	Data (0.013)	Loss (0.5030)	Accuracy (76.127)
# Epoch: [7][70/132]	Time (0.021)	Data (0.012)	Loss (0.5083)	Accuracy (75.528)
# Epoch: [7][80/132]	Time (0.022)	Data (0.013)	Loss (0.5088)	Accuracy (75.656)
# Epoch: [7][90/132]	Time (0.021)	Data (0.013)	Loss (0.5090)	Accuracy (75.618)
# Epoch: [7][100/132]	Time (0.021)	Data (0.013)	Loss (0.5081)	Accuracy (75.866)
# Epoch: [7][110/132]	Time (0.022)	Data (0.013)	Loss (0.5038)	Accuracy (76.154)
# Epoch: [7][120/132]	Time (0.022)	Data (0.013)	Loss (0.5028)	Accuracy (76.059)
# Epoch: [7][130/132]	Time (0.022)	Data (0.013)	Loss (0.5043)	Accuracy (75.811)
# Test: [0/24]	Time (0.014)	Loss (0.5516)	Accuracy (68.750)
# Test: [10/24]	Time (0.014)	Loss (0.5691)	Accuracy (68.182)
# Test: [20/24]	Time (0.013)	Loss (0.5272)	Accuracy (71.577)
# Epoch: [8][0/132]	Time (0.016)	Data (0.010)	Loss (0.4378)	Accuracy (84.375)
# Epoch: [8][10/132]	Time (0.019)	Data (0.012)	Loss (0.4791)	Accuracy (79.261)
# Epoch: [8][20/132]	Time (0.019)	Data (0.011)	Loss (0.4855)	Accuracy (77.530)
# Epoch: [8][30/132]	Time (0.019)	Data (0.012)	Loss (0.5033)	Accuracy (76.915)
# Epoch: [8][40/132]	Time (0.020)	Data (0.012)	Loss (0.4982)	Accuracy (77.287)
# Epoch: [8][50/132]	Time (0.021)	Data (0.013)	Loss (0.5008)	Accuracy (76.716)
# Epoch: [8][60/132]	Time (0.021)	Data (0.013)	Loss (0.5023)	Accuracy (76.742)
# Epoch: [8][70/132]	Time (0.022)	Data (0.013)	Loss (0.5009)	Accuracy (76.496)
# Epoch: [8][80/132]	Time (0.022)	Data (0.013)	Loss (0.5025)	Accuracy (76.620)
# Epoch: [8][90/132]	Time (0.021)	Data (0.013)	Loss (0.5030)	Accuracy (76.614)
# Epoch: [8][100/132]	Time (0.021)	Data (0.013)	Loss (0.4997)	Accuracy (76.547)
# Epoch: [8][110/132]	Time (0.021)	Data (0.013)	Loss (0.4991)	Accuracy (76.295)
# Epoch: [8][120/132]	Time (0.021)	Data (0.012)	Loss (0.4956)	Accuracy (76.498)
# Epoch: [8][130/132]	Time (0.021)	Data (0.012)	Loss (0.4917)	Accuracy (76.670)
# Test: [0/24]	Time (0.014)	Loss (0.5466)	Accuracy (71.875)
# Test: [10/24]	Time (0.013)	Loss (0.5671)	Accuracy (70.170)
# Test: [20/24]	Time (0.013)	Loss (0.5243)	Accuracy (72.470)
# Epoch: [9][0/132]	Time (0.015)	Data (0.009)	Loss (0.4543)	Accuracy (78.125)
# Epoch: [9][10/132]	Time (0.022)	Data (0.013)	Loss (0.5004)	Accuracy (75.000)
# Epoch: [9][20/132]	Time (0.021)	Data (0.013)	Loss (0.4880)	Accuracy (76.339)
# Epoch: [9][30/132]	Time (0.020)	Data (0.012)	Loss (0.4922)	Accuracy (76.109)
# Epoch: [9][40/132]	Time (0.020)	Data (0.012)	Loss (0.4958)	Accuracy (76.143)
# Epoch: [9][50/132]	Time (0.019)	Data (0.012)	Loss (0.4911)	Accuracy (76.900)
# Epoch: [9][60/132]	Time (0.019)	Data (0.012)	Loss (0.4900)	Accuracy (76.998)
# Epoch: [9][70/132]	Time (0.020)	Data (0.012)	Loss (0.4867)	Accuracy (77.245)
# Epoch: [9][80/132]	Time (0.020)	Data (0.012)	Loss (0.4849)	Accuracy (77.469)
# Epoch: [9][90/132]	Time (0.020)	Data (0.012)	Loss (0.4815)	Accuracy (77.610)
# Epoch: [9][100/132]	Time (0.020)	Data (0.012)	Loss (0.4813)	Accuracy (77.661)
# Epoch: [9][110/132]	Time (0.021)	Data (0.012)	Loss (0.4784)	Accuracy (77.815)
# Epoch: [9][120/132]	Time (0.021)	Data (0.013)	Loss (0.4767)	Accuracy (77.944)
# Epoch: [9][130/132]	Time (0.021)	Data (0.013)	Loss (0.4814)	Accuracy (77.624)
# Test: [0/24]	Time (0.016)	Loss (0.5462)	Accuracy (68.750)
# Test: [10/24]	Time (0.014)	Loss (0.5657)	Accuracy (71.591)
# Test: [20/24]	Time (0.013)	Loss (0.5243)	Accuracy (73.810)
# Epoch: [10][0/132]	Time (0.047)	Data (0.028)	Loss (0.4312)	Accuracy (84.375)
# Epoch: [10][10/132]	Time (0.022)	Data (0.013)	Loss (0.4714)	Accuracy (76.989)
# Epoch: [10][20/132]	Time (0.021)	Data (0.013)	Loss (0.5073)	Accuracy (75.149)
# Epoch: [10][30/132]	Time (0.020)	Data (0.012)	Loss (0.4993)	Accuracy (74.698)
# Epoch: [10][40/132]	Time (0.022)	Data (0.013)	Loss (0.4791)	Accuracy (76.601)
# Epoch: [10][50/132]	Time (0.021)	Data (0.013)	Loss (0.4759)	Accuracy (76.777)
# Epoch: [10][60/132]	Time (0.022)	Data (0.013)	Loss (0.4838)	Accuracy (76.639)
# Epoch: [10][70/132]	Time (0.022)	Data (0.013)	Loss (0.4764)	Accuracy (77.113)
# Epoch: [10][80/132]	Time (0.022)	Data (0.013)	Loss (0.4717)	Accuracy (77.662)
# Epoch: [10][90/132]	Time (0.022)	Data (0.013)	Loss (0.4693)	Accuracy (77.919)
# Epoch: [10][100/132]	Time (0.022)	Data (0.013)	Loss (0.4679)	Accuracy (78.001)
# Epoch: [10][110/132]	Time (0.022)	Data (0.013)	Loss (0.4697)	Accuracy (77.787)
# Epoch: [10][120/132]	Time (0.021)	Data (0.013)	Loss (0.4705)	Accuracy (77.738)
# Epoch: [10][130/132]	Time (0.021)	Data (0.013)	Loss (0.4738)	Accuracy (77.624)
# Test: [0/24]	Time (0.015)	Loss (0.5453)	Accuracy (68.750)
# Test: [10/24]	Time (0.014)	Loss (0.5650)	Accuracy (70.170)
# Test: [20/24]	Time (0.013)	Loss (0.5236)	Accuracy (73.363)
# Epoch: [11][0/132]	Time (0.015)	Data (0.008)	Loss (0.5236)	Accuracy (78.125)
# Epoch: [11][10/132]	Time (0.019)	Data (0.011)	Loss (0.4537)	Accuracy (81.534)
# Epoch: [11][20/132]	Time (0.020)	Data (0.012)	Loss (0.4622)	Accuracy (79.911)
# Epoch: [11][30/132]	Time (0.020)	Data (0.012)	Loss (0.4412)	Accuracy (80.746)
# Epoch: [11][40/132]	Time (0.020)	Data (0.012)	Loss (0.4497)	Accuracy (80.107)
# Epoch: [11][50/132]	Time (0.020)	Data (0.012)	Loss (0.4524)	Accuracy (79.596)
# Epoch: [11][60/132]	Time (0.021)	Data (0.013)	Loss (0.4569)	Accuracy (79.559)
# Epoch: [11][70/132]	Time (0.022)	Data (0.013)	Loss (0.4592)	Accuracy (79.357)
# Epoch: [11][80/132]	Time (0.022)	Data (0.013)	Loss (0.4632)	Accuracy (78.974)
# Epoch: [11][90/132]	Time (0.022)	Data (0.013)	Loss (0.4684)	Accuracy (78.503)
# Epoch: [11][100/132]	Time (0.021)	Data (0.013)	Loss (0.4695)	Accuracy (78.280)
# Epoch: [11][110/132]	Time (0.021)	Data (0.013)	Loss (0.4711)	Accuracy (78.209)
# Epoch: [11][120/132]	Time (0.021)	Data (0.013)	Loss (0.4691)	Accuracy (78.383)
# Epoch: [11][130/132]	Time (0.021)	Data (0.013)	Loss (0.4659)	Accuracy (78.674)
# Test: [0/24]	Time (0.013)	Loss (0.5571)	Accuracy (65.625)
# Test: [10/24]	Time (0.013)	Loss (0.5664)	Accuracy (70.170)
# Test: [20/24]	Time (0.013)	Loss (0.5277)	Accuracy (73.363)
# Epoch: [12][0/132]	Time (0.016)	Data (0.009)	Loss (0.4517)	Accuracy (75.000)
# Epoch: [12][10/132]	Time (0.020)	Data (0.012)	Loss (0.4600)	Accuracy (80.114)
# Epoch: [12][20/132]	Time (0.020)	Data (0.012)	Loss (0.4689)	Accuracy (79.018)
# Epoch: [12][30/132]	Time (0.022)	Data (0.013)	Loss (0.4681)	Accuracy (79.032)
# Epoch: [12][40/132]	Time (0.021)	Data (0.013)	Loss (0.4568)	Accuracy (79.345)
# Epoch: [12][50/132]	Time (0.021)	Data (0.013)	Loss (0.4550)	Accuracy (79.534)
# Epoch: [12][60/132]	Time (0.020)	Data (0.012)	Loss (0.4503)	Accuracy (79.816)
# Epoch: [12][70/132]	Time (0.020)	Data (0.012)	Loss (0.4472)	Accuracy (80.194)
# Epoch: [12][80/132]	Time (0.020)	Data (0.012)	Loss (0.4618)	Accuracy (78.974)
# Epoch: [12][90/132]	Time (0.021)	Data (0.012)	Loss (0.4633)	Accuracy (78.812)
# Epoch: [12][100/132]	Time (0.021)	Data (0.013)	Loss (0.4616)	Accuracy (78.960)
# Epoch: [12][110/132]	Time (0.021)	Data (0.013)	Loss (0.4571)	Accuracy (79.167)
# Epoch: [12][120/132]	Time (0.021)	Data (0.013)	Loss (0.4578)	Accuracy (79.390)
# Epoch: [12][130/132]	Time (0.022)	Data (0.013)	Loss (0.4582)	Accuracy (79.318)
# Test: [0/24]	Time (0.016)	Loss (0.5487)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.5645)	Accuracy (69.602)
# Test: [20/24]	Time (0.014)	Loss (0.5241)	Accuracy (72.917)
# Epoch: [13][0/132]	Time (0.018)	Data (0.012)	Loss (0.4189)	Accuracy (78.125)
# Epoch: [13][10/132]	Time (0.021)	Data (0.013)	Loss (0.4441)	Accuracy (80.114)
# Epoch: [13][20/132]	Time (0.020)	Data (0.012)	Loss (0.4420)	Accuracy (79.911)
# Epoch: [13][30/132]	Time (0.020)	Data (0.012)	Loss (0.4471)	Accuracy (79.234)
# Epoch: [13][40/132]	Time (0.021)	Data (0.012)	Loss (0.4481)	Accuracy (79.421)
# Epoch: [13][50/132]	Time (0.022)	Data (0.013)	Loss (0.4526)	Accuracy (79.657)
# Epoch: [13][60/132]	Time (0.022)	Data (0.013)	Loss (0.4484)	Accuracy (79.918)
# Epoch: [13][70/132]	Time (0.022)	Data (0.013)	Loss (0.4494)	Accuracy (79.798)
# Epoch: [13][80/132]	Time (0.022)	Data (0.013)	Loss (0.4507)	Accuracy (79.745)
# Epoch: [13][90/132]	Time (0.022)	Data (0.013)	Loss (0.4525)	Accuracy (79.361)
# Epoch: [13][100/132]	Time (0.022)	Data (0.013)	Loss (0.4558)	Accuracy (79.177)
# Epoch: [13][110/132]	Time (0.023)	Data (0.013)	Loss (0.4527)	Accuracy (79.392)
# Epoch: [13][120/132]	Time (0.023)	Data (0.014)	Loss (0.4543)	Accuracy (79.236)
# Epoch: [13][130/132]	Time (0.023)	Data (0.014)	Loss (0.4533)	Accuracy (79.389)
# Test: [0/24]	Time (0.012)	Loss (0.5616)	Accuracy (62.500)
# Test: [10/24]	Time (0.014)	Loss (0.5644)	Accuracy (69.318)
# Test: [20/24]	Time (0.014)	Loss (0.5266)	Accuracy (72.768)
# Epoch: [14][0/132]	Time (0.028)	Data (0.018)	Loss (0.4749)	Accuracy (78.125)
# Epoch: [14][10/132]	Time (0.029)	Data (0.017)	Loss (0.4522)	Accuracy (79.830)
# Epoch: [14][20/132]	Time (0.024)	Data (0.015)	Loss (0.4719)	Accuracy (78.274)
# Epoch: [14][30/132]	Time (0.026)	Data (0.016)	Loss (0.4471)	Accuracy (80.343)
# Epoch: [14][40/132]	Time (0.025)	Data (0.015)	Loss (0.4610)	Accuracy (79.573)
# Epoch: [14][50/132]	Time (0.026)	Data (0.015)	Loss (0.4592)	Accuracy (79.596)
# Epoch: [14][60/132]	Time (0.026)	Data (0.015)	Loss (0.4534)	Accuracy (79.918)
# Epoch: [14][70/132]	Time (0.026)	Data (0.015)	Loss (0.4501)	Accuracy (80.370)
# Epoch: [14][80/132]	Time (0.027)	Data (0.015)	Loss (0.4519)	Accuracy (80.093)
# Epoch: [14][90/132]	Time (0.029)	Data (0.017)	Loss (0.4519)	Accuracy (80.082)
# Epoch: [14][100/132]	Time (0.029)	Data (0.017)	Loss (0.4565)	Accuracy (79.796)
# Epoch: [14][110/132]	Time (0.028)	Data (0.016)	Loss (0.4518)	Accuracy (79.983)
# Epoch: [14][120/132]	Time (0.028)	Data (0.016)	Loss (0.4533)	Accuracy (79.959)
# Epoch: [14][130/132]	Time (0.027)	Data (0.016)	Loss (0.4508)	Accuracy (80.081)
# Test: [0/24]	Time (0.015)	Loss (0.5674)	Accuracy (62.500)
# Test: [10/24]	Time (0.023)	Loss (0.5648)	Accuracy (70.170)
# Test: [20/24]	Time (0.020)	Loss (0.5286)	Accuracy (73.214)
# Epoch: [15][0/132]	Time (0.043)	Data (0.026)	Loss (0.2871)	Accuracy (93.750)
# Epoch: [15][10/132]	Time (0.024)	Data (0.015)	Loss (0.4500)	Accuracy (79.545)
# Epoch: [15][20/132]	Time (0.027)	Data (0.017)	Loss (0.4475)	Accuracy (80.804)
# Epoch: [15][30/132]	Time (0.031)	Data (0.020)	Loss (0.4417)	Accuracy (80.141)
# Epoch: [15][40/132]	Time (0.028)	Data (0.018)	Loss (0.4536)	Accuracy (80.183)
# Epoch: [15][50/132]	Time (0.027)	Data (0.016)	Loss (0.4608)	Accuracy (79.473)
# Epoch: [15][60/132]	Time (0.026)	Data (0.016)	Loss (0.4625)	Accuracy (79.355)
# Epoch: [15][70/132]	Time (0.025)	Data (0.015)	Loss (0.4643)	Accuracy (79.445)
# Epoch: [15][80/132]	Time (0.025)	Data (0.016)	Loss (0.4597)	Accuracy (79.861)
# Epoch: [15][90/132]	Time (0.025)	Data (0.015)	Loss (0.4595)	Accuracy (79.842)
# Epoch: [15][100/132]	Time (0.025)	Data (0.015)	Loss (0.4514)	Accuracy (80.074)
# Epoch: [15][110/132]	Time (0.025)	Data (0.015)	Loss (0.4505)	Accuracy (79.955)
# Epoch: [15][120/132]	Time (0.024)	Data (0.015)	Loss (0.4469)	Accuracy (80.165)
# Epoch: [15][130/132]	Time (0.025)	Data (0.015)	Loss (0.4452)	Accuracy (80.296)
# Test: [0/24]	Time (0.015)	Loss (0.5669)	Accuracy (65.625)
# Test: [10/24]	Time (0.030)	Loss (0.5648)	Accuracy (71.023)
# Test: [20/24]	Time (0.022)	Loss (0.5277)	Accuracy (73.810)
# Epoch: [16][0/132]	Time (0.026)	Data (0.016)	Loss (0.4116)	Accuracy (81.250)
# Epoch: [16][10/132]	Time (0.026)	Data (0.016)	Loss (0.4378)	Accuracy (82.386)
# Epoch: [16][20/132]	Time (0.024)	Data (0.014)	Loss (0.4584)	Accuracy (80.804)
# Epoch: [16][30/132]	Time (0.022)	Data (0.013)	Loss (0.4546)	Accuracy (81.048)
# Epoch: [16][40/132]	Time (0.022)	Data (0.013)	Loss (0.4430)	Accuracy (81.250)
# Epoch: [16][50/132]	Time (0.023)	Data (0.014)	Loss (0.4346)	Accuracy (81.373)
# Epoch: [16][60/132]	Time (0.023)	Data (0.014)	Loss (0.4314)	Accuracy (81.250)
# Epoch: [16][70/132]	Time (0.023)	Data (0.014)	Loss (0.4270)	Accuracy (81.514)
# Epoch: [16][80/132]	Time (0.023)	Data (0.014)	Loss (0.4289)	Accuracy (81.173)
# Epoch: [16][90/132]	Time (0.023)	Data (0.014)	Loss (0.4345)	Accuracy (80.701)
# Epoch: [16][100/132]	Time (0.023)	Data (0.014)	Loss (0.4446)	Accuracy (80.229)
# Epoch: [16][110/132]	Time (0.023)	Data (0.014)	Loss (0.4448)	Accuracy (80.208)
# Epoch: [16][120/132]	Time (0.023)	Data (0.014)	Loss (0.4446)	Accuracy (80.191)
# Epoch: [16][130/132]	Time (0.023)	Data (0.014)	Loss (0.4412)	Accuracy (80.320)
# Test: [0/24]	Time (0.012)	Loss (0.5760)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.5664)	Accuracy (71.307)
# Test: [20/24]	Time (0.013)	Loss (0.5297)	Accuracy (74.107)
# Epoch: [17][0/132]	Time (0.019)	Data (0.013)	Loss (0.4412)	Accuracy (78.125)
# Epoch: [17][10/132]	Time (0.019)	Data (0.012)	Loss (0.4436)	Accuracy (81.534)
# Epoch: [17][20/132]	Time (0.023)	Data (0.014)	Loss (0.4242)	Accuracy (81.845)
# Epoch: [17][30/132]	Time (0.032)	Data (0.020)	Loss (0.4233)	Accuracy (81.956)
# Epoch: [17][40/132]	Time (0.035)	Data (0.020)	Loss (0.4254)	Accuracy (81.784)
# Epoch: [17][50/132]	Time (0.033)	Data (0.019)	Loss (0.4254)	Accuracy (81.250)
# Epoch: [17][60/132]	Time (0.032)	Data (0.018)	Loss (0.4275)	Accuracy (81.557)
# Epoch: [17][70/132]	Time (0.030)	Data (0.017)	Loss (0.4252)	Accuracy (81.734)
# Epoch: [17][80/132]	Time (0.031)	Data (0.018)	Loss (0.4235)	Accuracy (81.867)
# Epoch: [17][90/132]	Time (0.033)	Data (0.019)	Loss (0.4251)	Accuracy (81.559)
# Epoch: [17][100/132]	Time (0.032)	Data (0.018)	Loss (0.4261)	Accuracy (81.405)
# Epoch: [17][110/132]	Time (0.032)	Data (0.018)	Loss (0.4262)	Accuracy (81.363)
# Epoch: [17][120/132]	Time (0.031)	Data (0.018)	Loss (0.4285)	Accuracy (80.863)
# Epoch: [17][130/132]	Time (0.030)	Data (0.017)	Loss (0.4359)	Accuracy (80.630)
# Test: [0/24]	Time (0.014)	Loss (0.5893)	Accuracy (65.625)
# Test: [10/24]	Time (0.013)	Loss (0.5689)	Accuracy (70.739)
# Test: [20/24]	Time (0.014)	Loss (0.5334)	Accuracy (73.512)
# Epoch: [18][0/132]	Time (0.016)	Data (0.010)	Loss (0.3719)	Accuracy (81.250)
# Epoch: [18][10/132]	Time (0.027)	Data (0.016)	Loss (0.4607)	Accuracy (77.557)
# Epoch: [18][20/132]	Time (0.024)	Data (0.014)	Loss (0.4604)	Accuracy (78.125)
# Epoch: [18][30/132]	Time (0.022)	Data (0.013)	Loss (0.4658)	Accuracy (78.730)
# Epoch: [18][40/132]	Time (0.021)	Data (0.013)	Loss (0.4465)	Accuracy (79.878)
# Epoch: [18][50/132]	Time (0.021)	Data (0.013)	Loss (0.4432)	Accuracy (80.208)
# Epoch: [18][60/132]	Time (0.022)	Data (0.013)	Loss (0.4502)	Accuracy (79.816)
# Epoch: [18][70/132]	Time (0.022)	Data (0.013)	Loss (0.4432)	Accuracy (80.062)
# Epoch: [18][80/132]	Time (0.022)	Data (0.013)	Loss (0.4400)	Accuracy (80.401)
# Epoch: [18][90/132]	Time (0.021)	Data (0.013)	Loss (0.4390)	Accuracy (80.254)
# Epoch: [18][100/132]	Time (0.021)	Data (0.013)	Loss (0.4403)	Accuracy (80.322)
# Epoch: [18][110/132]	Time (0.022)	Data (0.013)	Loss (0.4359)	Accuracy (80.349)
# Epoch: [18][120/132]	Time (0.021)	Data (0.013)	Loss (0.4357)	Accuracy (80.243)
# Epoch: [18][130/132]	Time (0.021)	Data (0.013)	Loss (0.4333)	Accuracy (80.415)
# Test: [0/24]	Time (0.013)	Loss (0.5945)	Accuracy (65.625)
# Test: [10/24]	Time (0.015)	Loss (0.5697)	Accuracy (70.739)
# Test: [20/24]	Time (0.014)	Loss (0.5351)	Accuracy (73.661)
# Epoch: [19][0/132]	Time (0.024)	Data (0.014)	Loss (0.2691)	Accuracy (90.625)
# Epoch: [19][10/132]	Time (0.019)	Data (0.012)	Loss (0.4284)	Accuracy (80.682)
# Epoch: [19][20/132]	Time (0.020)	Data (0.012)	Loss (0.4331)	Accuracy (80.506)
# Epoch: [19][30/132]	Time (0.020)	Data (0.012)	Loss (0.4338)	Accuracy (80.343)
# Epoch: [19][40/132]	Time (0.020)	Data (0.012)	Loss (0.4243)	Accuracy (80.793)
# Epoch: [19][50/132]	Time (0.021)	Data (0.012)	Loss (0.4265)	Accuracy (80.699)
# Epoch: [19][60/132]	Time (0.021)	Data (0.013)	Loss (0.4274)	Accuracy (80.891)
# Epoch: [19][70/132]	Time (0.021)	Data (0.013)	Loss (0.4280)	Accuracy (81.074)
# Epoch: [19][80/132]	Time (0.022)	Data (0.013)	Loss (0.4299)	Accuracy (80.980)
# Epoch: [19][90/132]	Time (0.021)	Data (0.013)	Loss (0.4300)	Accuracy (81.181)
# Epoch: [19][100/132]	Time (0.022)	Data (0.013)	Loss (0.4253)	Accuracy (81.559)
# Epoch: [19][110/132]	Time (0.021)	Data (0.013)	Loss (0.4266)	Accuracy (81.447)
# Epoch: [19][120/132]	Time (0.021)	Data (0.013)	Loss (0.4263)	Accuracy (81.612)
# Epoch: [19][130/132]	Time (0.021)	Data (0.013)	Loss (0.4277)	Accuracy (81.322)
# Test: [0/24]	Time (0.020)	Loss (0.5895)	Accuracy (65.625)
# Test: [10/24]	Time (0.015)	Loss (0.5716)	Accuracy (70.170)
# Test: [20/24]	Time (0.014)	Loss (0.5360)	Accuracy (73.512)

# %% [markdown]
# ## 5. Plot best model

# %%
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, title):
    print("*****************************Plot learning curves*********************")
    x = len(train_losses)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_losses, label = "train_losses")
    plt.plot(x, valid_losses, label = "valid_losses" )
    plt.title("Loss Curve")
    plt.xlabel("epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(title + "_loss_curve.png")
    plt.show()

    print("*****************************Plot accuracy curves*********************")
    x = len(valid_accuracies)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_accuracies, label = "train_accuracies")
    plt.plot(x, valid_accuracies, label = "valid_accuracies")
    plt.title("Accuracy Curve")
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.savefig(title + "_acc_curve.png")
    plt.show()


def plot_confusion_matrix(results, class_names, title):
    print("*****************************Plot confusion maxtrix*********************")
    y_true, y_pred = zip(*results)
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=class_names, yticklabels=class_names,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha='center', va='center', color='white' if cm[i, j] > thresh else 'black')
    fig.tight_layout()
    plt.savefig(title + "_cm.png")
    plt.show()

# %%
best_model = torch.load(os.path.join(PATH_OUTPUT, "MyNet.pth"))
plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot learning curves*********************
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %% [markdown]
# ![loss curve](./figs/MyNet_loss_curve.png)
#
#
# ![accuracy curve](./figs/MyNet_acc_curve.png)

# %%
class_names = ['Live','Death']
plot_confusion_matrix(valid_results, class_names, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot confusion maxtrix*********************
# [[0.6360424  0.3639576 ]
#  [0.18471338 0.81528662]]

# %% [markdown]
# - Precision: 0.64
# - Recall: 0.78

# %% [markdown]
# ![confusion matrix](./figs/MyNet_cm.png)

# %% [markdown]
# ## 6. Predict

# %%
def predict_mortality(model, device, data_loader):
    model.eval()
    model.to(device)
    probas = []
    trues = []
    with torch.no_grad():
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)

            output = model(input)
            output = nn.Sigmoid()(output)

            if output[0][0] < output[0][1]:
                probas.append(1)
            else:
                probas.append(0)
            trues.append(target)
    acc = accuracy_score(trues, probas)
    print('The accuracy of test dataset is {}'.format(acc))
    return probas


test_prob = predict_mortality(best_model, device, test_loader)
# Out:
# The accuracy of test dataset is 0.7469194312796209

# %%
def make_report(list_id, list_prob, path):
    if len(list_id) != len(list_prob):
        raise AttributeError("ID list and Probability list have different lengths")

    os.makedirs(path, exist_ok=True)
    output_file = open(os.path.join(path, 'my_predictions.csv'), 'w')
    output_file.write("SUBJECT_ID,MORTALITY\n")
    for pid, prob in zip(list_id, list_prob):
        output_file.write("{},{}\n".format(pid, prob))
    output_file.close()

# %%
make_report(test_ids, test_prob, PATH_OUTPUT)
num_test_patient = len(test_ids)

# %%
num_test_patient
# Out:
# 1055
