# %%
import os
import pickle
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

PATH_DATA = "./data/mortality/data/"
PATH_VALIDATION = "./data/mortality/validation/"
PATH_OUTPUT = "./output/"

# %% [markdown]
# # Data Overview
#
# - Data source: MIMIC-III https://mimic.physionet.org/

# %%
df_mortality = pd.read_csv(os.path.join(PATH_DATA, "MORTALITY.csv"))
df_admissions = pd.read_csv(os.path.join(PATH_DATA, "ADMISSIONS.csv"))
df_diagnoses = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"))

# %%
df_mortality.head()
# Out:
#    SUBJECT_ID  MORTALITY
# 0         252          1
# 1         721          1
# 2         776          1
# 3         801          0
# 4         822          1

# %%
df_admissions.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 1      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 2      33          34   115799  2186-07-18 16:46:00  2186-07-20 16:00:00
# 3      34          34   144319  2191-02-23 05:23:00  2191-02-25 20:20:00
# 4      36          36   182104  2131-04-30 07:15:00  2131-05-08 14:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION DISCHARGE_LOCATION  \
# 0       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE
# 1       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
# 3       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
# 4       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
#
#   INSURANCE LANGUAGE       RELIGION MARITAL_STATUS ETHNICITY  \
# 0  Medicare      NaN       CATHOLIC        MARRIED     WHITE
# 1  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 2  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 3  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 4  Medicare     ENGL  NOT SPECIFIED        MARRIED     WHITE
#
#              EDREGTIME            EDOUTTIME  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3  2191-02-23 04:23:00  2191-02-23 07:25:00
# 4                  NaN                  NaN
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 1                                         BRAIN MASS                     0
# 2                                    CHEST PAIN\CATH                     0
# 3                                        BRADYCARDIA                     0
# 4  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
df_diagnoses.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1523         117   140784      1.0      5715
# 1    1524         117   140784      2.0      7895
# 2    1525         117   140784      3.0     07054
# 3    1526         117   140784      4.0      2875
# 4    1527         117   140784      5.0      4280

# %% [markdown]
# # Data processing
#
# ## Build original dataset
#
# - `extract_code`
#  - follow ICD-9-CM format (https://www.cms.gov/Medicare/Quality-Initiatives-Patient-Assessment-Instruments/HospitalQualityInits/Downloads/HospitalAppendix_F.pdf) to extract main digits of ICD-9 code
#
#
# - `build_dict`
#  - create corresponding id map for ICD9_code, {main digits of ICD9: unique feature ID}
#
#
# - `build_dataset`
#  - group the diagnosis codes for the same visit
#  - group the visits for same patient
#  - make visit lists for paitents with chronological order
#  - return: List(patient IDs), List(labels), Visit sequence data as a List of List of List.

# %%
def extract_code(icd9_object):

    icd9_str = str(icd9_object)
    if icd9_str[0] == 'E': icd9_str = icd9_str[0:4]
    else: icd9_str = icd9_str[0:3]
    
    return icd9_str

# %%
def build_dict(df_icd9, extract_func):

    unique_code = df_icd9['ICD9_CODE'].apply(extract_func).unique()
    unique_code = pd.Series(unique_code).sort_values()
    code_dict = dict(zip(unique_code, range(len(unique_code))))
    
    return code_dict

# %%
def build_dataset(path, code_dict, extract_func):

    df_mortality = pd.read_csv(os.path.join(path, "MORTALITY.csv"))
    df_admissions = pd.read_csv(os.path.join(path, "ADMISSIONS.csv"))
    df_diagnoses = pd.read_csv(os.path.join(path, "DIAGNOSES_ICD.csv"))
    
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].apply(extract_func)
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].map(code_dict)
    df_joined = df_admissions.merge(df_diagnoses, on=['HADM_ID', 'SUBJECT_ID'])
    df_patient_admittee_ICD9 = df_joined[['SUBJECT_ID', 'ADMITTIME','ICD9_CODE']]
    
    patient_ids = []
    labels = []
    seq_data = []
    
    for name1, d in df_patient_admittee_ICD9.groupby('SUBJECT_ID'):
        patient_ids.append(name1)
        labels.extend(list(df_mortality["MORTALITY"][(df_mortality["SUBJECT_ID"] == name1)]))
        subl = []
        d['ADMITTIME'] = pd.to_datetime(d['ADMITTIME'])
        for name2, subd in d.groupby('ADMITTIME'):
            subl.append(list(subd['ICD9_CODE']))
        seq_data.append(subl)
    
    return patient_ids, labels, seq_data

# %%
print("Build feature id map")
df_icd9 = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"), usecols=["ICD9_CODE"])
code_dict = build_dict(df_icd9, extract_code)

print("Construct train and test set")
ids, labels, seqs = build_dataset(PATH_DATA, code_dict, extract_code)
train_ids, test_ids, train_seqs, test_seqs, train_labels, test_labels = train_test_split(ids, seqs, labels, test_size=0.2)

print("Construct validation set")
valid_ids, valid_labels, valid_seqs = build_dataset(PATH_VALIDATION, code_dict, extract_code)
print("Completed!")
# Out:
# Build feature id map
# Construct train and test set
# Construct validation set
# Completed!

# %%
ids[0:5] # patient IDs
# Out:
# [17, 23, 34, 36, 61]

# %%
labels[0:5] # mortality
# Out:
# [1, 1, 1, 1, 0]

# %%
seqs[0:5] # unique feature id
# Out:
# [[[545, 336, 854, 171], [303, 375, 582, 336, 210, 525, 522, 171]],
#  [[296, 293, 304, 872, 171, 287, 451, 279],
#   [132, 242, 577, 304, 287, 171, 171, 872, 872, 857]],
#  [[292, 308, 305, 307, 746, 306, 296, 782],
#   [307, 308, 306, 296, 881, 308, 148, 258]],
#  [[296, 293, 367, 287, 204, 393, 451, 852, 447],
#   [747, 747, 297, 331, 745, 367, 296, 872, 287, 451, 393, 852],
#   [408, 297, 382, 358, 746, 382, 296, 367, 287, 451, 199, 852]],
#  [[113, 187, 186, 429, 184, 164, 748, 430, 498],
#   [113,
#    183,
#    745,
#    420,
#    418,
#    175,
#    16,
#    744,
#    175,
#    595,
#    43,
#    175,
#    336,
#    307,
#    157,
#    245,
#    34]]]

# %% [markdown]
# ## Custom Pytorch Dataset
#
# For each patient, I decided to use a matrix, rows represent different visits, jth column show the integer feature ID j. If matrix[i][j] == 1, it means that on ith visit, we get feature ID j.

# %%
# for each row, get the number of feature id.
def get_num_features(seqs):

    def get_flatten_list(ori_list, flatten_list = None):
        if flatten_list is None: flatten_list = []
        for i in ori_list:
            if isinstance(i, list): get_flatten_list(i, flatten_list)
            else: flatten_list.append(i)
        return flatten_list

    def get_max(list1):
        tmp = -1
        for i in list1:
            if i > tmp: tmp = i
        return tmp
    
    l = get_flatten_list(seqs)
    return get_max(l) + 1

# %%
# inherit from Dataset, represent matrixs.
class MyDataset(Dataset):
    def __init__(self, seqs, labels, num_features):

        self.labels = labels
        self.seqs = []
        def isNaN(num):
            return num != num
        for seq in seqs:
            new_seq = []
            for visit in seq:
                new_visit = [0] * int(num_features)
                for i in visit:
                    if not isNaN(i): new_visit[int(i)] = 1
                new_visit = np.asarray(new_visit)
                new_seq.append(new_visit)
            new_seq = np.asarray(new_seq)
            self.seqs.append(new_seq)
            
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # returns will be wrapped as List of Tensor(s) by DataLoader
        return self.seqs[index], self.labels[index]

# %% [markdown]
# ## Generate mini-batches represented by 3D Tensor
#
# Generate mini-batches by defining `collate_fn` which is an argument of DataLoader constructor.
#
# - mini-batches: batch_size * max_length * num_features
#
# - If matrice in same batch have different number of rows, I will padding them with zero rows.

# %%
def collate_fn(batch):

    def getKey(item):
        return item[1]
    
    new_tuples = []
    seqs = []
    labels = []
    lengths = []
    max_length = -1
    num_features = len(batch[0][0][0])
    
    for b in batch:
        b_seqs = b[0]
        tmp_list = [b_seqs, len(b_seqs), b[1]]
        new_tuples.append(tuple(tmp_list))
        if len(b_seqs) > max_length:
            max_length = len(b_seqs)
    batch = sorted(new_tuples, key = getKey, reverse=True)
    
    for b in batch:
        b_seqs = b[0]
        labels.append(b[2])
        lengths.append(b[1])
        b_seqs = list(b_seqs)
        while len(b_seqs) < max_length:
            b_seqs.append([0] * num_features)
        seqs.append(torch.Tensor(b_seqs))
    seqs_tensor = torch.stack(seqs, 0)
    lengths_tensor = torch.LongTensor(lengths)
    labels_tensor = torch.LongTensor(labels)

    return (seqs_tensor, lengths_tensor), labels_tensor

# %% [markdown]
# # Build RNN model
#
#
# - Only need to define the forward function, the backward function will be generate automatically

# %%
class MyNet(nn.Module):
    def __init__(self, dim_input):
        super(MyNet, self).__init__()
        self.fc1 = nn.Linear(dim_input, 32)
        self.fc2 = nn.Linear(16, 2)
        self.rnn = nn.GRU(input_size=32, hidden_size=16, num_layers=2, batch_first=True, dropout=0.5, bidirectional=False)
        self.tanh = nn.Tanh()

    def forward(self, input_tuple):
        seqs, lengths = input_tuple
        seqs = self.fc1(seqs)
        seqs = F.tanh(seqs)
        seqs = pack_padded_sequence(seqs, lengths, batch_first=True)
        seqs, _ = self.rnn(seqs)
        seqs, _ = pad_packed_sequence(seqs, batch_first=True)
        new_seqs = []
        for i in range(0, len(seqs)):
            new_seqs.append(seqs[i][lengths[i] - 1])
        new_seqs = torch.stack(new_seqs, 0)
        seqs = self.fc2(new_seqs)
        return seqs

# %% [markdown]
# # Training and validation process

# %%
import os
import time

class MyAverageGenerator():
    def __init__(self):
        self.val = 0
        self.average = 0
        self.sum = 0
        self.count = 0

    def update(self, val, size = 1):
        self.val = val
        self.sum += val * size
        self.count += size
        self.average = self.sum / self.count
        
def get_batch_accuracy(output, target):
    
    with torch.no_grad():

        batch_size = target.size(0)
        _, pred = output.max(1)
        correct = pred.eq(target).sum()

        return correct * 100.0 / batch_size
    
def train(model, device, data_loader, criterion, optimizer, epoch, print_freq=10):
    batch_time = MyAverageGenerator()
    data_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    accuracy = MyAverageGenerator()

    model.train()

    end = time.time()
    for i, (input, target) in enumerate(data_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        if isinstance(input, tuple):
            input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
        else:
            input = input.to(device)
        target = target.to(device)

        optimizer.zero_grad()
        output = model(input)
        loss = criterion(output, target)
        assert not np.isnan(loss.item()), 'Model diverged with loss = NaN'

        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        losses.update(loss.item(), target.size(0))
        accuracy.update(get_batch_accuracy(output, target).item(), target.size(0))

        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Time ({batch_time.average:.3f})\t'
                  'Data ({data_time.average:.3f})\t'
                  'Loss ({loss.average:.4f})\t'
                  'Accuracy ({acc.average:.3f})'.format(
                epoch, i, len(data_loader), batch_time=batch_time,
                data_time=data_time, loss=losses, acc=accuracy))

    return losses.average, accuracy.average


def evaluate(model, device, data_loader, criterion, print_freq=10):
    batch_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    accuracy = MyAverageGenerator()

    results = []

    model.eval()

    with torch.no_grad():
        end = time.time()
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)
            target = target.to(device)

            output = model(input)
            loss = criterion(output, target)

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            losses.update(loss.item(), target.size(0))
            accuracy.update(get_batch_accuracy(output, target).item(), target.size(0))

            y_true = target.detach().to('cpu').numpy().tolist()
            y_pred = output.detach().to('cpu').max(1)[1].numpy().tolist()
            results.extend(list(zip(y_true, y_pred)))

            if i % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                      'Time ({batch_time.average:.3f})\t'
                      'Loss ({loss.average:.4f})\t'
                      'Accuracy ({acc.average:.3f})'.format(
                    i, len(data_loader), batch_time=batch_time, loss=losses, acc=accuracy))

    return losses.average, accuracy.average, results

# %%
torch.manual_seed(0)
NUM_EPOCHS = 20
BATCH_SIZE = 32
USE_CUDA = False
NUM_WORKERS = 0

# %%
num_features = get_num_features(train_seqs)

train_dataset = MyDataset(train_seqs, train_labels, num_features)
valid_dataset = MyDataset(valid_seqs, valid_labels, num_features)
test_dataset = MyDataset(test_seqs, test_labels, num_features)

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=NUM_WORKERS)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)
# batch_size for the test set should be 1 to avoid sorting each mini-batch which breaks the connection with patient IDs
test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)

# %%
model = MyNet(num_features)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

device = torch.device("cuda" if torch.cuda.is_available() and USE_CUDA else "cpu")
model.to(device)
criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
best_val_acc = 0.0
train_losses, train_accuracies = [], []
valid_losses, valid_accuracies = [], []
for epoch in range(NUM_EPOCHS):
    train_loss, train_accuracy = train(model, device, train_loader, criterion, optimizer, epoch)
    valid_loss, valid_accuracy, valid_results = evaluate(model, device, valid_loader, criterion)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    train_accuracies.append(train_accuracy)
    valid_accuracies.append(valid_accuracy)

    is_best = valid_accuracy > best_val_acc  # let's keep the model that has the best accuracy, but you can also use another metric.
    if is_best:
        best_val_acc = valid_accuracy
        torch.save(model, os.path.join(PATH_OUTPUT, "MyNet.pth"))
# Out:
# Epoch: [0][0/132]	Time (0.069)	Data (0.042)	Loss (0.7251)	Accuracy (28.125)
# Epoch: [0][10/132]	Time (0.024)	Data (0.014)	Loss (0.7093)	Accuracy (37.500)
# Epoch: [0][20/132]	Time (0.023)	Data (0.014)	Loss (0.7063)	Accuracy (38.542)
# Epoch: [0][30/132]	Time (0.022)	Data (0.013)	Loss (0.7065)	Accuracy (37.903)
# Epoch: [0][40/132]	Time (0.021)	Data (0.013)	Loss (0.7049)	Accuracy (38.872)
# Epoch: [0][50/132]	Time (0.021)	Data (0.013)	Loss (0.7045)	Accuracy (38.971)
# Epoch: [0][60/132]	Time (0.021)	Data (0.013)	Loss (0.7036)	Accuracy (39.908)
# Epoch: [0][70/132]	Time (0.021)	Data (0.013)	Loss (0.7028)	Accuracy (40.537)
# Epoch: [0][80/132]	Time (0.021)	Data (0.013)	Loss (0.7017)	Accuracy (41.898)
# Epoch: [0][90/132]	Time (0.021)	Data (0.013)	Loss (0.7009)	Accuracy (42.617)
# Epoch: [0][100/132]	Time (0.022)	Data (0.014)	Loss (0.7002)	Accuracy (43.564)
# Epoch: [0][110/132]	Time (0.022)	Data (0.014)	Loss (0.6993)	Accuracy (44.679)
# Epoch: [0][120/132]	Time (0.022)	Data (0.013)	Loss (0.6985)	Accuracy (45.661)
# Epoch: [0][130/132]	Time (0.022)	Data (0.013)	Loss (0.6976)	Accuracy (46.517)
# Test: [0/24]	Time (0.015)	Loss (0.6952)	Accuracy (59.375)
# Test: [10/24]	Time (0.014)	Loss (0.6873)	Accuracy (62.216)
# Test: [20/24]	Time (0.013)	Loss (0.6844)	Accuracy (62.649)
# Epoch: [1][0/132]	Time (0.063)	Data (0.035)	Loss (0.7009)	Accuracy (46.875)
# Epoch: [1][10/132]	Time (0.028)	Data (0.017)	Loss (0.6894)	Accuracy (55.966)
# Epoch: [1][20/132]	Time (0.024)	Data (0.014)	Loss (0.6850)	Accuracy (59.077)
# Epoch: [1][30/132]	Time (0.023)	Data (0.014)	Loss (0.6863)	Accuracy (57.460)
# Epoch: [1][40/132]	Time (0.022)	Data (0.014)	Loss (0.6837)	Accuracy (58.994)
# Epoch: [1][50/132]	Time (0.022)	Data (0.014)	Loss (0.6825)	Accuracy (59.804)
# Epoch: [1][60/132]	Time (0.023)	Data (0.014)	Loss (0.6807)	Accuracy (60.348)
# Epoch: [1][70/132]	Time (0.022)	Data (0.013)	Loss (0.6800)	Accuracy (60.695)
# Epoch: [1][80/132]	Time (0.022)	Data (0.013)	Loss (0.6789)	Accuracy (60.880)
# Epoch: [1][90/132]	Time (0.022)	Data (0.013)	Loss (0.6781)	Accuracy (61.229)
# Epoch: [1][100/132]	Time (0.022)	Data (0.013)	Loss (0.6761)	Accuracy (61.757)
# Epoch: [1][110/132]	Time (0.022)	Data (0.013)	Loss (0.6765)	Accuracy (61.318)
# Epoch: [1][120/132]	Time (0.022)	Data (0.013)	Loss (0.6759)	Accuracy (61.312)
# Epoch: [1][130/132]	Time (0.022)	Data (0.013)	Loss (0.6750)	Accuracy (61.546)
# Test: [0/24]	Time (0.023)	Loss (0.6908)	Accuracy (56.250)
# Test: [10/24]	Time (0.017)	Loss (0.6725)	Accuracy (61.364)
# Test: [20/24]	Time (0.015)	Loss (0.6665)	Accuracy (62.054)
# Epoch: [2][0/132]	Time (0.029)	Data (0.018)	Loss (0.6500)	Accuracy (62.500)
# Epoch: [2][10/132]	Time (0.021)	Data (0.013)	Loss (0.6562)	Accuracy (65.909)
# Epoch: [2][20/132]	Time (0.022)	Data (0.013)	Loss (0.6621)	Accuracy (64.137)
# Epoch: [2][30/132]	Time (0.022)	Data (0.013)	Loss (0.6605)	Accuracy (64.113)
# Epoch: [2][40/132]	Time (0.021)	Data (0.013)	Loss (0.6630)	Accuracy (63.491)
# Epoch: [2][50/132]	Time (0.021)	Data (0.012)	Loss (0.6622)	Accuracy (63.174)
# Epoch: [2][60/132]	Time (0.022)	Data (0.013)	Loss (0.6618)	Accuracy (62.961)
# Epoch: [2][70/132]	Time (0.023)	Data (0.013)	Loss (0.6624)	Accuracy (62.588)
# Epoch: [2][80/132]	Time (0.022)	Data (0.013)	Loss (0.6623)	Accuracy (62.423)
# Epoch: [2][90/132]	Time (0.023)	Data (0.013)	Loss (0.6615)	Accuracy (62.534)
# Epoch: [2][100/132]	Time (0.023)	Data (0.014)	Loss (0.6607)	Accuracy (62.376)
# Epoch: [2][110/132]	Time (0.023)	Data (0.014)	Loss (0.6590)	Accuracy (62.641)
# Epoch: [2][120/132]	Time (0.022)	Data (0.013)	Loss (0.6581)	Accuracy (62.836)
# Epoch: [2][130/132]	Time (0.023)	Data (0.014)	Loss (0.6571)	Accuracy (62.858)
# Test: [0/24]	Time (0.015)	Loss (0.6732)	Accuracy (56.250)
# Test: [10/24]	Time (0.014)	Loss (0.6544)	Accuracy (61.648)
# Test: [20/24]	Time (0.013)	Loss (0.6444)	Accuracy (62.351)
# Epoch: [3][0/132]	Time (0.018)	Data (0.010)	Loss (0.6758)	Accuracy (53.125)
# Epoch: [3][10/132]	Time (0.020)	Data (0.012)	Loss (0.6566)	Accuracy (58.523)
# Epoch: [3][20/132]	Time (0.020)	Data (0.012)	Loss (0.6434)	Accuracy (62.054)
# Epoch: [3][30/132]	Time (0.021)	Data (0.013)	Loss (0.6447)	Accuracy (61.290)
# Epoch: [3][40/132]	Time (0.021)	Data (0.013)	Loss (0.6421)	Accuracy (62.271)
# Epoch: [3][50/132]	Time (0.021)	Data (0.013)	Loss (0.6416)	Accuracy (62.132)
# Epoch: [3][60/132]	Time (0.021)	Data (0.013)	Loss (0.6395)	Accuracy (63.064)
# Epoch: [3][70/132]	Time (0.021)	Data (0.013)	Loss (0.6371)	Accuracy (63.688)
# Epoch: [3][80/132]	Time (0.021)	Data (0.013)	Loss (0.6343)	Accuracy (64.198)
# Epoch: [3][90/132]	Time (0.021)	Data (0.013)	Loss (0.6324)	Accuracy (64.595)
# Epoch: [3][100/132]	Time (0.021)	Data (0.013)	Loss (0.6308)	Accuracy (65.006)
# Epoch: [3][110/132]	Time (0.021)	Data (0.013)	Loss (0.6302)	Accuracy (64.893)
# Epoch: [3][120/132]	Time (0.021)	Data (0.013)	Loss (0.6276)	Accuracy (65.238)
# Epoch: [3][130/132]	Time (0.022)	Data (0.013)	Loss (0.6261)	Accuracy (65.506)
# Test: [0/24]	Time (0.015)	Loss (0.6355)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.6239)	Accuracy (66.477)
# Test: [20/24]	Time (0.013)	Loss (0.6069)	Accuracy (68.304)
# Epoch: [4][0/132]	Time (0.022)	Data (0.012)	Loss (0.6022)	Accuracy (71.875)
# Epoch: [4][10/132]	Time (0.023)	Data (0.013)	Loss (0.5768)	Accuracy (74.716)
# Epoch: [4][20/132]	Time (0.022)	Data (0.013)	Loss (0.5771)	Accuracy (72.321)
# Epoch: [4][30/132]	Time (0.021)	Data (0.013)	Loss (0.5840)	Accuracy (71.069)
# Epoch: [4][40/132]	Time (0.021)	Data (0.013)	Loss (0.5916)	Accuracy (69.741)
# Epoch: [4][50/132]	Time (0.021)	Data (0.013)	Loss (0.5883)	Accuracy (70.221)
# Epoch: [4][60/132]	Time (0.021)	Data (0.013)	Loss (0.5899)	Accuracy (70.184)
# Epoch: [4][70/132]	Time (0.021)	Data (0.013)	Loss (0.5894)	Accuracy (70.290)
# Epoch: [4][80/132]	Time (0.021)	Data (0.013)	Loss (0.5902)	Accuracy (69.985)
# Epoch: [4][90/132]	Time (0.021)	Data (0.013)	Loss (0.5902)	Accuracy (69.986)
# Epoch: [4][100/132]	Time (0.022)	Data (0.013)	Loss (0.5889)	Accuracy (70.328)
# Epoch: [4][110/132]	Time (0.022)	Data (0.013)	Loss (0.5895)	Accuracy (70.439)
# Epoch: [4][120/132]	Time (0.022)	Data (0.013)	Loss (0.5883)	Accuracy (70.455)
# Epoch: [4][130/132]	Time (0.023)	Data (0.014)	Loss (0.5867)	Accuracy (70.468)
# Test: [0/24]	Time (0.015)	Loss (0.5901)	Accuracy (65.625)
# Test: [10/24]	Time (0.013)	Loss (0.5928)	Accuracy (67.898)
# Test: [20/24]	Time (0.013)	Loss (0.5670)	Accuracy (70.387)
# Epoch: [5][0/132]	Time (0.030)	Data (0.018)	Loss (0.5151)	Accuracy (78.125)
# Epoch: [5][10/132]	Time (0.024)	Data (0.015)	Loss (0.5447)	Accuracy (77.273)
# Epoch: [5][20/132]	Time (0.030)	Data (0.017)	Loss (0.5439)	Accuracy (75.744)
# Epoch: [5][30/132]	Time (0.029)	Data (0.017)	Loss (0.5560)	Accuracy (73.790)
# Epoch: [5][40/132]	Time (0.027)	Data (0.016)	Loss (0.5600)	Accuracy (73.095)
# Epoch: [5][50/132]	Time (0.027)	Data (0.016)	Loss (0.5583)	Accuracy (72.794)
# Epoch: [5][60/132]	Time (0.026)	Data (0.015)	Loss (0.5592)	Accuracy (72.285)
# Epoch: [5][70/132]	Time (0.026)	Data (0.015)	Loss (0.5633)	Accuracy (71.919)
# Epoch: [5][80/132]	Time (0.026)	Data (0.015)	Loss (0.5613)	Accuracy (71.952)
# Epoch: [5][90/132]	Time (0.027)	Data (0.016)	Loss (0.5587)	Accuracy (72.493)
# Epoch: [5][100/132]	Time (0.026)	Data (0.015)	Loss (0.5575)	Accuracy (72.339)
# Epoch: [5][110/132]	Time (0.026)	Data (0.015)	Loss (0.5563)	Accuracy (72.213)
# Epoch: [5][120/132]	Time (0.026)	Data (0.015)	Loss (0.5539)	Accuracy (72.392)
# Epoch: [5][130/132]	Time (0.026)	Data (0.015)	Loss (0.5526)	Accuracy (72.615)
# Test: [0/24]	Time (0.022)	Loss (0.5744)	Accuracy (65.625)
# Test: [10/24]	Time (0.016)	Loss (0.5785)	Accuracy (69.886)
# Test: [20/24]	Time (0.015)	Loss (0.5450)	Accuracy (71.875)
# Epoch: [6][0/132]	Time (0.026)	Data (0.014)	Loss (0.4430)	Accuracy (78.125)
# Epoch: [6][10/132]	Time (0.026)	Data (0.015)	Loss (0.5041)	Accuracy (75.568)
# Epoch: [6][20/132]	Time (0.026)	Data (0.015)	Loss (0.5155)	Accuracy (75.149)
# Epoch: [6][30/132]	Time (0.024)	Data (0.014)	Loss (0.5216)	Accuracy (74.093)
# Epoch: [6][40/132]	Time (0.025)	Data (0.015)	Loss (0.5197)	Accuracy (74.466)
# Epoch: [6][50/132]	Time (0.024)	Data (0.014)	Loss (0.5210)	Accuracy (74.571)
# Epoch: [6][60/132]	Time (0.024)	Data (0.014)	Loss (0.5203)	Accuracy (74.129)
# Epoch: [6][70/132]	Time (0.024)	Data (0.014)	Loss (0.5204)	Accuracy (73.812)
# Epoch: [6][80/132]	Time (0.023)	Data (0.014)	Loss (0.5243)	Accuracy (73.688)
# Epoch: [6][90/132]	Time (0.023)	Data (0.013)	Loss (0.5227)	Accuracy (73.970)
# Epoch: [6][100/132]	Time (0.023)	Data (0.013)	Loss (0.5248)	Accuracy (73.917)
# Epoch: [6][110/132]	Time (0.022)	Data (0.013)	Loss (0.5258)	Accuracy (73.677)
# Epoch: [6][120/132]	Time (0.022)	Data (0.013)	Loss (0.5254)	Accuracy (74.019)
# Epoch: [6][130/132]	Time (0.022)	Data (0.013)	Loss (0.5238)	Accuracy (74.022)
# Test: [0/24]	Time (0.019)	Loss (0.5610)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.5710)	Accuracy (69.034)
# Test: [20/24]	Time (0.014)	Loss (0.5314)	Accuracy (71.875)
# Epoch: [7][0/132]	Time (0.020)	Data (0.012)	Loss (0.5212)	Accuracy (81.250)
# Epoch: [7][10/132]	Time (0.023)	Data (0.014)	Loss (0.4963)	Accuracy (76.420)
# Epoch: [7][20/132]	Time (0.021)	Data (0.013)	Loss (0.5143)	Accuracy (75.000)
# Epoch: [7][30/132]	Time (0.020)	Data (0.012)	Loss (0.5071)	Accuracy (75.907)
# Epoch: [7][40/132]	Time (0.020)	Data (0.012)	Loss (0.5015)	Accuracy (76.143)
# Epoch: [7][50/132]	Time (0.020)	Data (0.012)	Loss (0.5042)	Accuracy (76.164)
# Epoch: [7][60/132]	Time (0.022)	Data (0.013)	Loss (0.5109)	Accuracy (75.256)
# Epoch: [7][70/132]	Time (0.022)	Data (0.013)	Loss (0.5134)	Accuracy (75.044)
# Epoch: [7][80/132]	Time (0.022)	Data (0.013)	Loss (0.5115)	Accuracy (75.424)
# Epoch: [7][90/132]	Time (0.022)	Data (0.013)	Loss (0.5132)	Accuracy (75.172)
# Epoch: [7][100/132]	Time (0.021)	Data (0.013)	Loss (0.5133)	Accuracy (75.217)
# Epoch: [7][110/132]	Time (0.021)	Data (0.013)	Loss (0.5122)	Accuracy (75.169)
# Epoch: [7][120/132]	Time (0.021)	Data (0.013)	Loss (0.5111)	Accuracy (75.181)
# Epoch: [7][130/132]	Time (0.021)	Data (0.013)	Loss (0.5111)	Accuracy (75.310)
# Test: [0/24]	Time (0.017)	Loss (0.5522)	Accuracy (68.750)
# Test: [10/24]	Time (0.015)	Loss (0.5669)	Accuracy (68.466)
# Test: [20/24]	Time (0.014)	Loss (0.5245)	Accuracy (72.173)
# Epoch: [8][0/132]	Time (0.013)	Data (0.008)	Loss (0.4499)	Accuracy (81.250)
# Epoch: [8][10/132]	Time (0.024)	Data (0.015)	Loss (0.5005)	Accuracy (75.852)
# Epoch: [8][20/132]	Time (0.023)	Data (0.014)	Loss (0.5120)	Accuracy (74.851)
# Epoch: [8][30/132]	Time (0.023)	Data (0.014)	Loss (0.4986)	Accuracy (75.806)
# Epoch: [8][40/132]	Time (0.022)	Data (0.013)	Loss (0.4972)	Accuracy (75.915)
# Epoch: [8][50/132]	Time (0.022)	Data (0.013)	Loss (0.5015)	Accuracy (75.245)
# Epoch: [8][60/132]	Time (0.021)	Data (0.013)	Loss (0.4957)	Accuracy (75.564)
# Epoch: [8][70/132]	Time (0.021)	Data (0.013)	Loss (0.4964)	Accuracy (75.880)
# Epoch: [8][80/132]	Time (0.021)	Data (0.013)	Loss (0.5003)	Accuracy (75.540)
# Epoch: [8][90/132]	Time (0.021)	Data (0.013)	Loss (0.5008)	Accuracy (75.721)
# Epoch: [8][100/132]	Time (0.021)	Data (0.013)	Loss (0.4995)	Accuracy (75.835)
# Epoch: [8][110/132]	Time (0.021)	Data (0.013)	Loss (0.4968)	Accuracy (76.154)
# Epoch: [8][120/132]	Time (0.021)	Data (0.013)	Loss (0.4976)	Accuracy (76.136)
# Epoch: [8][130/132]	Time (0.022)	Data (0.013)	Loss (0.4970)	Accuracy (76.169)
# Test: [0/24]	Time (0.015)	Loss (0.5554)	Accuracy (65.625)
# Test: [10/24]	Time (0.015)	Loss (0.5650)	Accuracy (69.602)
# Test: [20/24]	Time (0.015)	Loss (0.5222)	Accuracy (72.917)
# Epoch: [9][0/132]	Time (0.026)	Data (0.017)	Loss (0.5148)	Accuracy (75.000)
# Epoch: [9][10/132]	Time (0.024)	Data (0.015)	Loss (0.5193)	Accuracy (73.295)
# Epoch: [9][20/132]	Time (0.022)	Data (0.013)	Loss (0.4951)	Accuracy (75.893)
# Epoch: [9][30/132]	Time (0.021)	Data (0.013)	Loss (0.4882)	Accuracy (76.915)
# Epoch: [9][40/132]	Time (0.021)	Data (0.013)	Loss (0.4911)	Accuracy (76.677)
# Epoch: [9][50/132]	Time (0.021)	Data (0.013)	Loss (0.4817)	Accuracy (77.512)
# Epoch: [9][60/132]	Time (0.021)	Data (0.013)	Loss (0.4820)	Accuracy (77.254)
# Epoch: [9][70/132]	Time (0.021)	Data (0.013)	Loss (0.4785)	Accuracy (77.289)
# Epoch: [9][80/132]	Time (0.021)	Data (0.013)	Loss (0.4840)	Accuracy (76.968)
# Epoch: [9][90/132]	Time (0.021)	Data (0.013)	Loss (0.4888)	Accuracy (76.648)
# Epoch: [9][100/132]	Time (0.022)	Data (0.013)	Loss (0.4918)	Accuracy (76.485)
# Epoch: [9][110/132]	Time (0.021)	Data (0.013)	Loss (0.4916)	Accuracy (76.548)
# Epoch: [9][120/132]	Time (0.021)	Data (0.013)	Loss (0.4891)	Accuracy (76.937)
# Epoch: [9][130/132]	Time (0.022)	Data (0.013)	Loss (0.4865)	Accuracy (77.028)
# Test: [0/24]	Time (0.014)	Loss (0.5557)	Accuracy (62.500)
# Test: [10/24]	Time (0.014)	Loss (0.5634)	Accuracy (69.034)
# Test: [20/24]	Time (0.014)	Loss (0.5200)	Accuracy (72.619)
# Epoch: [10][0/132]	Time (0.016)	Data (0.010)	Loss (0.4744)	Accuracy (78.125)
# Epoch: [10][10/132]	Time (0.022)	Data (0.014)	Loss (0.4278)	Accuracy (80.398)
# Epoch: [10][20/132]	Time (0.022)	Data (0.013)	Loss (0.4650)	Accuracy (78.571)
# Epoch: [10][30/132]	Time (0.021)	Data (0.013)	Loss (0.4769)	Accuracy (77.823)
# Epoch: [10][40/132]	Time (0.021)	Data (0.013)	Loss (0.4648)	Accuracy (78.430)
# Epoch: [10][50/132]	Time (0.021)	Data (0.013)	Loss (0.4670)	Accuracy (78.615)
# Epoch: [10][60/132]	Time (0.022)	Data (0.013)	Loss (0.4713)	Accuracy (78.227)
# Epoch: [10][70/132]	Time (0.022)	Data (0.013)	Loss (0.4718)	Accuracy (78.213)
# Epoch: [10][80/132]	Time (0.022)	Data (0.013)	Loss (0.4702)	Accuracy (78.125)
# Epoch: [10][90/132]	Time (0.022)	Data (0.013)	Loss (0.4688)	Accuracy (78.262)
# Epoch: [10][100/132]	Time (0.022)	Data (0.013)	Loss (0.4691)	Accuracy (78.032)
# Epoch: [10][110/132]	Time (0.022)	Data (0.013)	Loss (0.4712)	Accuracy (78.153)
# Epoch: [10][120/132]	Time (0.021)	Data (0.013)	Loss (0.4713)	Accuracy (78.151)
# Epoch: [10][130/132]	Time (0.021)	Data (0.013)	Loss (0.4761)	Accuracy (77.863)
# Test: [0/24]	Time (0.013)	Loss (0.5561)	Accuracy (62.500)
# Test: [10/24]	Time (0.014)	Loss (0.5646)	Accuracy (69.318)
# Test: [20/24]	Time (0.013)	Loss (0.5195)	Accuracy (72.917)
# Epoch: [11][0/132]	Time (0.014)	Data (0.008)	Loss (0.4038)	Accuracy (87.500)
# Epoch: [11][10/132]	Time (0.024)	Data (0.014)	Loss (0.4704)	Accuracy (76.420)
# Epoch: [11][20/132]	Time (0.022)	Data (0.013)	Loss (0.4827)	Accuracy (77.083)
# Epoch: [11][30/132]	Time (0.022)	Data (0.013)	Loss (0.4724)	Accuracy (77.923)
# Epoch: [11][40/132]	Time (0.022)	Data (0.014)	Loss (0.4660)	Accuracy (78.506)
# Epoch: [11][50/132]	Time (0.022)	Data (0.013)	Loss (0.4587)	Accuracy (79.044)
# Epoch: [11][60/132]	Time (0.021)	Data (0.013)	Loss (0.4679)	Accuracy (78.893)
# Epoch: [11][70/132]	Time (0.021)	Data (0.013)	Loss (0.4687)	Accuracy (78.653)
# Epoch: [11][80/132]	Time (0.022)	Data (0.013)	Loss (0.4678)	Accuracy (78.627)
# Epoch: [11][90/132]	Time (0.021)	Data (0.013)	Loss (0.4712)	Accuracy (78.228)
# Epoch: [11][100/132]	Time (0.021)	Data (0.013)	Loss (0.4706)	Accuracy (78.342)
# Epoch: [11][110/132]	Time (0.021)	Data (0.013)	Loss (0.4707)	Accuracy (78.322)
# Epoch: [11][120/132]	Time (0.021)	Data (0.013)	Loss (0.4705)	Accuracy (78.306)
# Epoch: [11][130/132]	Time (0.021)	Data (0.013)	Loss (0.4731)	Accuracy (78.101)
# Test: [0/24]	Time (0.014)	Loss (0.5582)	Accuracy (59.375)
# Test: [10/24]	Time (0.014)	Loss (0.5633)	Accuracy (69.318)
# Test: [20/24]	Time (0.014)	Loss (0.5194)	Accuracy (72.917)
# Epoch: [12][0/132]	Time (0.014)	Data (0.008)	Loss (0.5266)	Accuracy (78.125)
# Epoch: [12][10/132]	Time (0.021)	Data (0.013)	Loss (0.5092)	Accuracy (73.580)
# Epoch: [12][20/132]	Time (0.020)	Data (0.012)	Loss (0.4824)	Accuracy (76.637)
# Epoch: [12][30/132]	Time (0.021)	Data (0.013)	Loss (0.4822)	Accuracy (77.621)
# Epoch: [12][40/132]	Time (0.021)	Data (0.013)	Loss (0.4725)	Accuracy (78.354)
# Epoch: [12][50/132]	Time (0.020)	Data (0.012)	Loss (0.4627)	Accuracy (78.738)
# Epoch: [12][60/132]	Time (0.020)	Data (0.012)	Loss (0.4649)	Accuracy (78.330)
# Epoch: [12][70/132]	Time (0.020)	Data (0.012)	Loss (0.4719)	Accuracy (77.905)
# Epoch: [12][80/132]	Time (0.020)	Data (0.012)	Loss (0.4698)	Accuracy (78.086)
# Epoch: [12][90/132]	Time (0.020)	Data (0.012)	Loss (0.4675)	Accuracy (78.125)
# Epoch: [12][100/132]	Time (0.021)	Data (0.013)	Loss (0.4650)	Accuracy (78.311)
# Epoch: [12][110/132]	Time (0.021)	Data (0.013)	Loss (0.4650)	Accuracy (78.407)
# Epoch: [12][120/132]	Time (0.021)	Data (0.013)	Loss (0.4621)	Accuracy (78.642)
# Epoch: [12][130/132]	Time (0.021)	Data (0.013)	Loss (0.4616)	Accuracy (78.626)
# Test: [0/24]	Time (0.014)	Loss (0.5667)	Accuracy (59.375)
# Test: [10/24]	Time (0.013)	Loss (0.5648)	Accuracy (68.750)
# Test: [20/24]	Time (0.013)	Loss (0.5212)	Accuracy (72.917)
# Epoch: [13][0/132]	Time (0.018)	Data (0.011)	Loss (0.3416)	Accuracy (90.625)
# Epoch: [13][10/132]	Time (0.024)	Data (0.015)	Loss (0.4223)	Accuracy (81.250)
# Epoch: [13][20/132]	Time (0.023)	Data (0.014)	Loss (0.4505)	Accuracy (78.720)
# Epoch: [13][30/132]	Time (0.025)	Data (0.015)	Loss (0.4459)	Accuracy (79.536)
# Epoch: [13][40/132]	Time (0.024)	Data (0.014)	Loss (0.4562)	Accuracy (79.040)
# Epoch: [13][50/132]	Time (0.023)	Data (0.014)	Loss (0.4549)	Accuracy (78.615)
# Epoch: [13][60/132]	Time (0.023)	Data (0.014)	Loss (0.4549)	Accuracy (78.791)
# Epoch: [13][70/132]	Time (0.023)	Data (0.014)	Loss (0.4507)	Accuracy (79.181)
# Epoch: [13][80/132]	Time (0.022)	Data (0.014)	Loss (0.4560)	Accuracy (78.781)
# Epoch: [13][90/132]	Time (0.022)	Data (0.013)	Loss (0.4603)	Accuracy (78.571)
# Epoch: [13][100/132]	Time (0.022)	Data (0.013)	Loss (0.4608)	Accuracy (78.620)
# Epoch: [13][110/132]	Time (0.022)	Data (0.013)	Loss (0.4623)	Accuracy (78.604)
# Epoch: [13][120/132]	Time (0.022)	Data (0.013)	Loss (0.4597)	Accuracy (78.616)
# Epoch: [13][130/132]	Time (0.022)	Data (0.013)	Loss (0.4582)	Accuracy (78.698)
# Test: [0/24]	Time (0.015)	Loss (0.5795)	Accuracy (59.375)
# Test: [10/24]	Time (0.014)	Loss (0.5641)	Accuracy (71.023)
# Test: [20/24]	Time (0.013)	Loss (0.5230)	Accuracy (73.363)
# Epoch: [14][0/132]	Time (0.020)	Data (0.012)	Loss (0.4427)	Accuracy (78.125)
# Epoch: [14][10/132]	Time (0.022)	Data (0.014)	Loss (0.4531)	Accuracy (80.682)
# Epoch: [14][20/132]	Time (0.022)	Data (0.013)	Loss (0.4414)	Accuracy (81.696)
# Epoch: [14][30/132]	Time (0.021)	Data (0.013)	Loss (0.4491)	Accuracy (80.242)
# Epoch: [14][40/132]	Time (0.021)	Data (0.013)	Loss (0.4503)	Accuracy (79.726)
# Epoch: [14][50/132]	Time (0.021)	Data (0.013)	Loss (0.4567)	Accuracy (79.167)
# Epoch: [14][60/132]	Time (0.021)	Data (0.013)	Loss (0.4448)	Accuracy (79.918)
# Epoch: [14][70/132]	Time (0.022)	Data (0.013)	Loss (0.4512)	Accuracy (79.489)
# Epoch: [14][80/132]	Time (0.022)	Data (0.013)	Loss (0.4567)	Accuracy (78.819)
# Epoch: [14][90/132]	Time (0.023)	Data (0.014)	Loss (0.4550)	Accuracy (79.087)
# Epoch: [14][100/132]	Time (0.023)	Data (0.014)	Loss (0.4583)	Accuracy (78.868)
# Epoch: [14][110/132]	Time (0.023)	Data (0.014)	Loss (0.4566)	Accuracy (78.913)
# Epoch: [14][120/132]	Time (0.023)	Data (0.014)	Loss (0.4499)	Accuracy (79.365)
# Epoch: [14][130/132]	Time (0.023)	Data (0.014)	Loss (0.4534)	Accuracy (79.127)
# Test: [0/24]	Time (0.012)	Loss (0.5776)	Accuracy (59.375)
# Test: [10/24]	Time (0.015)	Loss (0.5651)	Accuracy (71.307)
# Test: [20/24]	Time (0.014)	Loss (0.5227)	Accuracy (74.405)
# Epoch: [15][0/132]	Time (0.022)	Data (0.013)	Loss (0.4148)	Accuracy (78.125)
# Epoch: [15][10/132]	Time (0.026)	Data (0.015)	Loss (0.4394)	Accuracy (80.398)
# Epoch: [15][20/132]	Time (0.023)	Data (0.014)	Loss (0.4273)	Accuracy (80.655)
# Epoch: [15][30/132]	Time (0.022)	Data (0.013)	Loss (0.4503)	Accuracy (79.738)
# Epoch: [15][40/132]	Time (0.022)	Data (0.013)	Loss (0.4490)	Accuracy (79.649)
# Epoch: [15][50/132]	Time (0.022)	Data (0.013)	Loss (0.4440)	Accuracy (79.963)
# Epoch: [15][60/132]	Time (0.022)	Data (0.013)	Loss (0.4460)	Accuracy (80.225)
# Epoch: [15][70/132]	Time (0.022)	Data (0.013)	Loss (0.4508)	Accuracy (79.710)
# Epoch: [15][80/132]	Time (0.022)	Data (0.013)	Loss (0.4518)	Accuracy (79.167)
# Epoch: [15][90/132]	Time (0.022)	Data (0.013)	Loss (0.4467)	Accuracy (79.602)
# Epoch: [15][100/132]	Time (0.022)	Data (0.013)	Loss (0.4500)	Accuracy (79.641)
# Epoch: [15][110/132]	Time (0.022)	Data (0.013)	Loss (0.4505)	Accuracy (79.589)
# Epoch: [15][120/132]	Time (0.022)	Data (0.013)	Loss (0.4523)	Accuracy (79.313)
# Epoch: [15][130/132]	Time (0.022)	Data (0.013)	Loss (0.4500)	Accuracy (79.365)
# Test: [0/24]	Time (0.014)	Loss (0.5781)	Accuracy (59.375)
# Test: [10/24]	Time (0.015)	Loss (0.5655)	Accuracy (71.307)
# Test: [20/24]	Time (0.013)	Loss (0.5235)	Accuracy (74.256)
# Epoch: [16][0/132]	Time (0.013)	Data (0.008)	Loss (0.4837)	Accuracy (90.625)
# Epoch: [16][10/132]	Time (0.023)	Data (0.013)	Loss (0.4407)	Accuracy (80.966)
# Epoch: [16][20/132]	Time (0.024)	Data (0.015)	Loss (0.4376)	Accuracy (80.506)
# Epoch: [16][30/132]	Time (0.025)	Data (0.015)	Loss (0.4296)	Accuracy (81.149)
# Epoch: [16][40/132]	Time (0.024)	Data (0.014)	Loss (0.4357)	Accuracy (80.564)
# Epoch: [16][50/132]	Time (0.023)	Data (0.014)	Loss (0.4399)	Accuracy (80.515)
# Epoch: [16][60/132]	Time (0.023)	Data (0.014)	Loss (0.4352)	Accuracy (80.738)
# Epoch: [16][70/132]	Time (0.023)	Data (0.014)	Loss (0.4313)	Accuracy (80.898)
# Epoch: [16][80/132]	Time (0.023)	Data (0.014)	Loss (0.4338)	Accuracy (80.710)
# Epoch: [16][90/132]	Time (0.023)	Data (0.014)	Loss (0.4343)	Accuracy (81.044)
# Epoch: [16][100/132]	Time (0.023)	Data (0.014)	Loss (0.4378)	Accuracy (80.693)
# Epoch: [16][110/132]	Time (0.023)	Data (0.014)	Loss (0.4440)	Accuracy (80.039)
# Epoch: [16][120/132]	Time (0.023)	Data (0.014)	Loss (0.4424)	Accuracy (80.191)
# Epoch: [16][130/132]	Time (0.023)	Data (0.014)	Loss (0.4460)	Accuracy (79.795)
# Test: [0/24]	Time (0.016)	Loss (0.5957)	Accuracy (56.250)
# Test: [10/24]	Time (0.015)	Loss (0.5669)	Accuracy (69.886)
# Test: [20/24]	Time (0.013)	Loss (0.5259)	Accuracy (73.512)
# Epoch: [17][0/132]	Time (0.015)	Data (0.009)	Loss (0.5550)	Accuracy (75.000)
# Epoch: [17][10/132]	Time (0.022)	Data (0.013)	Loss (0.4380)	Accuracy (79.261)
# Epoch: [17][20/132]	Time (0.021)	Data (0.013)	Loss (0.4488)	Accuracy (78.423)
# Epoch: [17][30/132]	Time (0.022)	Data (0.013)	Loss (0.4374)	Accuracy (79.940)
# Epoch: [17][40/132]	Time (0.024)	Data (0.015)	Loss (0.4376)	Accuracy (79.649)
# Epoch: [17][50/132]	Time (0.024)	Data (0.014)	Loss (0.4475)	Accuracy (78.922)
# Epoch: [17][60/132]	Time (0.024)	Data (0.014)	Loss (0.4411)	Accuracy (79.150)
# Epoch: [17][70/132]	Time (0.024)	Data (0.015)	Loss (0.4435)	Accuracy (79.181)
# Epoch: [17][80/132]	Time (0.024)	Data (0.014)	Loss (0.4408)	Accuracy (79.167)
# Epoch: [17][90/132]	Time (0.024)	Data (0.014)	Loss (0.4381)	Accuracy (79.464)
# Epoch: [17][100/132]	Time (0.024)	Data (0.014)	Loss (0.4376)	Accuracy (79.579)
# Epoch: [17][110/132]	Time (0.023)	Data (0.014)	Loss (0.4415)	Accuracy (79.420)
# Epoch: [17][120/132]	Time (0.023)	Data (0.014)	Loss (0.4438)	Accuracy (79.468)
# Epoch: [17][130/132]	Time (0.024)	Data (0.014)	Loss (0.4418)	Accuracy (79.771)
# Test: [0/24]	Time (0.013)	Loss (0.5954)	Accuracy (56.250)
# Test: [10/24]	Time (0.016)	Loss (0.5672)	Accuracy (71.023)
# Test: [20/24]	Time (0.015)	Loss (0.5263)	Accuracy (74.256)
# Epoch: [18][0/132]	Time (0.017)	Data (0.010)	Loss (0.5772)	Accuracy (75.000)
# Epoch: [18][10/132]	Time (0.021)	Data (0.013)	Loss (0.4305)	Accuracy (80.398)
# Epoch: [18][20/132]	Time (0.020)	Data (0.012)	Loss (0.4309)	Accuracy (80.208)
# Epoch: [18][30/132]	Time (0.021)	Data (0.013)	Loss (0.4319)	Accuracy (80.242)
# Epoch: [18][40/132]	Time (0.022)	Data (0.013)	Loss (0.4410)	Accuracy (79.726)
# Epoch: [18][50/132]	Time (0.022)	Data (0.013)	Loss (0.4504)	Accuracy (78.983)
# Epoch: [18][60/132]	Time (0.022)	Data (0.013)	Loss (0.4540)	Accuracy (78.381)
# Epoch: [18][70/132]	Time (0.021)	Data (0.013)	Loss (0.4563)	Accuracy (78.257)
# Epoch: [18][80/132]	Time (0.021)	Data (0.013)	Loss (0.4552)	Accuracy (78.395)
# Epoch: [18][90/132]	Time (0.021)	Data (0.013)	Loss (0.4513)	Accuracy (78.846)
# Epoch: [18][100/132]	Time (0.021)	Data (0.013)	Loss (0.4523)	Accuracy (78.775)
# Epoch: [18][110/132]	Time (0.021)	Data (0.013)	Loss (0.4472)	Accuracy (79.139)
# Epoch: [18][120/132]	Time (0.021)	Data (0.013)	Loss (0.4448)	Accuracy (79.158)
# Epoch: [18][130/132]	Time (0.021)	Data (0.013)	Loss (0.4405)	Accuracy (79.652)
# Test: [0/24]	Time (0.017)	Loss (0.6023)	Accuracy (56.250)
# Test: [10/24]	Time (0.014)	Loss (0.5689)	Accuracy (71.023)
# Test: [20/24]	Time (0.014)	Loss (0.5286)	Accuracy (73.661)
# Epoch: [19][0/132]	Time (0.014)	Data (0.008)	Loss (0.3904)	Accuracy (81.250)
# Epoch: [19][10/132]	Time (0.021)	Data (0.012)	Loss (0.4112)	Accuracy (80.114)
# Epoch: [19][20/132]	Time (0.021)	Data (0.012)	Loss (0.4353)	Accuracy (79.911)
# Epoch: [19][30/132]	Time (0.021)	Data (0.013)	Loss (0.4295)	Accuracy (79.738)
# Epoch: [19][40/132]	Time (0.021)	Data (0.013)	Loss (0.4228)	Accuracy (80.640)
# Epoch: [19][50/132]	Time (0.021)	Data (0.013)	Loss (0.4289)	Accuracy (80.453)
# Epoch: [19][60/132]	Time (0.021)	Data (0.013)	Loss (0.4379)	Accuracy (79.918)
# Epoch: [19][70/132]	Time (0.021)	Data (0.013)	Loss (0.4367)	Accuracy (79.930)
# Epoch: [19][80/132]	Time (0.022)	Data (0.013)	Loss (0.4371)	Accuracy (80.093)
# Epoch: [19][90/132]	Time (0.023)	Data (0.014)	Loss (0.4443)	Accuracy (79.739)
# Epoch: [19][100/132]	Time (0.022)	Data (0.014)	Loss (0.4406)	Accuracy (80.074)
# Epoch: [19][110/132]	Time (0.022)	Data (0.014)	Loss (0.4392)	Accuracy (79.870)
# Epoch: [19][120/132]	Time (0.022)	Data (0.013)	Loss (0.4384)	Accuracy (79.752)
# Epoch: [19][130/132]	Time (0.022)	Data (0.013)	Loss (0.4357)	Accuracy (79.795)
# Test: [0/24]	Time (0.014)	Loss (0.6063)	Accuracy (56.250)
# Test: [10/24]	Time (0.013)	Loss (0.5706)	Accuracy (70.739)
# Test: [20/24]	Time (0.014)	Loss (0.5299)	Accuracy (73.512)

# %% [markdown]
# # Plot best model

# %%
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, title):
    print("*****************************Plot learning curves*********************")
    x = len(train_losses)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_losses, label = "train_losses")
    plt.plot(x, valid_losses, label = "valid_losses" )
    plt.title("Loss Curve")
    plt.xlabel("epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(title + "_loss_curve.png")
    plt.show()

    print("*****************************Plot accuracy curves*********************")
    x = len(valid_accuracies)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_accuracies, label = "train_accuracies")
    plt.plot(x, valid_accuracies, label = "valid_accuracies")
    plt.title("Accuracy Curve")
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.savefig(title + "_acc_curve.png")
    plt.show()


def plot_confusion_matrix(results, class_names, title):
    print("*****************************Plot confusion maxtrix*********************")
    y_true, y_pred = zip(*results)
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=class_names, yticklabels=class_names,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha='center', va='center', color='white' if cm[i, j] > thresh else 'black')
    fig.tight_layout()
    plt.savefig(title + "_cm.png")
    plt.show()

# %%
best_model = torch.load(os.path.join(PATH_OUTPUT, "MyNet.pth"))
# plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, 'MyNet')
class_names = ['Live','Death']
# plot_confusion_matrix(valid_results, class_names, 'MyNet')

# %% [markdown]
# # Predict

# %%
def predict_mortality(model, device, data_loader):
    model.eval()
    model.to(device)
    probas = []
    trues = []
    with torch.no_grad():
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)

            output = model(input)
            output = nn.Sigmoid()(output)

            if output[0][0] < output[0][1]:
                probas.append(1)
            else:
                probas.append(0)
            trues.append(target)
    acc = accuracy_score(trues, probas)
    print('The accuracy of test dataset is {}'.format(acc))
    return probas


test_prob = predict_mortality(best_model, device, test_loader)
# Out:
# The accuracy of test dataset is 0.7545023696682465

# %%
def make_report(list_id, list_prob, path):
    if len(list_id) != len(list_prob):
        raise AttributeError("ID list and Probability list have different lengths")

    os.makedirs(path, exist_ok=True)
    output_file = open(os.path.join(path, 'my_predictions.csv'), 'w')
    output_file.write("SUBJECT_ID,MORTALITY\n")
    for pid, prob in zip(list_id, list_prob):
        output_file.write("{},{}\n".format(pid, prob))
    output_file.close()

# %%
make_report(test_ids, test_prob, PATH_OUTPUT)
num_test_patient = len(test_ids)

# %%
num_test_patient
# Out:
# 1055
