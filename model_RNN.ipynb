# %%
import os
import pickle
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

PATH_DATA = "./data/mortality/data/"
PATH_VALIDATION = "./data/mortality/validation/"
PATH_OUTPUT = "./output/"

# %% [markdown]
# # Data Overview
#
# - Data source: MIMIC-III https://mimic.physionet.org/

# %%
df_mortality = pd.read_csv(os.path.join(PATH_DATA, "MORTALITY.csv"))
df_admissions = pd.read_csv(os.path.join(PATH_DATA, "ADMISSIONS.csv"))
df_diagnoses = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"))

# %%
df_mortality.head()
# Out:
#    SUBJECT_ID  MORTALITY
# 0         252          1
# 1         721          1
# 2         776          1
# 3         801          0
# 4         822          1

# %%
df_admissions.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 1      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 2      33          34   115799  2186-07-18 16:46:00  2186-07-20 16:00:00
# 3      34          34   144319  2191-02-23 05:23:00  2191-02-25 20:20:00
# 4      36          36   182104  2131-04-30 07:15:00  2131-05-08 14:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION DISCHARGE_LOCATION  \
# 0       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE
# 1       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
# 3       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
# 4       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
#
#   INSURANCE LANGUAGE       RELIGION MARITAL_STATUS ETHNICITY  \
# 0  Medicare      NaN       CATHOLIC        MARRIED     WHITE
# 1  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 2  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 3  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 4  Medicare     ENGL  NOT SPECIFIED        MARRIED     WHITE
#
#              EDREGTIME            EDOUTTIME  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3  2191-02-23 04:23:00  2191-02-23 07:25:00
# 4                  NaN                  NaN
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 1                                         BRAIN MASS                     0
# 2                                    CHEST PAIN\CATH                     0
# 3                                        BRADYCARDIA                     0
# 4  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
df_diagnoses.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1523         117   140784      1.0      5715
# 1    1524         117   140784      2.0      7895
# 2    1525         117   140784      3.0     07054
# 3    1526         117   140784      4.0      2875
# 4    1527         117   140784      5.0      4280

# %% [markdown]
# # Data processing
#
# ## Build original dataset
#
# - `extract_code`
#  - follow ICD-9-CM format (https://www.cms.gov/Medicare/Quality-Initiatives-Patient-Assessment-Instruments/HospitalQualityInits/Downloads/HospitalAppendix_F.pdf) to extract main digits of ICD-9 code
#
#
# - `build_dict`
#  - create corresponding id map for ICD9_code, {main digits of ICD9: unique feature ID}
#
#
# - `build_dataset`
#  - group the diagnosis codes for the same visit
#  - group the visits for same patient
#  - make visit lists for paitents with chronological order
#  - return: List(patient IDs), List(labels), Visit sequence data as a List of List of List.

# %%
def extract_code(icd9_object):

    icd9_str = str(icd9_object)
    if icd9_str[0] == 'E': icd9_str = icd9_str[0:4]
    else: icd9_str = icd9_str[0:3]
    
    return icd9_str

# %%
def build_dict(df_icd9, extract_func):

    unique_code = df_icd9['ICD9_CODE'].apply(extract_func).unique()
    unique_code = pd.Series(unique_code).sort_values()
    code_dict = dict(zip(unique_code, range(len(unique_code))))
    
    return code_dict

# %%
def build_dataset(path, code_dict, extract_func):

    df_mortality = pd.read_csv(os.path.join(path, "MORTALITY.csv"))
    df_admissions = pd.read_csv(os.path.join(path, "ADMISSIONS.csv"))
    df_diagnoses = pd.read_csv(os.path.join(path, "DIAGNOSES_ICD.csv"))
    
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].apply(extract_func)
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].map(code_dict)
    df_joined = df_admissions.merge(df_diagnoses, on=['HADM_ID', 'SUBJECT_ID'])
    df_patient_admittee_ICD9 = df_joined[['SUBJECT_ID', 'ADMITTIME','ICD9_CODE']]
    
    patient_ids = []
    labels = []
    seq_data = []
    
    for name1, d in df_patient_admittee_ICD9.groupby('SUBJECT_ID'):
        patient_ids.append(name1)
        labels.extend(list(df_mortality["MORTALITY"][(df_mortality["SUBJECT_ID"] == name1)]))
        subl = []
        d['ADMITTIME'] = pd.to_datetime(d['ADMITTIME'])
        for name2, subd in d.groupby('ADMITTIME'):
            subl.append(list(subd['ICD9_CODE']))
        seq_data.append(subl)
    
    return patient_ids, labels, seq_data

# %%
print("Build feature id map")
df_icd9 = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"), usecols=["ICD9_CODE"])
code_dict = build_dict(df_icd9, extract_code)

print("Construct train and test set")
ids, labels, seqs = build_dataset(PATH_DATA, code_dict, extract_code)
train_ids, test_ids, train_seqs, test_seqs, train_labels, test_labels = train_test_split(ids, seqs, labels, test_size=0.2)

print("Construct validation set")
valid_ids, valid_labels, valid_seqs = build_dataset(PATH_VALIDATION, code_dict, extract_code)
print("Completed!")
# Out:
# Build feature id map
# Construct train and test set
# Construct validation set
# Completed!

# %%
ids[0:5] # patient IDs
# Out:
# [17, 23, 34, 36, 61]

# %%
labels[0:5] # mortality
# Out:
# [1, 1, 1, 1, 0]

# %%
seqs[0:5] # unique feature id
# Out:
# [[[545, 336, 854, 171], [303, 375, 582, 336, 210, 525, 522, 171]],
#  [[296, 293, 304, 872, 171, 287, 451, 279],
#   [132, 242, 577, 304, 287, 171, 171, 872, 872, 857]],
#  [[292, 308, 305, 307, 746, 306, 296, 782],
#   [307, 308, 306, 296, 881, 308, 148, 258]],
#  [[296, 293, 367, 287, 204, 393, 451, 852, 447],
#   [747, 747, 297, 331, 745, 367, 296, 872, 287, 451, 393, 852],
#   [408, 297, 382, 358, 746, 382, 296, 367, 287, 451, 199, 852]],
#  [[113, 187, 186, 429, 184, 164, 748, 430, 498],
#   [113,
#    183,
#    745,
#    420,
#    418,
#    175,
#    16,
#    744,
#    175,
#    595,
#    43,
#    175,
#    336,
#    307,
#    157,
#    245,
#    34]]]

# %% [markdown]
# ## Custom Pytorch Dataset
#
# For each patient, I decided to use a matrix, rows represent different visits, jth column show the integer feature ID j. If matrix[i][j] == 1, it means that on ith visit, we get feature ID j.

# %%
# for each row, get the number of feature id.
def get_num_features(seqs):

    def get_flatten_list(ori_list, flatten_list = None):
        if flatten_list is None: flatten_list = []
        for i in ori_list:
            if isinstance(i, list): get_flatten_list(i, flatten_list)
            else: flatten_list.append(i)
        return flatten_list

    def get_max(list1):
        tmp = -1
        for i in list1:
            if i > tmp: tmp = i
        return tmp
    
    l = get_flatten_list(seqs)
    return get_max(l) + 1

# %%
# inherit from Dataset, represent matrixs.
class MyDataset(Dataset):
    def __init__(self, seqs, labels, num_features):

        self.labels = labels
        self.seqs = []
        def isNaN(num):
            return num != num
        for seq in seqs:
            new_seq = []
            for visit in seq:
                new_visit = [0] * int(num_features)
                for i in visit:
                    if not isNaN(i): new_visit[int(i)] = 1
                new_visit = np.asarray(new_visit)
                new_seq.append(new_visit)
            new_seq = np.asarray(new_seq)
            self.seqs.append(new_seq)
            
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # returns will be wrapped as List of Tensor(s) by DataLoader
        return self.seqs[index], self.labels[index]

# %% [markdown]
# ## Generate mini-batches represented by 3D Tensor
#
# Generate mini-batches by defining `collate_fn` which is an argument of DataLoader constructor.
#
# - mini-batches: batch_size * max_length * num_features
#
# - If matrice in same batch have different number of rows, I will padding them with zero rows.

# %%
def collate_fn(batch):

    def getKey(item):
        return item[1]
    
    new_tuples = []
    seqs = []
    labels = []
    lengths = []
    max_length = -1
    num_features = len(batch[0][0][0])
    
    for b in batch:
        b_seqs = b[0]
        tmp_list = [b_seqs, len(b_seqs), b[1]]
        new_tuples.append(tuple(tmp_list))
        if len(b_seqs) > max_length:
            max_length = len(b_seqs)
    batch = sorted(new_tuples, key = getKey, reverse=True)
    
    for b in batch:
        b_seqs = b[0]
        labels.append(b[2])
        lengths.append(b[1])
        b_seqs = list(b_seqs)
        while len(b_seqs) < max_length:
            b_seqs.append([0] * num_features)
        seqs.append(torch.Tensor(b_seqs))
    seqs_tensor = torch.stack(seqs, 0)
    lengths_tensor = torch.LongTensor(lengths)
    labels_tensor = torch.LongTensor(labels)

    return (seqs_tensor, lengths_tensor), labels_tensor

# %% [markdown]
# # Build RNN model
#
#
# - Only need to define the forward function, the backward function will be generate automatically

# %%
class MyNet(nn.Module):
    def __init__(self, dim_input):
        super(MyNet, self).__init__()
        self.fc1 = nn.Linear(dim_input, 32)
        self.fc2 = nn.Linear(16, 2)
        self.rnn = nn.GRU(input_size=32, hidden_size=16, num_layers=2, batch_first=True, dropout=0.5, bidirectional=False)
        self.tanh = nn.Tanh()

    def forward(self, input_tuple):
        seqs, lengths = input_tuple
        seqs = self.fc1(seqs)
        seqs = F.tanh(seqs)
        seqs = pack_padded_sequence(seqs, lengths, batch_first=True)
        seqs, _ = self.rnn(seqs)
        seqs, _ = pad_packed_sequence(seqs, batch_first=True)
        new_seqs = []
        for i in range(0, len(seqs)):
            new_seqs.append(seqs[i][lengths[i] - 1])
        new_seqs = torch.stack(new_seqs, 0)
        seqs = self.fc2(new_seqs)
        return seqs

# %% [markdown]
# # Training and validation process

# %%
import os
import time

class MyAverageGenerator():
    def __init__(self):
        self.val = 0
        self.average = 0
        self.sum = 0
        self.count = 0

    def update(self, val, size = 1):
        self.val = val
        self.sum += val * size
        self.count += size
        self.average = self.sum / self.count
        
def get_batch_accuracy(output, target):
    
    with torch.no_grad():

        batch_size = target.size(0)
        _, pred = output.max(1)
        correct = pred.eq(target).sum()

        return correct * 100.0 / batch_size
    
def train(model, device, data_loader, criterion, optimizer, epoch, print_freq=10):
    batch_time = MyAverageGenerator()
    data_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    accuracy = MyAverageGenerator()

    model.train()

    end = time.time()
    for i, (input, target) in enumerate(data_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        if isinstance(input, tuple):
            input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
        else:
            input = input.to(device)
        target = target.to(device)

        optimizer.zero_grad()
        output = model(input)
        loss = criterion(output, target)
        assert not np.isnan(loss.item()), 'Model diverged with loss = NaN'

        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        losses.update(loss.item(), target.size(0))
        accuracy.update(get_batch_accuracy(output, target).item(), target.size(0))

        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Time ({batch_time.average:.3f})\t'
                  'Data ({data_time.average:.3f})\t'
                  'Loss ({loss.average:.4f})\t'
                  'Accuracy ({acc.average:.3f})'.format(
                epoch, i, len(data_loader), batch_time=batch_time,
                data_time=data_time, loss=losses, acc=accuracy))

    return losses.average, accuracy.average


def evaluate(model, device, data_loader, criterion, print_freq=10):
    batch_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    accuracy = MyAverageGenerator()

    results = []

    model.eval()

    with torch.no_grad():
        end = time.time()
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)
            target = target.to(device)

            output = model(input)
            loss = criterion(output, target)

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            losses.update(loss.item(), target.size(0))
            accuracy.update(get_batch_accuracy(output, target).item(), target.size(0))

            y_true = target.detach().to('cpu').numpy().tolist()
            y_pred = output.detach().to('cpu').max(1)[1].numpy().tolist()
            results.extend(list(zip(y_true, y_pred)))

            if i % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                      'Time ({batch_time.average:.3f})\t'
                      'Loss ({loss.average:.4f})\t'
                      'Accuracy ({acc.average:.3f})'.format(
                    i, len(data_loader), batch_time=batch_time, loss=losses, acc=accuracy))

    return losses.average, accuracy.average, results

# %%
torch.manual_seed(0)
NUM_EPOCHS = 20
BATCH_SIZE = 32
USE_CUDA = False
NUM_WORKERS = 0

# %%
num_features = get_num_features(train_seqs)

train_dataset = MyDataset(train_seqs, train_labels, num_features)
valid_dataset = MyDataset(valid_seqs, valid_labels, num_features)
test_dataset = MyDataset(test_seqs, test_labels, num_features)

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=NUM_WORKERS)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)
# batch_size for the test set should be 1 to avoid sorting each mini-batch which breaks the connection with patient IDs
test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)

# %%
model = MyNet(num_features)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

device = torch.device("cuda" if torch.cuda.is_available() and USE_CUDA else "cpu")
model.to(device)
criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
best_val_acc = 0.0
train_losses, train_accuracies = [], []
valid_losses, valid_accuracies = [], []
for epoch in range(NUM_EPOCHS):
    train_loss, train_accuracy = train(model, device, train_loader, criterion, optimizer, epoch)
    valid_loss, valid_accuracy, valid_results = evaluate(model, device, valid_loader, criterion)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    train_accuracies.append(train_accuracy)
    valid_accuracies.append(valid_accuracy)

    is_best = valid_accuracy > best_val_acc  # let's keep the model that has the best accuracy, but you can also use another metric.
    if is_best:
        best_val_acc = valid_accuracy
        torch.save(model, os.path.join(PATH_OUTPUT, "MyNet.pth"))
# Out:
# Epoch: [0][0/132]	Time (0.123)	Data (0.032)	Loss (0.7125)	Accuracy (31.000)
# Epoch: [0][10/132]	Time (0.034)	Data (0.018)	Loss (0.7105)	Accuracy (32.909)
# Epoch: [0][20/132]	Time (0.029)	Data (0.017)	Loss (0.7075)	Accuracy (36.381)
# Epoch: [0][30/132]	Time (0.030)	Data (0.018)	Loss (0.7061)	Accuracy (37.000)
# Epoch: [0][40/132]	Time (0.029)	Data (0.018)	Loss (0.7049)	Accuracy (38.024)
# Epoch: [0][50/132]	Time (0.029)	Data (0.018)	Loss (0.7033)	Accuracy (39.412)
# Epoch: [0][60/132]	Time (0.028)	Data (0.017)	Loss (0.7023)	Accuracy (40.262)
# Epoch: [0][70/132]	Time (0.027)	Data (0.017)	Loss (0.7011)	Accuracy (41.535)
# Epoch: [0][80/132]	Time (0.028)	Data (0.017)	Loss (0.7001)	Accuracy (42.383)
# Epoch: [0][90/132]	Time (0.028)	Data (0.017)	Loss (0.6992)	Accuracy (43.374)
# Epoch: [0][100/132]	Time (0.027)	Data (0.017)	Loss (0.6981)	Accuracy (45.099)
# Epoch: [0][110/132]	Time (0.027)	Data (0.017)	Loss (0.6975)	Accuracy (45.712)
# Epoch: [0][120/132]	Time (0.027)	Data (0.017)	Loss (0.6968)	Accuracy (46.595)
# Epoch: [0][130/132]	Time (0.027)	Data (0.017)	Loss (0.6959)	Accuracy (47.389)
# Test: [0/24]	Time (0.019)	Loss (0.6962)	Accuracy (56.000)
# Test: [10/24]	Time (0.018)	Loss (0.6865)	Accuracy (61.000)
# Test: [20/24]	Time (0.019)	Loss (0.6833)	Accuracy (61.667)
# Epoch: [1][0/132]	Time (0.025)	Data (0.012)	Loss (0.6652)	Accuracy (68.000)
# Epoch: [1][10/132]	Time (0.028)	Data (0.017)	Loss (0.6815)	Accuracy (60.091)
# Epoch: [1][20/132]	Time (0.030)	Data (0.019)	Loss (0.6841)	Accuracy (59.714)
# Epoch: [1][30/132]	Time (0.030)	Data (0.019)	Loss (0.6812)	Accuracy (61.290)
# Epoch: [1][40/132]	Time (0.030)	Data (0.019)	Loss (0.6778)	Accuracy (62.098)
# Epoch: [1][50/132]	Time (0.030)	Data (0.019)	Loss (0.6778)	Accuracy (62.039)
# Epoch: [1][60/132]	Time (0.031)	Data (0.019)	Loss (0.6772)	Accuracy (61.984)
# Epoch: [1][70/132]	Time (0.031)	Data (0.019)	Loss (0.6762)	Accuracy (62.493)
# Epoch: [1][80/132]	Time (0.030)	Data (0.019)	Loss (0.6762)	Accuracy (62.321)
# Epoch: [1][90/132]	Time (0.030)	Data (0.019)	Loss (0.6765)	Accuracy (61.912)
# Epoch: [1][100/132]	Time (0.029)	Data (0.018)	Loss (0.6748)	Accuracy (62.069)
# Epoch: [1][110/132]	Time (0.029)	Data (0.018)	Loss (0.6752)	Accuracy (61.874)
# Epoch: [1][120/132]	Time (0.029)	Data (0.018)	Loss (0.6741)	Accuracy (62.091)
# Epoch: [1][130/132]	Time (0.028)	Data (0.018)	Loss (0.6729)	Accuracy (62.221)
# Test: [0/24]	Time (0.017)	Loss (0.6924)	Accuracy (56.000)
# Test: [10/24]	Time (0.013)	Loss (0.6729)	Accuracy (61.000)
# Test: [20/24]	Time (0.013)	Loss (0.6666)	Accuracy (61.667)
# Epoch: [2][0/132]	Time (0.019)	Data (0.011)	Loss (0.6422)	Accuracy (78.000)
# Epoch: [2][10/132]	Time (0.026)	Data (0.018)	Loss (0.6474)	Accuracy (68.273)
# Epoch: [2][20/132]	Time (0.026)	Data (0.017)	Loss (0.6545)	Accuracy (64.714)
# Epoch: [2][30/132]	Time (0.025)	Data (0.016)	Loss (0.6552)	Accuracy (64.226)
# Epoch: [2][40/132]	Time (0.025)	Data (0.016)	Loss (0.6552)	Accuracy (63.512)
# Epoch: [2][50/132]	Time (0.025)	Data (0.016)	Loss (0.6557)	Accuracy (63.490)
# Epoch: [2][60/132]	Time (0.026)	Data (0.017)	Loss (0.6539)	Accuracy (63.869)
# Epoch: [2][70/132]	Time (0.026)	Data (0.017)	Loss (0.6542)	Accuracy (63.845)
# Epoch: [2][80/132]	Time (0.025)	Data (0.017)	Loss (0.6518)	Accuracy (64.185)
# Epoch: [2][90/132]	Time (0.025)	Data (0.017)	Loss (0.6514)	Accuracy (64.011)
# Epoch: [2][100/132]	Time (0.025)	Data (0.016)	Loss (0.6533)	Accuracy (63.327)
# Epoch: [2][110/132]	Time (0.025)	Data (0.016)	Loss (0.6533)	Accuracy (63.396)
# Epoch: [2][120/132]	Time (0.025)	Data (0.016)	Loss (0.6533)	Accuracy (63.413)
# Epoch: [2][130/132]	Time (0.025)	Data (0.016)	Loss (0.6535)	Accuracy (63.069)
# Test: [0/24]	Time (0.018)	Loss (0.6747)	Accuracy (56.000)
# Test: [10/24]	Time (0.013)	Loss (0.6559)	Accuracy (61.273)
# Test: [20/24]	Time (0.014)	Loss (0.6458)	Accuracy (61.952)
# Epoch: [3][0/132]	Time (0.018)	Data (0.011)	Loss (0.7004)	Accuracy (56.000)
# Epoch: [3][10/132]	Time (0.024)	Data (0.016)	Loss (0.6598)	Accuracy (59.273)
# Epoch: [3][20/132]	Time (0.029)	Data (0.018)	Loss (0.6446)	Accuracy (63.143)
# Epoch: [3][30/132]	Time (0.027)	Data (0.017)	Loss (0.6443)	Accuracy (62.323)
# Epoch: [3][40/132]	Time (0.026)	Data (0.017)	Loss (0.6392)	Accuracy (63.000)
# Epoch: [3][50/132]	Time (0.026)	Data (0.016)	Loss (0.6374)	Accuracy (63.176)
# Epoch: [3][60/132]	Time (0.026)	Data (0.017)	Loss (0.6374)	Accuracy (63.328)
# Epoch: [3][70/132]	Time (0.026)	Data (0.017)	Loss (0.6349)	Accuracy (63.718)
# Epoch: [3][80/132]	Time (0.026)	Data (0.017)	Loss (0.6337)	Accuracy (64.185)
# Epoch: [3][90/132]	Time (0.026)	Data (0.017)	Loss (0.6324)	Accuracy (64.297)
# Epoch: [3][100/132]	Time (0.026)	Data (0.017)	Loss (0.6307)	Accuracy (64.673)
# Epoch: [3][110/132]	Time (0.025)	Data (0.016)	Loss (0.6301)	Accuracy (64.712)
# Epoch: [3][120/132]	Time (0.025)	Data (0.016)	Loss (0.6295)	Accuracy (64.876)
# Epoch: [3][130/132]	Time (0.025)	Data (0.016)	Loss (0.6268)	Accuracy (65.443)
# Test: [0/24]	Time (0.019)	Loss (0.6359)	Accuracy (68.000)
# Test: [10/24]	Time (0.013)	Loss (0.6269)	Accuracy (64.636)
# Test: [20/24]	Time (0.014)	Loss (0.6103)	Accuracy (66.429)
# Epoch: [4][0/132]	Time (0.029)	Data (0.018)	Loss (0.5902)	Accuracy (78.000)
# Epoch: [4][10/132]	Time (0.025)	Data (0.016)	Loss (0.6032)	Accuracy (69.455)
# Epoch: [4][20/132]	Time (0.025)	Data (0.015)	Loss (0.6095)	Accuracy (66.952)
# Epoch: [4][30/132]	Time (0.025)	Data (0.016)	Loss (0.5978)	Accuracy (69.581)
# Epoch: [4][40/132]	Time (0.025)	Data (0.017)	Loss (0.6003)	Accuracy (68.415)
# Epoch: [4][50/132]	Time (0.026)	Data (0.017)	Loss (0.6005)	Accuracy (68.706)
# Epoch: [4][60/132]	Time (0.026)	Data (0.017)	Loss (0.6036)	Accuracy (68.361)
# Epoch: [4][70/132]	Time (0.027)	Data (0.017)	Loss (0.6014)	Accuracy (68.535)
# Epoch: [4][80/132]	Time (0.027)	Data (0.018)	Loss (0.5995)	Accuracy (68.951)
# Epoch: [4][90/132]	Time (0.027)	Data (0.018)	Loss (0.5978)	Accuracy (69.154)
# Epoch: [4][100/132]	Time (0.027)	Data (0.018)	Loss (0.5933)	Accuracy (69.584)
# Epoch: [4][110/132]	Time (0.027)	Data (0.018)	Loss (0.5921)	Accuracy (69.730)
# Epoch: [4][120/132]	Time (0.027)	Data (0.018)	Loss (0.5897)	Accuracy (69.851)
# Epoch: [4][130/132]	Time (0.027)	Data (0.018)	Loss (0.5874)	Accuracy (70.015)
# Test: [0/24]	Time (0.025)	Loss (0.5930)	Accuracy (65.000)
# Test: [10/24]	Time (0.016)	Loss (0.5957)	Accuracy (67.182)
# Test: [20/24]	Time (0.015)	Loss (0.5694)	Accuracy (69.810)
# Epoch: [5][0/132]	Time (0.024)	Data (0.015)	Loss (0.5611)	Accuracy (71.000)
# Epoch: [5][10/132]	Time (0.029)	Data (0.018)	Loss (0.5611)	Accuracy (74.636)
# Epoch: [5][20/132]	Time (0.028)	Data (0.018)	Loss (0.5512)	Accuracy (74.762)
# Epoch: [5][30/132]	Time (0.028)	Data (0.018)	Loss (0.5502)	Accuracy (73.968)
# Epoch: [5][40/132]	Time (0.027)	Data (0.017)	Loss (0.5473)	Accuracy (74.122)
# Epoch: [5][50/132]	Time (0.027)	Data (0.017)	Loss (0.5435)	Accuracy (74.157)
# Epoch: [5][60/132]	Time (0.026)	Data (0.017)	Loss (0.5455)	Accuracy (73.426)
# Epoch: [5][70/132]	Time (0.026)	Data (0.017)	Loss (0.5471)	Accuracy (73.169)
# Epoch: [5][80/132]	Time (0.026)	Data (0.017)	Loss (0.5498)	Accuracy (72.642)
# Epoch: [5][90/132]	Time (0.026)	Data (0.017)	Loss (0.5501)	Accuracy (72.451)
# Epoch: [5][100/132]	Time (0.026)	Data (0.017)	Loss (0.5477)	Accuracy (72.673)
# Epoch: [5][110/132]	Time (0.026)	Data (0.017)	Loss (0.5506)	Accuracy (72.342)
# Epoch: [5][120/132]	Time (0.026)	Data (0.016)	Loss (0.5520)	Accuracy (71.934)
# Epoch: [5][130/132]	Time (0.026)	Data (0.016)	Loss (0.5498)	Accuracy (72.015)
# Test: [0/24]	Time (0.019)	Loss (0.5624)	Accuracy (68.000)
# Test: [10/24]	Time (0.014)	Loss (0.5769)	Accuracy (68.273)
# Test: [20/24]	Time (0.014)	Loss (0.5424)	Accuracy (70.905)
# Epoch: [6][0/132]	Time (0.019)	Data (0.012)	Loss (0.4800)	Accuracy (78.000)
# Epoch: [6][10/132]	Time (0.026)	Data (0.017)	Loss (0.5281)	Accuracy (74.636)
# Epoch: [6][20/132]	Time (0.025)	Data (0.016)	Loss (0.5393)	Accuracy (71.952)
# Epoch: [6][30/132]	Time (0.026)	Data (0.017)	Loss (0.5381)	Accuracy (72.806)
# Epoch: [6][40/132]	Time (0.024)	Data (0.016)	Loss (0.5325)	Accuracy (73.146)
# Epoch: [6][50/132]	Time (0.025)	Data (0.016)	Loss (0.5327)	Accuracy (72.569)
# Epoch: [6][60/132]	Time (0.025)	Data (0.016)	Loss (0.5328)	Accuracy (72.885)
# Epoch: [6][70/132]	Time (0.024)	Data (0.016)	Loss (0.5331)	Accuracy (72.761)
# Epoch: [6][80/132]	Time (0.024)	Data (0.016)	Loss (0.5344)	Accuracy (72.840)
# Epoch: [6][90/132]	Time (0.024)	Data (0.016)	Loss (0.5312)	Accuracy (73.099)
# Epoch: [6][100/132]	Time (0.025)	Data (0.016)	Loss (0.5317)	Accuracy (73.059)
# Epoch: [6][110/132]	Time (0.025)	Data (0.016)	Loss (0.5290)	Accuracy (73.261)
# Epoch: [6][120/132]	Time (0.025)	Data (0.016)	Loss (0.5250)	Accuracy (73.744)
# Epoch: [6][130/132]	Time (0.025)	Data (0.016)	Loss (0.5242)	Accuracy (73.763)
# Test: [0/24]	Time (0.018)	Loss (0.5547)	Accuracy (68.000)
# Test: [10/24]	Time (0.013)	Loss (0.5703)	Accuracy (69.727)
# Test: [20/24]	Time (0.013)	Loss (0.5304)	Accuracy (71.952)
# Epoch: [7][0/132]	Time (0.023)	Data (0.014)	Loss (0.5013)	Accuracy (81.000)
# Epoch: [7][10/132]	Time (0.025)	Data (0.016)	Loss (0.5365)	Accuracy (72.182)
# Epoch: [7][20/132]	Time (0.025)	Data (0.017)	Loss (0.5452)	Accuracy (71.333)
# Epoch: [7][30/132]	Time (0.024)	Data (0.016)	Loss (0.5210)	Accuracy (73.161)
# Epoch: [7][40/132]	Time (0.025)	Data (0.017)	Loss (0.5238)	Accuracy (73.902)
# Epoch: [7][50/132]	Time (0.025)	Data (0.017)	Loss (0.5181)	Accuracy (74.392)
# Epoch: [7][60/132]	Time (0.026)	Data (0.017)	Loss (0.5137)	Accuracy (74.557)
# Epoch: [7][70/132]	Time (0.026)	Data (0.017)	Loss (0.5167)	Accuracy (74.127)
# Epoch: [7][80/132]	Time (0.026)	Data (0.017)	Loss (0.5151)	Accuracy (74.420)
# Epoch: [7][90/132]	Time (0.026)	Data (0.017)	Loss (0.5115)	Accuracy (74.791)
# Epoch: [7][100/132]	Time (0.026)	Data (0.017)	Loss (0.5115)	Accuracy (75.079)
# Epoch: [7][110/132]	Time (0.026)	Data (0.017)	Loss (0.5110)	Accuracy (75.135)
# Epoch: [7][120/132]	Time (0.026)	Data (0.017)	Loss (0.5068)	Accuracy (75.512)
# Epoch: [7][130/132]	Time (0.026)	Data (0.017)	Loss (0.5100)	Accuracy (75.099)
# Test: [0/24]	Time (0.019)	Loss (0.5479)	Accuracy (68.000)
# Test: [10/24]	Time (0.015)	Loss (0.5665)	Accuracy (69.455)
# Test: [20/24]	Time (0.015)	Loss (0.5249)	Accuracy (72.381)
# Epoch: [8][0/132]	Time (0.018)	Data (0.012)	Loss (0.4933)	Accuracy (81.000)
# Epoch: [8][10/132]	Time (0.028)	Data (0.018)	Loss (0.4717)	Accuracy (78.545)
# Epoch: [8][20/132]	Time (0.026)	Data (0.017)	Loss (0.4760)	Accuracy (77.810)
# Epoch: [8][30/132]	Time (0.027)	Data (0.017)	Loss (0.4933)	Accuracy (76.258)
# Epoch: [8][40/132]	Time (0.029)	Data (0.018)	Loss (0.4935)	Accuracy (76.634)
# Epoch: [8][50/132]	Time (0.029)	Data (0.018)	Loss (0.4960)	Accuracy (76.804)
# Epoch: [8][60/132]	Time (0.029)	Data (0.018)	Loss (0.5000)	Accuracy (76.557)
# Epoch: [8][70/132]	Time (0.029)	Data (0.018)	Loss (0.5035)	Accuracy (75.873)
# Epoch: [8][80/132]	Time (0.029)	Data (0.018)	Loss (0.5010)	Accuracy (76.136)
# Epoch: [8][90/132]	Time (0.029)	Data (0.018)	Loss (0.4997)	Accuracy (76.066)
# Epoch: [8][100/132]	Time (0.028)	Data (0.018)	Loss (0.4984)	Accuracy (75.990)
# Epoch: [8][110/132]	Time (0.028)	Data (0.018)	Loss (0.4978)	Accuracy (76.189)
# Epoch: [8][120/132]	Time (0.028)	Data (0.018)	Loss (0.4992)	Accuracy (76.198)
# Epoch: [8][130/132]	Time (0.028)	Data (0.018)	Loss (0.4973)	Accuracy (76.282)
# Test: [0/24]	Time (0.018)	Loss (0.5431)	Accuracy (71.000)
# Test: [10/24]	Time (0.015)	Loss (0.5635)	Accuracy (69.818)
# Test: [20/24]	Time (0.015)	Loss (0.5202)	Accuracy (72.476)
# Epoch: [9][0/132]	Time (0.019)	Data (0.011)	Loss (0.4725)	Accuracy (78.000)
# Epoch: [9][10/132]	Time (0.026)	Data (0.017)	Loss (0.4906)	Accuracy (76.273)
# Epoch: [9][20/132]	Time (0.026)	Data (0.017)	Loss (0.4823)	Accuracy (77.286)
# Epoch: [9][30/132]	Time (0.025)	Data (0.017)	Loss (0.4764)	Accuracy (77.806)
# Epoch: [9][40/132]	Time (0.026)	Data (0.017)	Loss (0.4771)	Accuracy (78.122)
# Epoch: [9][50/132]	Time (0.026)	Data (0.017)	Loss (0.4805)	Accuracy (77.863)
# Epoch: [9][60/132]	Time (0.026)	Data (0.017)	Loss (0.4816)	Accuracy (77.689)
# Epoch: [9][70/132]	Time (0.026)	Data (0.017)	Loss (0.4865)	Accuracy (77.282)
# Epoch: [9][80/132]	Time (0.026)	Data (0.017)	Loss (0.4789)	Accuracy (77.691)
# Epoch: [9][90/132]	Time (0.026)	Data (0.017)	Loss (0.4786)	Accuracy (77.824)
# Epoch: [9][100/132]	Time (0.026)	Data (0.017)	Loss (0.4786)	Accuracy (77.574)
# Epoch: [9][110/132]	Time (0.026)	Data (0.016)	Loss (0.4796)	Accuracy (77.432)
# Epoch: [9][120/132]	Time (0.026)	Data (0.016)	Loss (0.4822)	Accuracy (77.223)
# Epoch: [9][130/132]	Time (0.026)	Data (0.016)	Loss (0.4833)	Accuracy (76.977)
# Test: [0/24]	Time (0.019)	Loss (0.5413)	Accuracy (68.000)
# Test: [10/24]	Time (0.013)	Loss (0.5613)	Accuracy (69.545)
# Test: [20/24]	Time (0.014)	Loss (0.5183)	Accuracy (72.286)
# Epoch: [10][0/132]	Time (0.017)	Data (0.011)	Loss (0.4126)	Accuracy (78.000)
# Epoch: [10][10/132]	Time (0.028)	Data (0.019)	Loss (0.4538)	Accuracy (77.455)
# Epoch: [10][20/132]	Time (0.027)	Data (0.018)	Loss (0.4495)	Accuracy (78.857)
# Epoch: [10][30/132]	Time (0.026)	Data (0.017)	Loss (0.4569)	Accuracy (78.935)
# Epoch: [10][40/132]	Time (0.025)	Data (0.017)	Loss (0.4620)	Accuracy (78.390)
# Epoch: [10][50/132]	Time (0.026)	Data (0.017)	Loss (0.4718)	Accuracy (77.392)
# Epoch: [10][60/132]	Time (0.026)	Data (0.017)	Loss (0.4729)	Accuracy (77.115)
# Epoch: [10][70/132]	Time (0.026)	Data (0.017)	Loss (0.4728)	Accuracy (77.211)
# Epoch: [10][80/132]	Time (0.025)	Data (0.017)	Loss (0.4678)	Accuracy (77.630)
# Epoch: [10][90/132]	Time (0.026)	Data (0.017)	Loss (0.4696)	Accuracy (77.538)
# Epoch: [10][100/132]	Time (0.026)	Data (0.017)	Loss (0.4651)	Accuracy (77.703)
# Epoch: [10][110/132]	Time (0.026)	Data (0.017)	Loss (0.4689)	Accuracy (77.568)
# Epoch: [10][120/132]	Time (0.026)	Data (0.017)	Loss (0.4710)	Accuracy (77.372)
# Epoch: [10][130/132]	Time (0.026)	Data (0.017)	Loss (0.4715)	Accuracy (77.382)
# Test: [0/24]	Time (0.019)	Loss (0.5416)	Accuracy (68.000)
# Test: [10/24]	Time (0.017)	Loss (0.5620)	Accuracy (69.364)
# Test: [20/24]	Time (0.017)	Loss (0.5174)	Accuracy (72.190)
# Epoch: [11][0/132]	Time (0.038)	Data (0.023)	Loss (0.7028)	Accuracy (68.000)
# Epoch: [11][10/132]	Time (0.028)	Data (0.017)	Loss (0.4641)	Accuracy (78.818)
# Epoch: [11][20/132]	Time (0.027)	Data (0.017)	Loss (0.4670)	Accuracy (78.048)
# Epoch: [11][30/132]	Time (0.027)	Data (0.018)	Loss (0.4636)	Accuracy (78.032)
# Epoch: [11][40/132]	Time (0.028)	Data (0.018)	Loss (0.4663)	Accuracy (77.000)
# Epoch: [11][50/132]	Time (0.027)	Data (0.018)	Loss (0.4622)	Accuracy (77.941)
# Epoch: [11][60/132]	Time (0.027)	Data (0.018)	Loss (0.4561)	Accuracy (77.836)
# Epoch: [11][70/132]	Time (0.027)	Data (0.018)	Loss (0.4639)	Accuracy (77.451)
# Epoch: [11][80/132]	Time (0.027)	Data (0.018)	Loss (0.4654)	Accuracy (77.469)
# Epoch: [11][90/132]	Time (0.027)	Data (0.018)	Loss (0.4719)	Accuracy (77.077)
# Epoch: [11][100/132]	Time (0.027)	Data (0.018)	Loss (0.4692)	Accuracy (77.307)
# Epoch: [11][110/132]	Time (0.027)	Data (0.018)	Loss (0.4672)	Accuracy (77.631)
# Epoch: [11][120/132]	Time (0.027)	Data (0.018)	Loss (0.4678)	Accuracy (77.562)
# Epoch: [11][130/132]	Time (0.027)	Data (0.018)	Loss (0.4654)	Accuracy (77.679)
# Test: [0/24]	Time (0.019)	Loss (0.5488)	Accuracy (71.000)
# Test: [10/24]	Time (0.014)	Loss (0.5597)	Accuracy (70.545)
# Test: [20/24]	Time (0.014)	Loss (0.5182)	Accuracy (73.095)
# Epoch: [12][0/132]	Time (0.017)	Data (0.011)	Loss (0.3626)	Accuracy (87.000)
# Epoch: [12][10/132]	Time (0.025)	Data (0.017)	Loss (0.4411)	Accuracy (78.909)
# Epoch: [12][20/132]	Time (0.026)	Data (0.018)	Loss (0.4463)	Accuracy (78.571)
# Epoch: [12][30/132]	Time (0.026)	Data (0.017)	Loss (0.4596)	Accuracy (77.161)
# Epoch: [12][40/132]	Time (0.026)	Data (0.017)	Loss (0.4598)	Accuracy (77.512)
# Epoch: [12][50/132]	Time (0.026)	Data (0.017)	Loss (0.4529)	Accuracy (78.490)
# Epoch: [12][60/132]	Time (0.026)	Data (0.017)	Loss (0.4580)	Accuracy (78.410)
# Epoch: [12][70/132]	Time (0.026)	Data (0.017)	Loss (0.4633)	Accuracy (78.155)
# Epoch: [12][80/132]	Time (0.026)	Data (0.017)	Loss (0.4604)	Accuracy (78.049)
# Epoch: [12][90/132]	Time (0.026)	Data (0.017)	Loss (0.4595)	Accuracy (77.978)
# Epoch: [12][100/132]	Time (0.026)	Data (0.017)	Loss (0.4617)	Accuracy (78.020)
# Epoch: [12][110/132]	Time (0.026)	Data (0.017)	Loss (0.4595)	Accuracy (78.090)
# Epoch: [12][120/132]	Time (0.026)	Data (0.017)	Loss (0.4614)	Accuracy (78.116)
# Epoch: [12][130/132]	Time (0.026)	Data (0.017)	Loss (0.4611)	Accuracy (78.099)
# Test: [0/24]	Time (0.022)	Loss (0.5533)	Accuracy (71.000)
# Test: [10/24]	Time (0.014)	Loss (0.5598)	Accuracy (70.818)
# Test: [20/24]	Time (0.014)	Loss (0.5196)	Accuracy (73.238)
# Epoch: [13][0/132]	Time (0.017)	Data (0.011)	Loss (0.5581)	Accuracy (71.000)
# Epoch: [13][10/132]	Time (0.026)	Data (0.017)	Loss (0.4531)	Accuracy (78.727)
# Epoch: [13][20/132]	Time (0.026)	Data (0.017)	Loss (0.4473)	Accuracy (78.571)
# Epoch: [13][30/132]	Time (0.025)	Data (0.017)	Loss (0.4361)	Accuracy (79.935)
# Epoch: [13][40/132]	Time (0.025)	Data (0.017)	Loss (0.4477)	Accuracy (78.976)
# Epoch: [13][50/132]	Time (0.025)	Data (0.017)	Loss (0.4461)	Accuracy (78.941)
# Epoch: [13][60/132]	Time (0.025)	Data (0.017)	Loss (0.4463)	Accuracy (78.967)
# Epoch: [13][70/132]	Time (0.025)	Data (0.017)	Loss (0.4481)	Accuracy (78.930)
# Epoch: [13][80/132]	Time (0.026)	Data (0.017)	Loss (0.4480)	Accuracy (79.049)
# Epoch: [13][90/132]	Time (0.026)	Data (0.017)	Loss (0.4499)	Accuracy (78.923)
# Epoch: [13][100/132]	Time (0.026)	Data (0.017)	Loss (0.4514)	Accuracy (78.851)
# Epoch: [13][110/132]	Time (0.026)	Data (0.017)	Loss (0.4528)	Accuracy (78.586)
# Epoch: [13][120/132]	Time (0.025)	Data (0.017)	Loss (0.4548)	Accuracy (78.388)
# Epoch: [13][130/132]	Time (0.026)	Data (0.017)	Loss (0.4559)	Accuracy (78.458)
# Test: [0/24]	Time (0.019)	Loss (0.5594)	Accuracy (71.000)
# Test: [10/24]	Time (0.015)	Loss (0.5595)	Accuracy (71.455)
# Test: [20/24]	Time (0.015)	Loss (0.5191)	Accuracy (73.905)
# Epoch: [14][0/132]	Time (0.019)	Data (0.012)	Loss (0.5552)	Accuracy (62.000)
# Epoch: [14][10/132]	Time (0.026)	Data (0.016)	Loss (0.4363)	Accuracy (81.091)
# Epoch: [14][20/132]	Time (0.027)	Data (0.017)	Loss (0.4523)	Accuracy (80.381)
# Epoch: [14][30/132]	Time (0.028)	Data (0.017)	Loss (0.4413)	Accuracy (80.000)
# Epoch: [14][40/132]	Time (0.027)	Data (0.016)	Loss (0.4445)	Accuracy (79.683)
# Epoch: [14][50/132]	Time (0.027)	Data (0.016)	Loss (0.4464)	Accuracy (79.333)
# Epoch: [14][60/132]	Time (0.027)	Data (0.017)	Loss (0.4526)	Accuracy (78.918)
# Epoch: [14][70/132]	Time (0.026)	Data (0.016)	Loss (0.4466)	Accuracy (79.268)
# Epoch: [14][80/132]	Time (0.026)	Data (0.016)	Loss (0.4429)	Accuracy (79.309)
# Epoch: [14][90/132]	Time (0.026)	Data (0.016)	Loss (0.4476)	Accuracy (78.736)
# Epoch: [14][100/132]	Time (0.026)	Data (0.016)	Loss (0.4494)	Accuracy (78.723)
# Epoch: [14][110/132]	Time (0.026)	Data (0.016)	Loss (0.4528)	Accuracy (78.595)
# Epoch: [14][120/132]	Time (0.026)	Data (0.017)	Loss (0.4499)	Accuracy (78.702)
# Epoch: [14][130/132]	Time (0.026)	Data (0.016)	Loss (0.4506)	Accuracy (78.710)
# Test: [0/24]	Time (0.018)	Loss (0.5598)	Accuracy (65.000)
# Test: [10/24]	Time (0.014)	Loss (0.5584)	Accuracy (71.455)
# Test: [20/24]	Time (0.014)	Loss (0.5203)	Accuracy (73.762)
# Epoch: [15][0/132]	Time (0.015)	Data (0.010)	Loss (0.5055)	Accuracy (75.000)
# Epoch: [15][10/132]	Time (0.022)	Data (0.014)	Loss (0.4735)	Accuracy (77.000)
# Epoch: [15][20/132]	Time (0.024)	Data (0.016)	Loss (0.4426)	Accuracy (79.571)
# Epoch: [15][30/132]	Time (0.025)	Data (0.015)	Loss (0.4535)	Accuracy (78.645)
# Epoch: [15][40/132]	Time (0.026)	Data (0.016)	Loss (0.4419)	Accuracy (79.732)
# Epoch: [15][50/132]	Time (0.026)	Data (0.016)	Loss (0.4373)	Accuracy (80.078)
# Epoch: [15][60/132]	Time (0.026)	Data (0.016)	Loss (0.4445)	Accuracy (79.689)
# Epoch: [15][70/132]	Time (0.025)	Data (0.016)	Loss (0.4390)	Accuracy (79.746)
# Epoch: [15][80/132]	Time (0.025)	Data (0.016)	Loss (0.4421)	Accuracy (79.383)
# Epoch: [15][90/132]	Time (0.025)	Data (0.016)	Loss (0.4434)	Accuracy (79.363)
# Epoch: [15][100/132]	Time (0.025)	Data (0.016)	Loss (0.4422)	Accuracy (79.238)
# Epoch: [15][110/132]	Time (0.026)	Data (0.016)	Loss (0.4454)	Accuracy (78.928)
# Epoch: [15][120/132]	Time (0.025)	Data (0.016)	Loss (0.4465)	Accuracy (78.983)
# Epoch: [15][130/132]	Time (0.025)	Data (0.016)	Loss (0.4427)	Accuracy (79.244)
# Test: [0/24]	Time (0.016)	Loss (0.5668)	Accuracy (65.000)
# Test: [10/24]	Time (0.014)	Loss (0.5590)	Accuracy (70.909)
# Test: [20/24]	Time (0.014)	Loss (0.5221)	Accuracy (73.143)
# Epoch: [16][0/132]	Time (0.023)	Data (0.013)	Loss (0.4860)	Accuracy (81.000)
# Epoch: [16][10/132]	Time (0.027)	Data (0.018)	Loss (0.4303)	Accuracy (80.273)
# Epoch: [16][20/132]	Time (0.028)	Data (0.018)	Loss (0.4480)	Accuracy (79.381)
# Epoch: [16][30/132]	Time (0.028)	Data (0.018)	Loss (0.4531)	Accuracy (78.452)
# Epoch: [16][40/132]	Time (0.028)	Data (0.018)	Loss (0.4527)	Accuracy (78.537)
# Epoch: [16][50/132]	Time (0.028)	Data (0.018)	Loss (0.4539)	Accuracy (78.176)
# Epoch: [16][60/132]	Time (0.028)	Data (0.018)	Loss (0.4458)	Accuracy (78.410)
# Epoch: [16][70/132]	Time (0.028)	Data (0.018)	Loss (0.4455)	Accuracy (78.676)
# Epoch: [16][80/132]	Time (0.029)	Data (0.019)	Loss (0.4464)	Accuracy (78.642)
# Epoch: [16][90/132]	Time (0.029)	Data (0.018)	Loss (0.4431)	Accuracy (79.066)
# Epoch: [16][100/132]	Time (0.029)	Data (0.018)	Loss (0.4431)	Accuracy (79.040)
# Epoch: [16][110/132]	Time (0.029)	Data (0.018)	Loss (0.4447)	Accuracy (79.090)
# Epoch: [16][120/132]	Time (0.029)	Data (0.018)	Loss (0.4408)	Accuracy (79.107)
# Epoch: [16][130/132]	Time (0.029)	Data (0.018)	Loss (0.4442)	Accuracy (78.931)
# Test: [0/24]	Time (0.018)	Loss (0.5745)	Accuracy (65.000)
# Test: [10/24]	Time (0.019)	Loss (0.5601)	Accuracy (71.818)
# Test: [20/24]	Time (0.018)	Loss (0.5241)	Accuracy (73.286)
# Epoch: [17][0/132]	Time (0.027)	Data (0.014)	Loss (0.2819)	Accuracy (96.000)
# Epoch: [17][10/132]	Time (0.027)	Data (0.018)	Loss (0.4469)	Accuracy (78.455)
# Epoch: [17][20/132]	Time (0.032)	Data (0.019)	Loss (0.4166)	Accuracy (79.524)
# Epoch: [17][30/132]	Time (0.030)	Data (0.018)	Loss (0.4378)	Accuracy (78.452)
# Epoch: [17][40/132]	Time (0.029)	Data (0.018)	Loss (0.4285)	Accuracy (79.122)
# Epoch: [17][50/132]	Time (0.028)	Data (0.018)	Loss (0.4319)	Accuracy (78.784)
# Epoch: [17][60/132]	Time (0.028)	Data (0.018)	Loss (0.4298)	Accuracy (79.098)
# Epoch: [17][70/132]	Time (0.028)	Data (0.018)	Loss (0.4296)	Accuracy (79.507)
# Epoch: [17][80/132]	Time (0.028)	Data (0.018)	Loss (0.4284)	Accuracy (79.568)
# Epoch: [17][90/132]	Time (0.028)	Data (0.018)	Loss (0.4265)	Accuracy (79.813)
# Epoch: [17][100/132]	Time (0.028)	Data (0.018)	Loss (0.4262)	Accuracy (79.960)
# Epoch: [17][110/132]	Time (0.028)	Data (0.018)	Loss (0.4306)	Accuracy (79.748)
# Epoch: [17][120/132]	Time (0.028)	Data (0.018)	Loss (0.4312)	Accuracy (79.612)
# Epoch: [17][130/132]	Time (0.027)	Data (0.018)	Loss (0.4366)	Accuracy (79.351)
# Test: [0/24]	Time (0.020)	Loss (0.5716)	Accuracy (68.000)
# Test: [10/24]	Time (0.015)	Loss (0.5605)	Accuracy (72.364)
# Test: [20/24]	Time (0.015)	Loss (0.5245)	Accuracy (73.857)
# Epoch: [18][0/132]	Time (0.027)	Data (0.013)	Loss (0.4893)	Accuracy (78.000)
# Epoch: [18][10/132]	Time (0.024)	Data (0.015)	Loss (0.4399)	Accuracy (79.818)
# Epoch: [18][20/132]	Time (0.026)	Data (0.017)	Loss (0.4456)	Accuracy (79.667)
# Epoch: [18][30/132]	Time (0.027)	Data (0.017)	Loss (0.4335)	Accuracy (79.903)
# Epoch: [18][40/132]	Time (0.027)	Data (0.017)	Loss (0.4344)	Accuracy (79.829)
# Epoch: [18][50/132]	Time (0.028)	Data (0.017)	Loss (0.4268)	Accuracy (79.706)
# Epoch: [18][60/132]	Time (0.028)	Data (0.018)	Loss (0.4329)	Accuracy (79.459)
# Epoch: [18][70/132]	Time (0.028)	Data (0.018)	Loss (0.4335)	Accuracy (79.254)
# Epoch: [18][80/132]	Time (0.028)	Data (0.018)	Loss (0.4308)	Accuracy (79.704)
# Epoch: [18][90/132]	Time (0.028)	Data (0.018)	Loss (0.4291)	Accuracy (79.648)
# Epoch: [18][100/132]	Time (0.029)	Data (0.018)	Loss (0.4362)	Accuracy (79.119)
# Epoch: [18][110/132]	Time (0.028)	Data (0.018)	Loss (0.4376)	Accuracy (79.117)
# Epoch: [18][120/132]	Time (0.029)	Data (0.018)	Loss (0.4368)	Accuracy (79.207)
# Epoch: [18][130/132]	Time (0.029)	Data (0.018)	Loss (0.4331)	Accuracy (79.458)
# Test: [0/24]	Time (0.020)	Loss (0.5770)	Accuracy (65.000)
# Test: [10/24]	Time (0.016)	Loss (0.5615)	Accuracy (72.636)
# Test: [20/24]	Time (0.017)	Loss (0.5263)	Accuracy (74.048)
# Epoch: [19][0/132]	Time (0.020)	Data (0.013)	Loss (0.4520)	Accuracy (84.000)
# Epoch: [19][10/132]	Time (0.031)	Data (0.020)	Loss (0.4803)	Accuracy (76.818)
# Epoch: [19][20/132]	Time (0.031)	Data (0.020)	Loss (0.4373)	Accuracy (78.762)
# Epoch: [19][30/132]	Time (0.031)	Data (0.020)	Loss (0.4377)	Accuracy (79.000)
# Epoch: [19][40/132]	Time (0.030)	Data (0.019)	Loss (0.4404)	Accuracy (78.829)
# Epoch: [19][50/132]	Time (0.029)	Data (0.019)	Loss (0.4492)	Accuracy (78.235)
# Epoch: [19][60/132]	Time (0.029)	Data (0.018)	Loss (0.4407)	Accuracy (79.082)
# Epoch: [19][70/132]	Time (0.029)	Data (0.018)	Loss (0.4383)	Accuracy (79.282)
# Epoch: [19][80/132]	Time (0.028)	Data (0.018)	Loss (0.4386)	Accuracy (79.481)
# Epoch: [19][90/132]	Time (0.028)	Data (0.018)	Loss (0.4402)	Accuracy (79.231)
# Epoch: [19][100/132]	Time (0.028)	Data (0.018)	Loss (0.4392)	Accuracy (79.267)
# Epoch: [19][110/132]	Time (0.028)	Data (0.017)	Loss (0.4359)	Accuracy (79.568)
# Epoch: [19][120/132]	Time (0.028)	Data (0.017)	Loss (0.4351)	Accuracy (79.702)
# Epoch: [19][130/132]	Time (0.027)	Data (0.017)	Loss (0.4307)	Accuracy (79.817)
# Test: [0/24]	Time (0.019)	Loss (0.5860)	Accuracy (68.000)
# Test: [10/24]	Time (0.014)	Loss (0.5627)	Accuracy (72.000)
# Test: [20/24]	Time (0.014)	Loss (0.5296)	Accuracy (73.571)

# %% [markdown]
# # Plot best model

# %%
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, title):
    print("*****************************Plot learning curves*********************")
    x = len(train_losses)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_losses, label = "train_losses")
    plt.plot(x, valid_losses, label = "valid_losses" )
    plt.title("Loss Curve")
    plt.xlabel("epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(title + "_loss_curve.png")
    plt.show()

    print("*****************************Plot accuracy curves*********************")
    x = len(valid_accuracies)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_accuracies, label = "train_accuracies")
    plt.plot(x, valid_accuracies, label = "valid_accuracies")
    plt.title("Accuracy Curve")
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.savefig(title + "_acc_curve.png")
    plt.show()


def plot_confusion_matrix(results, class_names, title):
    print("*****************************Plot confusion maxtrix*********************")
    y_true, y_pred = zip(*results)
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=class_names, yticklabels=class_names,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha='center', va='center', color='white' if cm[i, j] > thresh else 'black')
    fig.tight_layout()
    plt.savefig(title + "_cm.png")
    plt.show()

# %%
best_model = torch.load(os.path.join(PATH_OUTPUT, "MyNet.pth"))
plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot learning curves*********************
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
class_names = ['Live','Death']
plot_confusion_matrix(valid_results, class_names, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot confusion maxtrix*********************
# [[0.6360424  0.3639576 ]
#  [0.18471338 0.81528662]]

# %% [markdown]
# # Predict

# %%
def predict_mortality(model, device, data_loader):
    model.eval()
    model.to(device)
    probas = []
    trues = []
    with torch.no_grad():
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)

            output = model(input)
            output = nn.Sigmoid()(output)

            if output[0][0] < output[0][1]:
                probas.append(1)
            else:
                probas.append(0)
            trues.append(target)
    acc = accuracy_score(trues, probas)
    print('The accuracy of test dataset is {}'.format(acc))
    return probas


test_prob = predict_mortality(best_model, device, test_loader)
# Out:
# The accuracy of test dataset is 0.7469194312796209

# %%
def make_report(list_id, list_prob, path):
    if len(list_id) != len(list_prob):
        raise AttributeError("ID list and Probability list have different lengths")

    os.makedirs(path, exist_ok=True)
    output_file = open(os.path.join(path, 'my_predictions.csv'), 'w')
    output_file.write("SUBJECT_ID,MORTALITY\n")
    for pid, prob in zip(list_id, list_prob):
        output_file.write("{},{}\n".format(pid, prob))
    output_file.close()

# %%
make_report(test_ids, test_prob, PATH_OUTPUT)
num_test_patient = len(test_ids)

# %%
num_test_patient
# Out:
# 1055
