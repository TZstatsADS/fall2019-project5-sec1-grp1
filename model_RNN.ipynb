# %%
import os
import pickle
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

PATH_DATA = "./data/mortality/data/"
PATH_VALIDATION = "./data/mortality/validation/"
PATH_OUTPUT = "./output/"

# %% [markdown]
# # Mortality Prediction Based on RNN with GRU

# %% [markdown]
# ## 1. Data Overview
#
# - Data source: MIMIC-III https://mimic.physionet.org/

# %%
df_mortality = pd.read_csv(os.path.join(PATH_DATA, "MORTALITY.csv"))
df_admissions = pd.read_csv(os.path.join(PATH_DATA, "ADMISSIONS.csv"))
df_diagnoses = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"))

# %%
df_mortality.head()
# Out:
#    SUBJECT_ID  MORTALITY
# 0         252          1
# 1         721          1
# 2         776          1
# 3         801          0
# 4         822          1

# %%
df_admissions.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 1      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 2      33          34   115799  2186-07-18 16:46:00  2186-07-20 16:00:00
# 3      34          34   144319  2191-02-23 05:23:00  2191-02-25 20:20:00
# 4      36          36   182104  2131-04-30 07:15:00  2131-05-08 14:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION DISCHARGE_LOCATION  \
# 0       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE
# 1       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM   HOME HEALTH CARE
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM               HOME
# 3       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
# 4       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE   HOME HEALTH CARE
#
#   INSURANCE LANGUAGE       RELIGION MARITAL_STATUS ETHNICITY  \
# 0  Medicare      NaN       CATHOLIC        MARRIED     WHITE
# 1  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 2  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 3  Medicare     ENGL       CATHOLIC        MARRIED     WHITE
# 4  Medicare     ENGL  NOT SPECIFIED        MARRIED     WHITE
#
#              EDREGTIME            EDOUTTIME  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3  2191-02-23 04:23:00  2191-02-23 07:25:00
# 4                  NaN                  NaN
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 1                                         BRAIN MASS                     0
# 2                                    CHEST PAIN\CATH                     0
# 3                                        BRADYCARDIA                     0
# 4  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
df_diagnoses.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1523         117   140784      1.0      5715
# 1    1524         117   140784      2.0      7895
# 2    1525         117   140784      3.0     07054
# 3    1526         117   140784      4.0      2875
# 4    1527         117   140784      5.0      4280

# %% [markdown]
# ## 2. Data preprocessing
#
# ### 2.1 Build original dataset
#
# - `extract_code`
#  - follow ICD-9-CM format (https://www.cms.gov/Medicare/Quality-Initiatives-Patient-Assessment-Instruments/HospitalQualityInits/Downloads/HospitalAppendix_F.pdf) to extract main digits of ICD-9 code
#
#
# - `build_dict`
#  - create corresponding id map for ICD-9 code, {main digits of ICD9: unique feature ID}
#
#
# - `build_dataset`
#  - group the diagnosis codes for the same visit
#  - group the visits for same patient
#  - make visit lists for paitents with chronological order
#  - return: List(patient IDs), List(labels), Visit sequence data as a List of List of List.

# %%
def extract_code(icd9_object):

    icd9_str = str(icd9_object)
    if icd9_str[0] == 'E': icd9_str = icd9_str[0:4]
    else: icd9_str = icd9_str[0:3]
    
    return icd9_str

# %%
def build_dict(df_icd9, extract_func):

    unique_code = df_icd9['ICD9_CODE'].apply(extract_func).unique()
    unique_code = pd.Series(unique_code).sort_values()
    code_dict = dict(zip(unique_code, range(len(unique_code))))
    
    return code_dict

# %%
def build_dataset(path, code_dict, extract_func):

    df_mortality = pd.read_csv(os.path.join(path, "MORTALITY.csv"))
    df_admissions = pd.read_csv(os.path.join(path, "ADMISSIONS.csv"))
    df_diagnoses = pd.read_csv(os.path.join(path, "DIAGNOSES_ICD.csv"))
    
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].apply(extract_func)
    df_diagnoses['ICD9_CODE'] = df_diagnoses['ICD9_CODE'].map(code_dict)
    df_joined = df_admissions.merge(df_diagnoses, on=['HADM_ID', 'SUBJECT_ID'])
    df_patient_admittee_ICD9 = df_joined[['SUBJECT_ID', 'ADMITTIME','ICD9_CODE']]
    
    patient_ids = []
    labels = []
    seq_data = []
    
    for name1, d in df_patient_admittee_ICD9.groupby('SUBJECT_ID'):
        patient_ids.append(name1)
        labels.extend(list(df_mortality["MORTALITY"][(df_mortality["SUBJECT_ID"] == name1)]))
        subl = []
        d['ADMITTIME'] = pd.to_datetime(d['ADMITTIME'])
        for name2, subd in d.groupby('ADMITTIME'):
            subl.append(list(subd['ICD9_CODE']))
        seq_data.append(subl)
    
    return patient_ids, labels, seq_data

# %%
print("Building feature id map")
df_icd9 = pd.read_csv(os.path.join(PATH_DATA, "DIAGNOSES_ICD.csv"), usecols=["ICD9_CODE"])
code_dict = build_dict(df_icd9, extract_code)

print("Constructing train and test set")
ids, labels, seqs = build_dataset(PATH_DATA, code_dict, extract_code)
train_ids, test_ids, train_seqs, test_seqs, train_labels, test_labels = train_test_split(ids, seqs, labels, test_size=0.2)

print("Constructing validation set")
valid_ids, valid_labels, valid_seqs = build_dataset(PATH_VALIDATION, code_dict, extract_code)
print("Completed!")
# Out:
# Building feature id map
# Constructing train and test set
# Constructing validation set
# Completed!

# %%
ids[0:5] # patient IDs
# Out:
# [17, 23, 34, 36, 61]

# %%
labels[0:5] # mortality
# Out:
# [1, 1, 1, 1, 0]

# %%
seqs[0:5] # unique feature id
# Out:
# [[[545, 336, 854, 171], [303, 375, 582, 336, 210, 525, 522, 171]],
#  [[296, 293, 304, 872, 171, 287, 451, 279],
#   [132, 242, 577, 304, 287, 171, 171, 872, 872, 857]],
#  [[292, 308, 305, 307, 746, 306, 296, 782],
#   [307, 308, 306, 296, 881, 308, 148, 258]],
#  [[296, 293, 367, 287, 204, 393, 451, 852, 447],
#   [747, 747, 297, 331, 745, 367, 296, 872, 287, 451, 393, 852],
#   [408, 297, 382, 358, 746, 382, 296, 367, 287, 451, 199, 852]],
#  [[113, 187, 186, 429, 184, 164, 748, 430, 498],
#   [113,
#    183,
#    745,
#    420,
#    418,
#    175,
#    16,
#    744,
#    175,
#    595,
#    43,
#    175,
#    336,
#    307,
#    157,
#    245,
#    34]]]

# %% [markdown]
# ### 2.2 Custom Pytorch Dataset
#
# For each patient, I decided to use a matrix, rows represent different visits, jth column show the integer feature ID j. If matrix[i][j] == 1, it means that on ith visit, we get feature ID j.

# %%
# for each row, get the number of feature id.
def get_num_features(seqs):

    def get_flatten_list(ori_list, flatten_list = None):
        if flatten_list is None: flatten_list = []
        for i in ori_list:
            if isinstance(i, list): get_flatten_list(i, flatten_list)
            else: flatten_list.append(i)
        return flatten_list

    def get_max(list1):
        tmp = -1
        for i in list1:
            if i > tmp: tmp = i
        return tmp
    
    l = get_flatten_list(seqs)
    return get_max(l) + 1

# %%
# inherit from Dataset, represent matrixs.
class MyDataset(Dataset):
    def __init__(self, seqs, labels, num_features):

        self.labels = labels
        self.seqs = []
        def isNaN(num):
            return num != num
        for seq in seqs:
            new_seq = []
            for visit in seq:
                new_visit = [0] * int(num_features)
                for i in visit:
                    if not isNaN(i): new_visit[int(i)] = 1
                new_visit = np.asarray(new_visit)
                new_seq.append(new_visit)
            new_seq = np.asarray(new_seq)
            self.seqs.append(new_seq)
            
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # returns will be wrapped as List of Tensor(s) by DataLoader
        return self.seqs[index], self.labels[index]

# %% [markdown]
# ### 2.3 Generate mini-batches represented by 3D tensors
#
# Generate mini-batches by defining `collate_fn` which is an argument of DataLoader constructor.
#
# - mini-batches: batch_size * max_length * num_features. A min-batch consists of different patient's matrice
#
# - If matrice in same batch have different number of rows, I will padding them with zero rows.

# %%
def collate_fn(batch):

    def getKey(item):
        return item[1]
    
    new_tuples = []
    seqs = []
    labels = []
    lengths = []
    max_length = -1
    num_features = len(batch[0][0][0])
    
    for b in batch:
        b_seqs = b[0]
        tmp_list = [b_seqs, len(b_seqs), b[1]]
        new_tuples.append(tuple(tmp_list))
        if len(b_seqs) > max_length:
            max_length = len(b_seqs)
    batch = sorted(new_tuples, key = getKey, reverse=True)
    
    for b in batch:
        b_seqs = b[0]
        labels.append(b[2])
        lengths.append(b[1])
        b_seqs = list(b_seqs)
        while len(b_seqs) < max_length:
            b_seqs.append([0] * num_features)
        seqs.append(torch.Tensor(b_seqs))
    seqs_tensor = torch.stack(seqs, 0)
    lengths_tensor = torch.LongTensor(lengths)
    labels_tensor = torch.LongTensor(labels)

    return (seqs_tensor, lengths_tensor), labels_tensor

# %% [markdown]
# ## 3. Build RNN model
#
#
# - Only need to define the forward function, the backward function will be generate automatically

# %%
class MyNet(nn.Module):
    def __init__(self, dim_input):
        super(MyNet, self).__init__()
        self.fc1 = nn.Linear(dim_input, 32)
        self.rnn = nn.GRU(input_size=32, hidden_size=16, num_layers=2, batch_first=True, dropout=0.5, bidirectional=False)
        self.fc2 = nn.Linear(16, 2)
        self.tanh = nn.Tanh()

    def forward(self, input_tuple):
        seqs, lengths = input_tuple
        seqs = self.fc1(seqs)
        seqs = F.tanh(seqs)
        seqs = pack_padded_sequence(seqs, lengths, batch_first=True)
        seqs, _ = self.rnn(seqs)
        seqs, _ = pad_packed_sequence(seqs, batch_first=True)
        new_seqs = []
        for i in range(0, len(seqs)):
            new_seqs.append(seqs[i][lengths[i] - 1])
        new_seqs = torch.stack(new_seqs, 0)
        seqs = self.fc2(new_seqs)
        return seqs

# %% [markdown]
# ## 4. Training and validation process

# %%
import os
import time

class MyAverageGenerator():
    def __init__(self):
        self.val = 0
        self.average = 0
        self.sum = 0
        self.count = 0

    def update(self, val, size = 1):
        self.val = val
        self.sum += val * size
        self.count += size
        self.average = self.sum / self.count
 
'''
Reference: https://github.com/cse6250/SepsisPrediction/blob/1b732548e263a29e859540bbcda6ede2c40445db/src/sepsis_prediction_lstm/utils.py
'''

def get_batch_accuracy(output, target):
    
    with torch.no_grad():

        batch_size = target.size(0)
        _, pred = output.max(1)
        correct = pred.eq(target).sum()

        return correct * 100.0 / batch_size

def train(model, device, data_loader, criterion, optimizer, epoch, print_freq=10):
    batch_time = MyAverageGenerator()
    data_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    acc = MyAverageGenerator()

    model.train()

    end = time.time()
    for i, (input, target) in enumerate(data_loader):
        # measure data loading time
        data_time.update(time.time() - end)

        if isinstance(input, tuple):
            input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
        else:
            input = input.to(device)
        target = target.to(device)

        optimizer.zero_grad()
        output = model(input)
        loss = criterion(output, target)
        assert not np.isnan(loss.item()), 'Model diverged with loss = NaN'

        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        losses.update(loss.item(), target.size(0))
        acc.update(get_batch_accuracy(output, target).item(), target.size(0))

        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Time ({batch_time.average:.3f})\t'
                  'Data ({data_time.average:.3f})\t'
                  'Loss ({loss.average:.4f})\t'
                  'Accuracy ({acc.average:.3f})'.format(epoch, i, len(data_loader), batch_time=batch_time, data_time=data_time, loss=losses, acc=acc))

    return losses.average, acc.average


def evaluate(model, device, data_loader, criterion, print_freq=10):
    batch_time = MyAverageGenerator()
    losses = MyAverageGenerator()
    acc = MyAverageGenerator()

    results = []

    model.eval()

    with torch.no_grad():
        end = time.time()
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)
            target = target.to(device)

            output = model(input)
            loss = criterion(output, target)

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            losses.update(loss.item(), target.size(0))
            acc.update(get_batch_accuracy(output, target).item(), target.size(0))

            y_true = target.detach().to('cpu').numpy().tolist()
            y_pred = output.detach().to('cpu').max(1)[1].numpy().tolist()
            results.extend(list(zip(y_true, y_pred)))

            if i % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                      'Time ({batch_time.average:.3f})\t'
                      'Loss ({loss.average:.4f})\t'
                      'Accuracy ({acc.average:.3f})'.format(i, len(data_loader), batch_time=batch_time, loss=losses, acc=acc))

    return losses.average, acc.average, results

# %%
torch.manual_seed(0)
NUM_EPOCHS = 20
BATCH_SIZE = 32
USE_CUDA = False
NUM_WORKERS = 0

# %%
num_features = get_num_features(train_seqs)

train_dataset = MyDataset(train_seqs, train_labels, num_features)
valid_dataset = MyDataset(valid_seqs, valid_labels, num_features)
test_dataset = MyDataset(test_seqs, test_labels, num_features)

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn, num_workers=NUM_WORKERS)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)
# batch_size for the test set should be 1 to avoid sorting each mini-batch which breaks the connection with patient IDs
test_loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn, num_workers=NUM_WORKERS)

# %%
model = MyNet(num_features)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

device = torch.device("cuda" if torch.cuda.is_available() and USE_CUDA else "cpu")
model.to(device)
criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
best_val_acc = 0.0
train_losses, train_accuracies = [], []
valid_losses, valid_accuracies = [], []
for epoch in range(NUM_EPOCHS):
    train_loss, train_accuracy = train(model, device, train_loader, criterion, optimizer, epoch)
    valid_loss, valid_accuracy, valid_results = evaluate(model, device, valid_loader, criterion)

    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    train_accuracies.append(train_accuracy)
    valid_accuracies.append(valid_accuracy)

    is_best = valid_accuracy > best_val_acc  # keep the best model
    if is_best:
        best_val_acc = valid_accuracy
        torch.save(model, os.path.join(PATH_OUTPUT, "MyNet.pth"))
# Out:
# Epoch: [0][0/132]	Time (0.440)	Data (0.034)	Loss (0.7175)	Accuracy (46.875)
# Epoch: [0][10/132]	Time (0.060)	Data (0.016)	Loss (0.6723)	Accuracy (60.511)
# Epoch: [0][20/132]	Time (0.042)	Data (0.014)	Loss (0.6699)	Accuracy (61.012)
# Epoch: [0][30/132]	Time (0.036)	Data (0.014)	Loss (0.6700)	Accuracy (60.988)
# Epoch: [0][40/132]	Time (0.035)	Data (0.015)	Loss (0.6671)	Accuracy (61.814)
# Epoch: [0][50/132]	Time (0.032)	Data (0.015)	Loss (0.6658)	Accuracy (62.194)
# Epoch: [0][60/132]	Time (0.031)	Data (0.014)	Loss (0.6655)	Accuracy (62.244)
# Epoch: [0][70/132]	Time (0.030)	Data (0.014)	Loss (0.6661)	Accuracy (62.016)
# Epoch: [0][80/132]	Time (0.028)	Data (0.014)	Loss (0.6676)	Accuracy (61.497)
# Epoch: [0][90/132]	Time (0.028)	Data (0.014)	Loss (0.6653)	Accuracy (62.122)
# Epoch: [0][100/132]	Time (0.028)	Data (0.014)	Loss (0.6653)	Accuracy (62.129)
# Epoch: [0][110/132]	Time (0.029)	Data (0.015)	Loss (0.6655)	Accuracy (61.965)
# Epoch: [0][120/132]	Time (0.029)	Data (0.015)	Loss (0.6653)	Accuracy (62.009)
# Epoch: [0][130/132]	Time (0.028)	Data (0.015)	Loss (0.6643)	Accuracy (62.238)
# Test: [0/24]	Time (0.016)	Loss (0.6833)	Accuracy (56.250)
# Test: [10/24]	Time (0.019)	Loss (0.6651)	Accuracy (61.364)
# Test: [20/24]	Time (0.017)	Loss (0.6624)	Accuracy (62.054)
# Epoch: [1][0/132]	Time (0.015)	Data (0.009)	Loss (0.6417)	Accuracy (68.750)
# Epoch: [1][10/132]	Time (0.022)	Data (0.013)	Loss (0.6582)	Accuracy (63.352)
# Epoch: [1][20/132]	Time (0.025)	Data (0.015)	Loss (0.6620)	Accuracy (62.202)
# Epoch: [1][30/132]	Time (0.024)	Data (0.014)	Loss (0.6628)	Accuracy (61.895)
# Epoch: [1][40/132]	Time (0.023)	Data (0.014)	Loss (0.6659)	Accuracy (61.052)
# Epoch: [1][50/132]	Time (0.022)	Data (0.013)	Loss (0.6651)	Accuracy (61.213)
# Epoch: [1][60/132]	Time (0.022)	Data (0.013)	Loss (0.6652)	Accuracy (61.117)
# Epoch: [1][70/132]	Time (0.022)	Data (0.013)	Loss (0.6644)	Accuracy (61.312)
# Epoch: [1][80/132]	Time (0.024)	Data (0.014)	Loss (0.6618)	Accuracy (61.998)
# Epoch: [1][90/132]	Time (0.023)	Data (0.014)	Loss (0.6601)	Accuracy (62.363)
# Epoch: [1][100/132]	Time (0.023)	Data (0.014)	Loss (0.6592)	Accuracy (62.531)
# Epoch: [1][110/132]	Time (0.023)	Data (0.014)	Loss (0.6585)	Accuracy (62.641)
# Epoch: [1][120/132]	Time (0.023)	Data (0.014)	Loss (0.6604)	Accuracy (62.087)
# Epoch: [1][130/132]	Time (0.023)	Data (0.014)	Loss (0.6595)	Accuracy (62.238)
# Test: [0/24]	Time (0.017)	Loss (0.6787)	Accuracy (56.250)
# Test: [10/24]	Time (0.015)	Loss (0.6600)	Accuracy (61.364)
# Test: [20/24]	Time (0.014)	Loss (0.6561)	Accuracy (62.054)
# Epoch: [2][0/132]	Time (0.015)	Data (0.009)	Loss (0.6124)	Accuracy (71.875)
# Epoch: [2][10/132]	Time (0.022)	Data (0.013)	Loss (0.6447)	Accuracy (65.057)
# Epoch: [2][20/132]	Time (0.021)	Data (0.013)	Loss (0.6501)	Accuracy (63.542)
# Epoch: [2][30/132]	Time (0.024)	Data (0.014)	Loss (0.6554)	Accuracy (62.198)
# Epoch: [2][40/132]	Time (0.023)	Data (0.013)	Loss (0.6564)	Accuracy (61.814)
# Epoch: [2][50/132]	Time (0.025)	Data (0.015)	Loss (0.6572)	Accuracy (61.336)
# Epoch: [2][60/132]	Time (0.025)	Data (0.015)	Loss (0.6573)	Accuracy (61.424)
# Epoch: [2][70/132]	Time (0.025)	Data (0.015)	Loss (0.6551)	Accuracy (61.972)
# Epoch: [2][80/132]	Time (0.024)	Data (0.015)	Loss (0.6536)	Accuracy (62.191)
# Epoch: [2][90/132]	Time (0.024)	Data (0.015)	Loss (0.6544)	Accuracy (61.985)
# Epoch: [2][100/132]	Time (0.024)	Data (0.014)	Loss (0.6535)	Accuracy (62.098)
# Epoch: [2][110/132]	Time (0.025)	Data (0.015)	Loss (0.6531)	Accuracy (61.909)
# Epoch: [2][120/132]	Time (0.024)	Data (0.015)	Loss (0.6505)	Accuracy (62.474)
# Epoch: [2][130/132]	Time (0.025)	Data (0.015)	Loss (0.6504)	Accuracy (62.261)
# Test: [0/24]	Time (0.013)	Loss (0.6629)	Accuracy (56.250)
# Test: [10/24]	Time (0.015)	Loss (0.6482)	Accuracy (61.364)
# Test: [20/24]	Time (0.017)	Loss (0.6417)	Accuracy (62.202)
# Epoch: [3][0/132]	Time (0.018)	Data (0.011)	Loss (0.6105)	Accuracy (65.625)
# Epoch: [3][10/132]	Time (0.021)	Data (0.013)	Loss (0.6375)	Accuracy (64.489)
# Epoch: [3][20/132]	Time (0.021)	Data (0.013)	Loss (0.6354)	Accuracy (63.839)
# Epoch: [3][30/132]	Time (0.022)	Data (0.013)	Loss (0.6325)	Accuracy (64.214)
# Epoch: [3][40/132]	Time (0.023)	Data (0.014)	Loss (0.6398)	Accuracy (62.652)
# Epoch: [3][50/132]	Time (0.022)	Data (0.014)	Loss (0.6385)	Accuracy (63.051)
# Epoch: [3][60/132]	Time (0.022)	Data (0.014)	Loss (0.6355)	Accuracy (63.525)
# Epoch: [3][70/132]	Time (0.022)	Data (0.013)	Loss (0.6336)	Accuracy (63.908)
# Epoch: [3][80/132]	Time (0.023)	Data (0.014)	Loss (0.6349)	Accuracy (63.426)
# Epoch: [3][90/132]	Time (0.022)	Data (0.014)	Loss (0.6345)	Accuracy (63.255)
# Epoch: [3][100/132]	Time (0.023)	Data (0.014)	Loss (0.6351)	Accuracy (62.964)
# Epoch: [3][110/132]	Time (0.023)	Data (0.014)	Loss (0.6325)	Accuracy (63.570)
# Epoch: [3][120/132]	Time (0.023)	Data (0.014)	Loss (0.6291)	Accuracy (64.282)
# Epoch: [3][130/132]	Time (0.023)	Data (0.014)	Loss (0.6301)	Accuracy (64.003)
# Test: [0/24]	Time (0.016)	Loss (0.6277)	Accuracy (68.750)
# Test: [10/24]	Time (0.016)	Loss (0.6231)	Accuracy (63.636)
# Test: [20/24]	Time (0.015)	Loss (0.6107)	Accuracy (66.369)
# Epoch: [4][0/132]	Time (0.016)	Data (0.009)	Loss (0.6339)	Accuracy (62.500)
# Epoch: [4][10/132]	Time (0.022)	Data (0.013)	Loss (0.6060)	Accuracy (69.318)
# Epoch: [4][20/132]	Time (0.023)	Data (0.014)	Loss (0.6122)	Accuracy (67.560)
# Epoch: [4][30/132]	Time (0.024)	Data (0.014)	Loss (0.6077)	Accuracy (67.742)
# Epoch: [4][40/132]	Time (0.024)	Data (0.014)	Loss (0.6035)	Accuracy (68.521)
# Epoch: [4][50/132]	Time (0.024)	Data (0.014)	Loss (0.6019)	Accuracy (68.689)
# Epoch: [4][60/132]	Time (0.024)	Data (0.014)	Loss (0.6040)	Accuracy (68.084)
# Epoch: [4][70/132]	Time (0.023)	Data (0.014)	Loss (0.6065)	Accuracy (67.077)
# Epoch: [4][80/132]	Time (0.023)	Data (0.013)	Loss (0.6035)	Accuracy (67.515)
# Epoch: [4][90/132]	Time (0.023)	Data (0.014)	Loss (0.5979)	Accuracy (68.166)
# Epoch: [4][100/132]	Time (0.022)	Data (0.013)	Loss (0.5973)	Accuracy (68.069)
# Epoch: [4][110/132]	Time (0.022)	Data (0.013)	Loss (0.5970)	Accuracy (67.962)
# Epoch: [4][120/132]	Time (0.022)	Data (0.013)	Loss (0.5962)	Accuracy (68.104)
# Epoch: [4][130/132]	Time (0.022)	Data (0.013)	Loss (0.5949)	Accuracy (68.368)
# Test: [0/24]	Time (0.015)	Loss (0.5851)	Accuracy (75.000)
# Test: [10/24]	Time (0.014)	Loss (0.5930)	Accuracy (68.750)
# Test: [20/24]	Time (0.014)	Loss (0.5713)	Accuracy (71.131)
# Epoch: [5][0/132]	Time (0.020)	Data (0.012)	Loss (0.5539)	Accuracy (78.125)
# Epoch: [5][10/132]	Time (0.023)	Data (0.014)	Loss (0.5607)	Accuracy (74.148)
# Epoch: [5][20/132]	Time (0.020)	Data (0.012)	Loss (0.5686)	Accuracy (72.768)
# Epoch: [5][30/132]	Time (0.020)	Data (0.012)	Loss (0.5652)	Accuracy (71.875)
# Epoch: [5][40/132]	Time (0.020)	Data (0.012)	Loss (0.5711)	Accuracy (71.570)
# Epoch: [5][50/132]	Time (0.020)	Data (0.012)	Loss (0.5727)	Accuracy (71.507)
# Epoch: [5][60/132]	Time (0.020)	Data (0.012)	Loss (0.5684)	Accuracy (71.824)
# Epoch: [5][70/132]	Time (0.020)	Data (0.012)	Loss (0.5691)	Accuracy (71.655)
# Epoch: [5][80/132]	Time (0.021)	Data (0.013)	Loss (0.5689)	Accuracy (71.451)
# Epoch: [5][90/132]	Time (0.021)	Data (0.013)	Loss (0.5672)	Accuracy (71.429)
# Epoch: [5][100/132]	Time (0.021)	Data (0.013)	Loss (0.5653)	Accuracy (71.689)
# Epoch: [5][110/132]	Time (0.022)	Data (0.013)	Loss (0.5658)	Accuracy (71.650)
# Epoch: [5][120/132]	Time (0.022)	Data (0.013)	Loss (0.5623)	Accuracy (71.798)
# Epoch: [5][130/132]	Time (0.023)	Data (0.013)	Loss (0.5612)	Accuracy (71.875)
# Test: [0/24]	Time (0.015)	Loss (0.5565)	Accuracy (75.000)
# Test: [10/24]	Time (0.014)	Loss (0.5739)	Accuracy (69.886)
# Test: [20/24]	Time (0.016)	Loss (0.5446)	Accuracy (71.875)
# Epoch: [6][0/132]	Time (0.023)	Data (0.014)	Loss (0.5183)	Accuracy (78.125)
# Epoch: [6][10/132]	Time (0.028)	Data (0.014)	Loss (0.5439)	Accuracy (74.148)
# Epoch: [6][20/132]	Time (0.028)	Data (0.016)	Loss (0.5442)	Accuracy (74.405)
# Epoch: [6][30/132]	Time (0.025)	Data (0.014)	Loss (0.5463)	Accuracy (73.992)
# Epoch: [6][40/132]	Time (0.025)	Data (0.014)	Loss (0.5402)	Accuracy (73.780)
# Epoch: [6][50/132]	Time (0.025)	Data (0.015)	Loss (0.5325)	Accuracy (74.326)
# Epoch: [6][60/132]	Time (0.024)	Data (0.014)	Loss (0.5312)	Accuracy (74.488)
# Epoch: [6][70/132]	Time (0.024)	Data (0.014)	Loss (0.5297)	Accuracy (74.472)
# Epoch: [6][80/132]	Time (0.024)	Data (0.014)	Loss (0.5302)	Accuracy (74.344)
# Epoch: [6][90/132]	Time (0.024)	Data (0.014)	Loss (0.5327)	Accuracy (74.073)
# Epoch: [6][100/132]	Time (0.024)	Data (0.014)	Loss (0.5364)	Accuracy (73.855)
# Epoch: [6][110/132]	Time (0.024)	Data (0.014)	Loss (0.5361)	Accuracy (73.902)
# Epoch: [6][120/132]	Time (0.024)	Data (0.014)	Loss (0.5375)	Accuracy (73.502)
# Epoch: [6][130/132]	Time (0.024)	Data (0.014)	Loss (0.5363)	Accuracy (73.664)
# Test: [0/24]	Time (0.015)	Loss (0.5376)	Accuracy (68.750)
# Test: [10/24]	Time (0.016)	Loss (0.5638)	Accuracy (69.886)
# Test: [20/24]	Time (0.015)	Loss (0.5290)	Accuracy (72.768)
# Epoch: [7][0/132]	Time (0.020)	Data (0.012)	Loss (0.5444)	Accuracy (68.750)
# Epoch: [7][10/132]	Time (0.031)	Data (0.018)	Loss (0.5017)	Accuracy (75.852)
# Epoch: [7][20/132]	Time (0.029)	Data (0.017)	Loss (0.5165)	Accuracy (73.958)
# Epoch: [7][30/132]	Time (0.028)	Data (0.016)	Loss (0.5132)	Accuracy (74.496)
# Epoch: [7][40/132]	Time (0.027)	Data (0.016)	Loss (0.5189)	Accuracy (74.238)
# Epoch: [7][50/132]	Time (0.027)	Data (0.016)	Loss (0.5188)	Accuracy (74.203)
# Epoch: [7][60/132]	Time (0.026)	Data (0.015)	Loss (0.5198)	Accuracy (74.232)
# Epoch: [7][70/132]	Time (0.025)	Data (0.015)	Loss (0.5171)	Accuracy (74.648)
# Epoch: [7][80/132]	Time (0.025)	Data (0.015)	Loss (0.5121)	Accuracy (75.231)
# Epoch: [7][90/132]	Time (0.026)	Data (0.015)	Loss (0.5136)	Accuracy (75.000)
# Epoch: [7][100/132]	Time (0.025)	Data (0.015)	Loss (0.5165)	Accuracy (74.505)
# Epoch: [7][110/132]	Time (0.024)	Data (0.015)	Loss (0.5193)	Accuracy (74.268)
# Epoch: [7][120/132]	Time (0.024)	Data (0.015)	Loss (0.5193)	Accuracy (74.199)
# Epoch: [7][130/132]	Time (0.024)	Data (0.014)	Loss (0.5171)	Accuracy (74.499)
# Test: [0/24]	Time (0.013)	Loss (0.5291)	Accuracy (68.750)
# Test: [10/24]	Time (0.014)	Loss (0.5592)	Accuracy (71.591)
# Test: [20/24]	Time (0.014)	Loss (0.5224)	Accuracy (73.810)
# Epoch: [8][0/132]	Time (0.013)	Data (0.008)	Loss (0.4396)	Accuracy (81.250)
# Epoch: [8][10/132]	Time (0.019)	Data (0.011)	Loss (0.5102)	Accuracy (75.568)
# Epoch: [8][20/132]	Time (0.019)	Data (0.012)	Loss (0.5281)	Accuracy (75.744)
# Epoch: [8][30/132]	Time (0.021)	Data (0.013)	Loss (0.5338)	Accuracy (75.605)
# Epoch: [8][40/132]	Time (0.021)	Data (0.013)	Loss (0.5279)	Accuracy (75.991)
# Epoch: [8][50/132]	Time (0.022)	Data (0.013)	Loss (0.5259)	Accuracy (75.735)
# Epoch: [8][60/132]	Time (0.024)	Data (0.014)	Loss (0.5179)	Accuracy (76.127)
# Epoch: [8][70/132]	Time (0.023)	Data (0.014)	Loss (0.5159)	Accuracy (76.056)
# Epoch: [8][80/132]	Time (0.024)	Data (0.014)	Loss (0.5124)	Accuracy (76.119)
# Epoch: [8][90/132]	Time (0.024)	Data (0.014)	Loss (0.5060)	Accuracy (76.202)
# Epoch: [8][100/132]	Time (0.024)	Data (0.014)	Loss (0.5081)	Accuracy (75.897)
# Epoch: [8][110/132]	Time (0.024)	Data (0.014)	Loss (0.5112)	Accuracy (75.563)
# Epoch: [8][120/132]	Time (0.024)	Data (0.014)	Loss (0.5073)	Accuracy (75.775)
# Epoch: [8][130/132]	Time (0.024)	Data (0.014)	Loss (0.5032)	Accuracy (76.097)
# Test: [0/24]	Time (0.020)	Loss (0.5196)	Accuracy (71.875)
# Test: [10/24]	Time (0.017)	Loss (0.5580)	Accuracy (70.739)
# Test: [20/24]	Time (0.016)	Loss (0.5193)	Accuracy (73.065)
# Epoch: [9][0/132]	Time (0.027)	Data (0.015)	Loss (0.4809)	Accuracy (78.125)
# Epoch: [9][10/132]	Time (0.029)	Data (0.017)	Loss (0.5522)	Accuracy (73.580)
# Epoch: [9][20/132]	Time (0.024)	Data (0.014)	Loss (0.4992)	Accuracy (75.744)
# Epoch: [9][30/132]	Time (0.022)	Data (0.013)	Loss (0.4928)	Accuracy (76.815)
# Epoch: [9][40/132]	Time (0.022)	Data (0.013)	Loss (0.4865)	Accuracy (76.829)
# Epoch: [9][50/132]	Time (0.023)	Data (0.014)	Loss (0.4835)	Accuracy (77.206)
# Epoch: [9][60/132]	Time (0.023)	Data (0.013)	Loss (0.4917)	Accuracy (76.332)
# Epoch: [9][70/132]	Time (0.023)	Data (0.014)	Loss (0.4941)	Accuracy (76.012)
# Epoch: [9][80/132]	Time (0.023)	Data (0.013)	Loss (0.4893)	Accuracy (76.620)
# Epoch: [9][90/132]	Time (0.023)	Data (0.014)	Loss (0.4881)	Accuracy (76.683)
# Epoch: [9][100/132]	Time (0.024)	Data (0.014)	Loss (0.4913)	Accuracy (76.392)
# Epoch: [9][110/132]	Time (0.024)	Data (0.014)	Loss (0.4935)	Accuracy (76.211)
# Epoch: [9][120/132]	Time (0.024)	Data (0.014)	Loss (0.4903)	Accuracy (76.472)
# Epoch: [9][130/132]	Time (0.024)	Data (0.014)	Loss (0.4919)	Accuracy (76.312)
# Test: [0/24]	Time (0.012)	Loss (0.5260)	Accuracy (71.875)
# Test: [10/24]	Time (0.015)	Loss (0.5570)	Accuracy (72.727)
# Test: [20/24]	Time (0.013)	Loss (0.5211)	Accuracy (73.810)
# Epoch: [10][0/132]	Time (0.016)	Data (0.009)	Loss (0.4341)	Accuracy (81.250)
# Epoch: [10][10/132]	Time (0.024)	Data (0.014)	Loss (0.4627)	Accuracy (79.545)
# Epoch: [10][20/132]	Time (0.023)	Data (0.013)	Loss (0.4775)	Accuracy (78.869)
# Epoch: [10][30/132]	Time (0.022)	Data (0.013)	Loss (0.4784)	Accuracy (77.520)
# Epoch: [10][40/132]	Time (0.024)	Data (0.014)	Loss (0.4826)	Accuracy (77.668)
# Epoch: [10][50/132]	Time (0.023)	Data (0.014)	Loss (0.4770)	Accuracy (77.819)
# Epoch: [10][60/132]	Time (0.023)	Data (0.014)	Loss (0.4865)	Accuracy (77.152)
# Epoch: [10][70/132]	Time (0.025)	Data (0.015)	Loss (0.4891)	Accuracy (76.937)
# Epoch: [10][80/132]	Time (0.025)	Data (0.015)	Loss (0.4902)	Accuracy (76.813)
# Epoch: [10][90/132]	Time (0.024)	Data (0.014)	Loss (0.4911)	Accuracy (76.923)
# Epoch: [10][100/132]	Time (0.025)	Data (0.015)	Loss (0.4937)	Accuracy (76.702)
# Epoch: [10][110/132]	Time (0.024)	Data (0.014)	Loss (0.4964)	Accuracy (76.323)
# Epoch: [10][120/132]	Time (0.024)	Data (0.014)	Loss (0.4932)	Accuracy (76.498)
# Epoch: [10][130/132]	Time (0.024)	Data (0.014)	Loss (0.4899)	Accuracy (76.932)
# Test: [0/24]	Time (0.015)	Loss (0.5195)	Accuracy (71.875)
# Test: [10/24]	Time (0.019)	Loss (0.5536)	Accuracy (71.875)
# Test: [20/24]	Time (0.018)	Loss (0.5176)	Accuracy (73.363)
# Epoch: [11][0/132]	Time (0.021)	Data (0.012)	Loss (0.3487)	Accuracy (87.500)
# Epoch: [11][10/132]	Time (0.023)	Data (0.013)	Loss (0.4509)	Accuracy (80.966)
# Epoch: [11][20/132]	Time (0.021)	Data (0.012)	Loss (0.4932)	Accuracy (76.935)
# Epoch: [11][30/132]	Time (0.023)	Data (0.013)	Loss (0.4854)	Accuracy (77.319)
# Epoch: [11][40/132]	Time (0.023)	Data (0.014)	Loss (0.4785)	Accuracy (77.744)
# Epoch: [11][50/132]	Time (0.023)	Data (0.014)	Loss (0.4837)	Accuracy (77.022)
# Epoch: [11][60/132]	Time (0.022)	Data (0.013)	Loss (0.4802)	Accuracy (76.998)
# Epoch: [11][70/132]	Time (0.023)	Data (0.014)	Loss (0.4738)	Accuracy (77.861)
# Epoch: [11][80/132]	Time (0.023)	Data (0.014)	Loss (0.4709)	Accuracy (77.894)
# Epoch: [11][90/132]	Time (0.024)	Data (0.014)	Loss (0.4739)	Accuracy (77.713)
# Epoch: [11][100/132]	Time (0.023)	Data (0.014)	Loss (0.4785)	Accuracy (77.290)
# Epoch: [11][110/132]	Time (0.024)	Data (0.014)	Loss (0.4767)	Accuracy (77.590)
# Epoch: [11][120/132]	Time (0.023)	Data (0.014)	Loss (0.4746)	Accuracy (77.660)
# Epoch: [11][130/132]	Time (0.023)	Data (0.014)	Loss (0.4806)	Accuracy (77.457)
# Test: [0/24]	Time (0.015)	Loss (0.5191)	Accuracy (68.750)
# Test: [10/24]	Time (0.014)	Loss (0.5543)	Accuracy (71.875)
# Test: [20/24]	Time (0.014)	Loss (0.5163)	Accuracy (73.661)
# Epoch: [12][0/132]	Time (0.020)	Data (0.013)	Loss (0.5158)	Accuracy (75.000)
# Epoch: [12][10/132]	Time (0.019)	Data (0.012)	Loss (0.4571)	Accuracy (78.125)
# Epoch: [12][20/132]	Time (0.022)	Data (0.013)	Loss (0.4538)	Accuracy (79.018)
# Epoch: [12][30/132]	Time (0.024)	Data (0.015)	Loss (0.4542)	Accuracy (80.141)
# Epoch: [12][40/132]	Time (0.024)	Data (0.014)	Loss (0.4533)	Accuracy (79.497)
# Epoch: [12][50/132]	Time (0.024)	Data (0.014)	Loss (0.4499)	Accuracy (79.350)
# Epoch: [12][60/132]	Time (0.023)	Data (0.014)	Loss (0.4623)	Accuracy (78.586)
# Epoch: [12][70/132]	Time (0.023)	Data (0.014)	Loss (0.4656)	Accuracy (78.565)
# Epoch: [12][80/132]	Time (0.023)	Data (0.014)	Loss (0.4682)	Accuracy (78.549)
# Epoch: [12][90/132]	Time (0.022)	Data (0.013)	Loss (0.4731)	Accuracy (78.468)
# Epoch: [12][100/132]	Time (0.022)	Data (0.013)	Loss (0.4706)	Accuracy (78.527)
# Epoch: [12][110/132]	Time (0.022)	Data (0.013)	Loss (0.4722)	Accuracy (77.984)
# Epoch: [12][120/132]	Time (0.022)	Data (0.013)	Loss (0.4759)	Accuracy (77.738)
# Epoch: [12][130/132]	Time (0.022)	Data (0.013)	Loss (0.4756)	Accuracy (77.719)
# Test: [0/24]	Time (0.014)	Loss (0.5242)	Accuracy (71.875)
# Test: [10/24]	Time (0.016)	Loss (0.5524)	Accuracy (72.727)
# Test: [20/24]	Time (0.014)	Loss (0.5171)	Accuracy (73.958)
# Epoch: [13][0/132]	Time (0.015)	Data (0.009)	Loss (0.4659)	Accuracy (78.125)
# Epoch: [13][10/132]	Time (0.019)	Data (0.012)	Loss (0.4774)	Accuracy (78.409)
# Epoch: [13][20/132]	Time (0.019)	Data (0.011)	Loss (0.4721)	Accuracy (78.423)
# Epoch: [13][30/132]	Time (0.019)	Data (0.012)	Loss (0.4791)	Accuracy (77.218)
# Epoch: [13][40/132]	Time (0.020)	Data (0.012)	Loss (0.4691)	Accuracy (77.973)
# Epoch: [13][50/132]	Time (0.020)	Data (0.012)	Loss (0.4714)	Accuracy (78.064)
# Epoch: [13][60/132]	Time (0.020)	Data (0.012)	Loss (0.4671)	Accuracy (78.279)
# Epoch: [13][70/132]	Time (0.020)	Data (0.012)	Loss (0.4635)	Accuracy (78.653)
# Epoch: [13][80/132]	Time (0.021)	Data (0.013)	Loss (0.4643)	Accuracy (78.665)
# Epoch: [13][90/132]	Time (0.022)	Data (0.013)	Loss (0.4690)	Accuracy (78.468)
# Epoch: [13][100/132]	Time (0.022)	Data (0.013)	Loss (0.4696)	Accuracy (78.373)
# Epoch: [13][110/132]	Time (0.021)	Data (0.013)	Loss (0.4666)	Accuracy (78.575)
# Epoch: [13][120/132]	Time (0.022)	Data (0.013)	Loss (0.4654)	Accuracy (78.745)
# Epoch: [13][130/132]	Time (0.022)	Data (0.013)	Loss (0.4655)	Accuracy (78.888)
# Test: [0/24]	Time (0.015)	Loss (0.5241)	Accuracy (68.750)
# Test: [10/24]	Time (0.013)	Loss (0.5532)	Accuracy (72.727)
# Test: [20/24]	Time (0.013)	Loss (0.5170)	Accuracy (73.958)
# Epoch: [14][0/132]	Time (0.015)	Data (0.009)	Loss (0.5735)	Accuracy (68.750)
# Epoch: [14][10/132]	Time (0.020)	Data (0.012)	Loss (0.4739)	Accuracy (78.125)
# Epoch: [14][20/132]	Time (0.023)	Data (0.014)	Loss (0.4545)	Accuracy (79.167)
# Epoch: [14][30/132]	Time (0.023)	Data (0.014)	Loss (0.4457)	Accuracy (79.335)
# Epoch: [14][40/132]	Time (0.023)	Data (0.014)	Loss (0.4583)	Accuracy (79.040)
# Epoch: [14][50/132]	Time (0.023)	Data (0.014)	Loss (0.4611)	Accuracy (78.860)
# Epoch: [14][60/132]	Time (0.022)	Data (0.014)	Loss (0.4588)	Accuracy (78.996)
# Epoch: [14][70/132]	Time (0.022)	Data (0.013)	Loss (0.4579)	Accuracy (78.785)
# Epoch: [14][80/132]	Time (0.022)	Data (0.013)	Loss (0.4565)	Accuracy (78.704)
# Epoch: [14][90/132]	Time (0.022)	Data (0.013)	Loss (0.4606)	Accuracy (78.468)
# Epoch: [14][100/132]	Time (0.022)	Data (0.013)	Loss (0.4566)	Accuracy (78.620)
# Epoch: [14][110/132]	Time (0.022)	Data (0.013)	Loss (0.4595)	Accuracy (78.491)
# Epoch: [14][120/132]	Time (0.021)	Data (0.013)	Loss (0.4606)	Accuracy (78.409)
# Epoch: [14][130/132]	Time (0.022)	Data (0.013)	Loss (0.4617)	Accuracy (78.340)
# Test: [0/24]	Time (0.014)	Loss (0.5299)	Accuracy (65.625)
# Test: [10/24]	Time (0.014)	Loss (0.5547)	Accuracy (73.295)
# Test: [20/24]	Time (0.013)	Loss (0.5199)	Accuracy (74.554)
# Epoch: [15][0/132]	Time (0.013)	Data (0.008)	Loss (0.4116)	Accuracy (84.375)
# Epoch: [15][10/132]	Time (0.020)	Data (0.012)	Loss (0.4518)	Accuracy (80.398)
# Epoch: [15][20/132]	Time (0.019)	Data (0.011)	Loss (0.4726)	Accuracy (78.571)
# Epoch: [15][30/132]	Time (0.019)	Data (0.012)	Loss (0.4676)	Accuracy (77.823)
# Epoch: [15][40/132]	Time (0.020)	Data (0.012)	Loss (0.4699)	Accuracy (78.354)
# Epoch: [15][50/132]	Time (0.021)	Data (0.012)	Loss (0.4643)	Accuracy (78.922)
# Epoch: [15][60/132]	Time (0.020)	Data (0.012)	Loss (0.4621)	Accuracy (79.047)
# Epoch: [15][70/132]	Time (0.021)	Data (0.013)	Loss (0.4537)	Accuracy (79.842)
# Epoch: [15][80/132]	Time (0.021)	Data (0.013)	Loss (0.4590)	Accuracy (79.398)
# Epoch: [15][90/132]	Time (0.021)	Data (0.013)	Loss (0.4603)	Accuracy (79.155)
# Epoch: [15][100/132]	Time (0.021)	Data (0.013)	Loss (0.4589)	Accuracy (79.363)
# Epoch: [15][110/132]	Time (0.022)	Data (0.013)	Loss (0.4624)	Accuracy (79.139)
# Epoch: [15][120/132]	Time (0.021)	Data (0.013)	Loss (0.4593)	Accuracy (79.365)
# Epoch: [15][130/132]	Time (0.022)	Data (0.013)	Loss (0.4605)	Accuracy (79.246)
# Test: [0/24]	Time (0.016)	Loss (0.5313)	Accuracy (68.750)
# Test: [10/24]	Time (0.016)	Loss (0.5550)	Accuracy (73.864)
# Test: [20/24]	Time (0.015)	Loss (0.5208)	Accuracy (74.702)
# Epoch: [16][0/132]	Time (0.018)	Data (0.010)	Loss (0.5788)	Accuracy (68.750)
# Epoch: [16][10/132]	Time (0.021)	Data (0.013)	Loss (0.4426)	Accuracy (81.250)
# Epoch: [16][20/132]	Time (0.021)	Data (0.013)	Loss (0.4651)	Accuracy (79.167)
# Epoch: [16][30/132]	Time (0.021)	Data (0.013)	Loss (0.4620)	Accuracy (79.335)
# Epoch: [16][40/132]	Time (0.021)	Data (0.013)	Loss (0.4577)	Accuracy (78.963)
# Epoch: [16][50/132]	Time (0.021)	Data (0.013)	Loss (0.4544)	Accuracy (79.228)
# Epoch: [16][60/132]	Time (0.021)	Data (0.013)	Loss (0.4479)	Accuracy (80.020)
# Epoch: [16][70/132]	Time (0.021)	Data (0.013)	Loss (0.4473)	Accuracy (79.621)
# Epoch: [16][80/132]	Time (0.022)	Data (0.013)	Loss (0.4542)	Accuracy (79.167)
# Epoch: [16][90/132]	Time (0.022)	Data (0.013)	Loss (0.4550)	Accuracy (79.087)
# Epoch: [16][100/132]	Time (0.022)	Data (0.013)	Loss (0.4521)	Accuracy (79.022)
# Epoch: [16][110/132]	Time (0.023)	Data (0.014)	Loss (0.4520)	Accuracy (78.970)
# Epoch: [16][120/132]	Time (0.023)	Data (0.013)	Loss (0.4516)	Accuracy (79.055)
# Epoch: [16][130/132]	Time (0.024)	Data (0.014)	Loss (0.4531)	Accuracy (79.008)
# Test: [0/24]	Time (0.021)	Loss (0.5329)	Accuracy (65.625)
# Test: [10/24]	Time (0.019)	Loss (0.5550)	Accuracy (73.011)
# Test: [20/24]	Time (0.017)	Loss (0.5196)	Accuracy (74.554)
# Epoch: [17][0/132]	Time (0.017)	Data (0.009)	Loss (0.3116)	Accuracy (87.500)
# Epoch: [17][10/132]	Time (0.026)	Data (0.015)	Loss (0.4077)	Accuracy (80.682)
# Epoch: [17][20/132]	Time (0.026)	Data (0.016)	Loss (0.4634)	Accuracy (78.720)
# Epoch: [17][30/132]	Time (0.025)	Data (0.015)	Loss (0.4654)	Accuracy (78.226)
# Epoch: [17][40/132]	Time (0.025)	Data (0.015)	Loss (0.4590)	Accuracy (78.354)
# Epoch: [17][50/132]	Time (0.025)	Data (0.015)	Loss (0.4521)	Accuracy (79.105)
# Epoch: [17][60/132]	Time (0.025)	Data (0.015)	Loss (0.4536)	Accuracy (79.047)
# Epoch: [17][70/132]	Time (0.025)	Data (0.014)	Loss (0.4491)	Accuracy (79.093)
# Epoch: [17][80/132]	Time (0.025)	Data (0.015)	Loss (0.4495)	Accuracy (79.051)
# Epoch: [17][90/132]	Time (0.025)	Data (0.015)	Loss (0.4448)	Accuracy (79.464)
# Epoch: [17][100/132]	Time (0.025)	Data (0.015)	Loss (0.4507)	Accuracy (79.053)
# Epoch: [17][110/132]	Time (0.025)	Data (0.015)	Loss (0.4527)	Accuracy (79.139)
# Epoch: [17][120/132]	Time (0.025)	Data (0.015)	Loss (0.4517)	Accuracy (79.287)
# Epoch: [17][130/132]	Time (0.025)	Data (0.015)	Loss (0.4531)	Accuracy (79.222)
# Test: [0/24]	Time (0.015)	Loss (0.5385)	Accuracy (65.625)
# Test: [10/24]	Time (0.016)	Loss (0.5554)	Accuracy (73.295)
# Test: [20/24]	Time (0.015)	Loss (0.5206)	Accuracy (74.554)
# Epoch: [18][0/132]	Time (0.016)	Data (0.009)	Loss (0.4181)	Accuracy (81.250)
# Epoch: [18][10/132]	Time (0.021)	Data (0.012)	Loss (0.4491)	Accuracy (80.966)
# Epoch: [18][20/132]	Time (0.021)	Data (0.013)	Loss (0.4604)	Accuracy (79.464)
# Epoch: [18][30/132]	Time (0.022)	Data (0.013)	Loss (0.4519)	Accuracy (79.234)
# Epoch: [18][40/132]	Time (0.021)	Data (0.013)	Loss (0.4499)	Accuracy (79.116)
# Epoch: [18][50/132]	Time (0.021)	Data (0.013)	Loss (0.4465)	Accuracy (78.799)
# Epoch: [18][60/132]	Time (0.022)	Data (0.013)	Loss (0.4445)	Accuracy (79.098)
# Epoch: [18][70/132]	Time (0.023)	Data (0.013)	Loss (0.4444)	Accuracy (78.917)
# Epoch: [18][80/132]	Time (0.023)	Data (0.014)	Loss (0.4400)	Accuracy (79.167)
# Epoch: [18][90/132]	Time (0.023)	Data (0.014)	Loss (0.4440)	Accuracy (78.915)
# Epoch: [18][100/132]	Time (0.023)	Data (0.013)	Loss (0.4418)	Accuracy (79.084)
# Epoch: [18][110/132]	Time (0.023)	Data (0.013)	Loss (0.4421)	Accuracy (79.026)
# Epoch: [18][120/132]	Time (0.023)	Data (0.013)	Loss (0.4422)	Accuracy (78.874)
# Epoch: [18][130/132]	Time (0.023)	Data (0.014)	Loss (0.4463)	Accuracy (78.650)
# Test: [0/24]	Time (0.014)	Loss (0.5432)	Accuracy (68.750)
# Test: [10/24]	Time (0.015)	Loss (0.5562)	Accuracy (73.580)
# Test: [20/24]	Time (0.017)	Loss (0.5218)	Accuracy (74.554)
# Epoch: [19][0/132]	Time (0.022)	Data (0.012)	Loss (0.5188)	Accuracy (75.000)
# Epoch: [19][10/132]	Time (0.027)	Data (0.015)	Loss (0.4520)	Accuracy (78.125)
# Epoch: [19][20/132]	Time (0.026)	Data (0.015)	Loss (0.4181)	Accuracy (80.506)
# Epoch: [19][30/132]	Time (0.027)	Data (0.015)	Loss (0.4184)	Accuracy (80.645)
# Epoch: [19][40/132]	Time (0.027)	Data (0.015)	Loss (0.4232)	Accuracy (80.640)
# Epoch: [19][50/132]	Time (0.027)	Data (0.015)	Loss (0.4206)	Accuracy (80.576)
# Epoch: [19][60/132]	Time (0.027)	Data (0.015)	Loss (0.4364)	Accuracy (79.662)
# Epoch: [19][70/132]	Time (0.027)	Data (0.015)	Loss (0.4356)	Accuracy (79.974)
# Epoch: [19][80/132]	Time (0.026)	Data (0.015)	Loss (0.4368)	Accuracy (79.938)
# Epoch: [19][90/132]	Time (0.026)	Data (0.015)	Loss (0.4395)	Accuracy (79.842)
# Epoch: [19][100/132]	Time (0.025)	Data (0.015)	Loss (0.4413)	Accuracy (79.827)
# Epoch: [19][110/132]	Time (0.026)	Data (0.015)	Loss (0.4424)	Accuracy (79.842)
# Epoch: [19][120/132]	Time (0.026)	Data (0.015)	Loss (0.4450)	Accuracy (79.623)
# Epoch: [19][130/132]	Time (0.026)	Data (0.015)	Loss (0.4454)	Accuracy (79.699)
# Test: [0/24]	Time (0.017)	Loss (0.5498)	Accuracy (68.750)
# Test: [10/24]	Time (0.017)	Loss (0.5569)	Accuracy (73.580)
# Test: [20/24]	Time (0.014)	Loss (0.5227)	Accuracy (74.554)

# %% [markdown]
# ## 5. Plot best model

# %%
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, title):
    print("*****************************Plot learning curves*********************")
    x = len(train_losses)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_losses, label = "train_losses")
    plt.plot(x, valid_losses, label = "valid_losses" )
    plt.title("Loss Curve")
    plt.xlabel("epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(title + "_loss_curve.png")
    plt.show()

    print("*****************************Plot accuracy curves*********************")
    x = len(valid_accuracies)
    x = np.arange(x)
    plt.figure()
    plt.plot(x, train_accuracies, label = "train_accuracies")
    plt.plot(x, valid_accuracies, label = "valid_accuracies")
    plt.title("Accuracy Curve")
    plt.xlabel("epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.savefig(title + "_acc_curve.png")
    plt.show()


def plot_confusion_matrix(results, class_names, title):
    print("*****************************Plot confusion maxtrix*********************")
    y_true, y_pred = zip(*results)
    cm = confusion_matrix(y_true, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)

    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=class_names, yticklabels=class_names,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f'
    thresh = cm.max() / 2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha='center', va='center', color='white' if cm[i, j] > thresh else 'black')
    fig.tight_layout()
    plt.savefig(title + "_cm.png")
    plt.show()

# %%
best_model = torch.load(os.path.join(PATH_OUTPUT, "MyNet.pth"))
plot_learning_curves(train_losses, valid_losses, train_accuracies, valid_accuracies, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot learning curves*********************
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %% [markdown]
# ![loss curve](./figs/MyNet_loss_curve.png)
#
#
# ![accuracy curve](./figs/MyNet_acc_curve.png)

# %%
class_names = ['Live','Death']
plot_confusion_matrix(valid_results, class_names, os.path.join(PATH_OUTPUT, "MyNet"))
# Out:
# *****************************Plot confusion maxtrix*********************
# [[0.6360424  0.3639576 ]
#  [0.18471338 0.81528662]]

# %% [markdown]
# - Precision: 0.64
# - Recall: 0.78

# %% [markdown]
# ![confusion matrix](./figs/MyNet_cm.png)

# %% [markdown]
# ## 6. Predict

# %%
def predict_mortality(model, device, data_loader):
    model.eval()
    model.to(device)
    probas = []
    trues = []
    with torch.no_grad():
        for i, (input, target) in enumerate(data_loader):

            if isinstance(input, tuple):
                input = tuple([e.to(device) if type(e) == torch.Tensor else e for e in input])
            else:
                input = input.to(device)

            output = model(input)
            output = nn.Sigmoid()(output)

            if output[0][0] < output[0][1]:
                probas.append(1)
            else:
                probas.append(0)
            trues.append(target)
    acc = accuracy_score(trues, probas)
    print('The accuracy of test dataset is {}'.format(acc))
    return probas


test_prob = predict_mortality(best_model, device, test_loader)
# Out:
# The accuracy of test dataset is 0.7469194312796209

# %%
def make_report(list_id, list_prob, path):
    if len(list_id) != len(list_prob):
        raise AttributeError("ID list and Probability list have different lengths")

    os.makedirs(path, exist_ok=True)
    output_file = open(os.path.join(path, 'my_predictions.csv'), 'w')
    output_file.write("SUBJECT_ID,MORTALITY\n")
    for pid, prob in zip(list_id, list_prob):
        output_file.write("{},{}\n".format(pid, prob))
    output_file.close()

# %%
make_report(test_ids, test_prob, PATH_OUTPUT)
num_test_patient = len(test_ids)

# %%
num_test_patient
# Out:
# 1055
